# %%
print "IMPORTING LIBRARIES..."
import pandas as pd
import numpy as np
import statsmodels.api as sm
import re
import requests
from requests.auth import HTTPBasicAuth


#DOWLOADING FILE FROM DROPBOX FIRST TIME
import urllib2
import os.path
import time
import random
while not os.path.exists('dev.csv') or not os.path.exists('oot0.csv'):
    time.sleep (3*random.random()); #Sleeping less than 3 seconds before going to Dropbox - avoid too many students at once.
    if not os.path.exists('dev.csv'):
        print "DOWLOADING FILE dev.csv FROM DROPBOX BECAUSE LOCAL FILE DOES NOT EXIST!"
        csvfile = urllib2.urlopen("https://dl.dropboxusercontent.com/u/28535341/dev.csv")
        output = open('dev.csv','wb')
        output.write(csvfile.read())
        output.close()
    if not os.path.exists('oot0.csv'):
        print "DOWLOADING FILE oot0.csv FROM DROPBOX BECAUSE LOCAL FILE DOES NOT EXIST!"
        csvfile = urllib2.urlopen("https://dl.dropboxusercontent.com/u/28535341/oot0.csv")
        output = open('oot0.csv','wb')
        output.write(csvfile.read())
        output.close()  
#DOWLOADING FILE FROM DROPBOX FIRST TIME

def psi(bench, comp, group):
    ben_len=len(bench);
    comp_len=len(comp);
    bench.sort();
    comp.sort();
    psi_cut=[];
    n=int(math.floor(ben_len/group));
    for i in range(1,group):
        lowercut=bench[(i-1)*n+1];
        if i!=group:
            uppercut=bench[(i*n)];
            ben_cnt=n;
        else:
            uppercut=bench[-1];
            ben_cnt=ben_len-group*(n-1)
    comp_cnt = len([i for i in comp if i > lowercut and i<=uppercut]);
    ben_pct=(ben_cnt+0.0)/ben_len;
    comp_pct=(comp_cnt+0.0)/comp_len;
    if comp_pct > 0.0:
        psi_cut.append((ben_pct-comp_pct)*math.log(ben_pct/(comp_pct)));
    else:
        psi_cut.append(0);
    psi=sum(psi_cut);
    return psi;
    
print "LOADING DATASETS..."
df = pd.read_csv("dev.csv") #DEV-SAMPLE
dfo = pd.read_csv("oot0.csv")#OUT-OF-TIME SAMPLE

print "IDENTIFYING TYPES..."
in_model = []
list_ib = set()  #input binary
list_icn = set() #input categorical nominal
list_ico = set() #input categorical ordinal
list_if = set()  #input numerical continuos (input float)
list_inputs = set()
output_var = 'ob_target'

for var_name in df.columns:
    if re.search('^i',var_name):
        list_inputs.add(var_name)
        print var_name,"is input"   
    if re.search('^ib_',var_name):
        list_ib.add(var_name)
        print var_name,"is input binary"
    elif re.search('^icn_',var_name):
        list_icn.add(var_name)
        print var_name,"is input categorical nominal"
    elif re.search('^ico_',var_name):
        list_ico.add(var_name)
        print var_name,"is input categorical ordinal"
    elif re.search('^if_',var_name):
        list_if.add(var_name)
        print var_name,"is input numerical continuos (input float)"
    elif re.search('^ob_',var_name):
        output_var = var_name
    else:
        print "ERROR: unable to identify the type of:", var_name


print "STEP 1: DOING MY TRANSFORMATIONS..."
#Será necesario transformar las variables categoricas ordinales, en variables 
print " ------------ PSI for DEV dataset-------------"
import re
import math
list_inputs = set()
var_to_check = set()
for var_name in df.columns:
    if re.search('^i',var_name):
        list_inputs.add(var_name)
for var_name in list_inputs:
    psi_value=psi(bench=list(df[var_name]),comp=list(df[var_name]),group=max(2,min((len(set(df[var_name]))),10)));
    if psi_value > 0.1:
        print "psi for ", var_name, " = ", psi_value
        var_to_check.add(var_name)

print " ------------ PSI for OOT dataset-------------"
list_inputs = set()
var_to_check = set()
for var_name in dfo.columns:
    if re.search('^i',var_name):
        list_inputs.add(var_name)
for var_name in list_inputs:
    psi_value=psi(bench=list(dfo[var_name]),comp=list(dfo[var_name]),group=max(2,min((len(set(dfo[var_name]))),10)));
    if psi_value > 0.1:
        print "psi for ", var_name, " = ", psi_value
        var_to_check.add(var_name)

dfo1 = dfo.fillna(dfo.mean())

print "STEP 2: SELECTING CHARACTERISTICS TO ENTER INTO THE MODEL..."
#in_model = list_inputs #['ib_var_1','icn_var_22','ico_var_25','if_var_65']
#in_model = ['ib_var_1','icn_var_22','ico_var_25','if_var_65']
####-------------------------------------------#####
from sklearn.ensemble import RandomForestClassifier

list_inputs = list(set(list_inputs))
X = df[list_inputs]
y = df[output_var]

print "STEP 2.1: FEATURE IMPORTANCE WITH RANDOM FOREST..."
# Build a forest and compute the feature importances
forest = RandomForestClassifier(n_estimators=250,
                              random_state=0)
forest.fit(X, y)
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]
# Print the feature ranking
in_model = set()
print("Feature ranking:")
for f in range(81):
    print("%d. feature %s (%f) " % (f + 1, list_inputs[indices[f]], importances[indices[f]] ))
    in_model.add(list_inputs[indices[f]])

in_model = list(in_model) 
print in_model
####-------------------------------------------#####

print "STEP 3: DEVELOPING THE MODEL..."
X = df[list(in_model)]
y = df[output_var]

Xo = dfo1[list(set(in_model))]

#model = sm.Logit(y,X)

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

try:
#     model = sm.GLM(y,X, family = sm.families.Binomial())
#     result = model.fit()
#     print result.summary()
#     y_pred = result.predict(X)
#     yo_pred = result.predict(Xo)

#     model = tree.DecisionTreeClassifier()
#     result = model.fit(X, y)
#     #print result.summary()
#     y_pred = result.predict(X)
#     yo_pred = result.predict(Xo)

    model = RandomForestClassifier(n_estimators=100, criterion='gini')
    result = model.fit(X, y)
    #print result.summary()
    y_pred = result.predict(X)
    yo_pred = result.predict(Xo)
    
except np.linalg.linalg.LinAlgError as err:
    if 'Singular matrix' in err.message:
        print "MODEL-INVALID (Singular Matrix)"
    else:
        raise

print "STEP 4: ASSESSING THE MODEL..."
# CALCULATING GINI PERFORMANCE ON DEVELOPMENT SAMPLE
from sklearn.metrics import roc_auc_score
gini_score = 2*roc_auc_score(df[output_var], y_pred)-1
print "GINI DEVELOPMENT=", gini_score

print "STEP 5: SUBMITTING THE RESULTS..."
dfo['pred'] = yo_pred
dfo_tosend = dfo[list(['id','pred'])]

i=1
filename = "group_Z_sub"+str(i)+".csv"
dfo_tosend.to_csv(filename, sep=',')

url = 'http://mgadi.pythonanywhere.com/api/v1.0/uploadpredictions'

files = {'file': (filename, open(filename, 'rb'))}
rsub = requests.post(url, files=files, auth=HTTPBasicAuth('amarino', 'amarino'))
resp_str = str(rsub.text)
print "RESULT SUBMISSION: ", resp_str
# Out:
# IMPORTING LIBRARIES...
# LOADING DATASETS...
# IDENTIFYING TYPES...
# id is input
# ERROR: unable to identify the type of: id
# ib_var_1 is input
# ib_var_1 is input binary
# ib_var_2 is input
# ib_var_2 is input binary
# ib_var_3 is input
# ib_var_3 is input binary
# ib_var_4 is input
# ib_var_4 is input binary
# ib_var_5 is input
# ib_var_5 is input binary
# ib_var_6 is input
# ib_var_6 is input binary
# ib_var_7 is input
# ib_var_7 is input binary
# ib_var_8 is input
# ib_var_8 is input binary
# ib_var_9 is input
# ib_var_9 is input binary
# ib_var_10 is input
# ib_var_10 is input binary
# ib_var_11 is input
# ib_var_11 is input binary
# ib_var_12 is input
# ib_var_12 is input binary
# ib_var_13 is input
# ib_var_13 is input binary
# ib_var_14 is input
# ib_var_14 is input binary
# ib_var_15 is input
# ib_var_15 is input binary
# ib_var_16 is input
# ib_var_16 is input binary
# ib_var_17 is input
# ib_var_17 is input binary
# ib_var_18 is input
# ib_var_18 is input binary
# ib_var_19 is input
# ib_var_19 is input binary
# ib_var_20 is input
# ib_var_20 is input binary
# ib_var_21 is input
# ib_var_21 is input binary
# icn_var_22 is input
# icn_var_22 is input categorical nominal
# icn_var_23 is input
# icn_var_23 is input categorical nominal
# icn_var_24 is input
# icn_var_24 is input categorical nominal
# ico_var_25 is input
# ico_var_25 is input categorical ordinal
# ico_var_26 is input
# ico_var_26 is input categorical ordinal
# ico_var_27 is input
# ico_var_27 is input categorical ordinal
# ico_var_28 is input
# ico_var_28 is input categorical ordinal
# ico_var_29 is input
# ico_var_29 is input categorical ordinal
# ico_var_30 is input
# ico_var_30 is input categorical ordinal
# ico_var_31 is input
# ico_var_31 is input categorical ordinal
# ico_var_32 is input
# ico_var_32 is input categorical ordinal
# ico_var_33 is input
# ico_var_33 is input categorical ordinal
# ico_var_34 is input
# ico_var_34 is input categorical ordinal
# ico_var_35 is input
# ico_var_35 is input categorical ordinal
# ico_var_36 is input
# ico_var_36 is input categorical ordinal
# ico_var_37 is input
# ico_var_37 is input categorical ordinal
# ico_var_38 is input
# ico_var_38 is input categorical ordinal
# ico_var_39 is input
# ico_var_39 is input categorical ordinal
# ico_var_40 is input
# ico_var_40 is input categorical ordinal
# ico_var_41 is input
# ico_var_41 is input categorical ordinal
# ico_var_42 is input
# ico_var_42 is input categorical ordinal
# ico_var_43 is input
# ico_var_43 is input categorical ordinal
# ico_var_44 is input
# ico_var_44 is input categorical ordinal
# ico_var_45 is input
# ico_var_45 is input categorical ordinal
# ico_var_46 is input
# ico_var_46 is input categorical ordinal
# ico_var_47 is input
# ico_var_47 is input categorical ordinal
# ico_var_48 is input
# ico_var_48 is input categorical ordinal
# ico_var_49 is input
# ico_var_49 is input categorical ordinal
# ico_var_50 is input
# ico_var_50 is input categorical ordinal
# ico_var_51 is input
# ico_var_51 is input categorical ordinal
# ico_var_52 is input
# ico_var_52 is input categorical ordinal
# ico_var_53 is input
# ico_var_53 is input categorical ordinal
# ico_var_54 is input
# ico_var_54 is input categorical ordinal
# ico_var_55 is input
# ico_var_55 is input categorical ordinal
# ico_var_56 is input
# ico_var_56 is input categorical ordinal
# ico_var_57 is input
# ico_var_57 is input categorical ordinal
# ico_var_58 is input
# ico_var_58 is input categorical ordinal
# ico_var_59 is input
# ico_var_59 is input categorical ordinal
# ico_var_60 is input
# ico_var_60 is input categorical ordinal
# ico_var_61 is input
# ico_var_61 is input categorical ordinal
# ico_var_62 is input
# ico_var_62 is input categorical ordinal
# ico_var_63 is input
# ico_var_63 is input categorical ordinal
# ico_var_64 is input
# ico_var_64 is input categorical ordinal
# if_var_65 is input
# if_var_65 is input numerical continuos (input float)
# if_var_66 is input
# if_var_66 is input numerical continuos (input float)
# if_var_67 is input
# if_var_67 is input numerical continuos (input float)
# if_var_68 is input
# if_var_68 is input numerical continuos (input float)
# if_var_69 is input
# if_var_69 is input numerical continuos (input float)
# if_var_70 is input
# if_var_70 is input numerical continuos (input float)
# if_var_71 is input
# if_var_71 is input numerical continuos (input float)
# if_var_72 is input
# if_var_72 is input numerical continuos (input float)
# if_var_73 is input
# if_var_73 is input numerical continuos (input float)
# if_var_74 is input
# if_var_74 is input numerical continuos (input float)
# if_var_75 is input
# if_var_75 is input numerical continuos (input float)
# if_var_76 is input
# if_var_76 is input numerical continuos (input float)
# if_var_77 is input
# if_var_77 is input numerical continuos (input float)
# if_var_78 is input
# if_var_78 is input numerical continuos (input float)
# if_var_79 is input
# if_var_79 is input numerical continuos (input float)
# if_var_80 is input
# if_var_80 is input numerical continuos (input float)
# if_var_81 is input
# if_var_81 is input numerical continuos (input float)
# STEP 1: DOING MY TRANSFORMATIONS...
#  ------------ PSI for DEV dataset-------------
# psi for  ib_var_20  =  0.17451251714
# psi for  ib_var_19  =  0.275016288497
# psi for  ib_var_15  =  0.230828737949
# psi for  ib_var_16  =  0.208713388894
# psi for  ib_var_17  =  0.267449779291
#  ------------ PSI for OOT dataset-------------
# STEP 2: SELECTING CHARACTERISTICS TO ENTER INTO THE MODEL...
# STEP 2.1: FEATURE IMPORTANCE WITH RANDOM FOREST...
# Feature ranking:
# 1. feature if_var_68 (0.041134)
# 2. feature if_var_78 (0.038343)
# 3. feature id (0.037014)
# 4. feature if_var_65 (0.036702)
# 5. feature if_var_79 (0.035192)
# 6. feature if_var_69 (0.030505)
# 7. feature ico_var_34 (0.028048)
# 8. feature if_var_76 (0.027751)
# 9. feature ico_var_35 (0.027401)
# 10. feature if_var_75 (0.026985)
# 11. feature if_var_77 (0.026701)
# 12. feature if_var_67 (0.026019)
# 13. feature ico_var_36 (0.024158)
# 14. feature if_var_72 (0.022102)
# 15. feature if_var_80 (0.022067)
# 16. feature if_var_73 (0.021330)
# 17. feature if_var_71 (0.019819)
# 18. feature ico_var_33 (0.018523)
# 19. feature if_var_81 (0.017479)
# 20. feature ico_var_42 (0.014560)
# 21. feature if_var_70 (0.013803)
# 22. feature ico_var_41 (0.013643)
# 23. feature icn_var_24 (0.013612)
# 24. feature ico_var_52 (0.013586)
# 25. feature ico_var_56 (0.013072)
# 26. feature ico_var_31 (0.012820)
# 27. feature ico_var_29 (0.011898)
# 28. feature ico_var_62 (0.011716)
# 29. feature ico_var_59 (0.011519)
# 30. feature if_var_74 (0.011477)
# 31. feature ico_var_38 (0.011299)
# 32. feature ico_var_47 (0.010693)
# 33. feature ico_var_39 (0.010651)
# 34. feature ico_var_37 (0.010604)
# 35. feature icn_var_22 (0.009964)
# 36. feature ico_var_61 (0.009877)
# 37. feature ico_var_55 (0.009804)
# 38. feature ico_var_57 (0.009662)
# 39. feature ico_var_51 (0.009647)
# 40. feature ico_var_60 (0.009592)
# 41. feature ico_var_53 (0.009425)
# 42. feature ico_var_40 (0.009074)
# 43. feature ico_var_63 (0.008996)
# 44. feature ico_var_48 (0.008979)
# 45. feature ib_var_5 (0.008937)
# 46. feature ico_var_58 (0.008664)
# 47. feature ico_var_43 (0.008643)
# 48. feature ico_var_45 (0.008639)
# 49. feature ico_var_54 (0.008554)
# 50. feature ico_var_27 (0.008533)
# 51. feature ico_var_28 (0.008155)
# 52. feature ico_var_26 (0.008134)
# 53. feature ico_var_30 (0.008094)
# 54. feature ico_var_64 (0.007904)
# 55. feature ico_var_25 (0.007684)
# 56. feature ico_var_44 (0.007512)
# 57. feature ico_var_46 (0.007476)
# 58. feature ico_var_32 (0.007206)
# 59. feature ico_var_49 (0.006574)
# 60. feature ib_var_2 (0.006466)
# 61. feature ib_var_6 (0.006261)
# 62. feature ib_var_4 (0.006112)
# 63. feature icn_var_23 (0.005381)
# 64. feature ib_var_14 (0.005120)
# 65. feature ib_var_3 (0.004992)
# 66. feature ib_var_21 (0.004945)
# 67. feature ico_var_50 (0.004572)
# 68. feature ib_var_18 (0.004225)
# 69. feature ib_var_13 (0.004223)
# 70. feature ib_var_8 (0.004097)
# 71. feature ib_var_20 (0.002455)
# 72. feature ib_var_15 (0.002414)
# 73. feature ib_var_19 (0.002147)
# 74. feature ib_var_16 (0.002110)
# 75. feature ib_var_7 (0.001982)
# 76. feature ib_var_17 (0.001785)
# 77. feature ib_var_1 (0.001674)
# 78. feature ib_var_11 (0.001036)
# 79. feature ib_var_10 (0.000041)
# 80. feature if_var_66 (0.000000)
# 81. feature ib_var_9 (0.000000)
# ['ico_var_49', 'ico_var_26', 'if_var_81', 'if_var_80', 'ico_var_27', 'ib_var_20', 'ico_var_44', 'ib_var_3', 'if_var_65', 'ico_var_36', 'if_var_67', 'ico_var_34', 'ico_var_33', 'ico_var_32', 'ico_var_31', 'ico_var_61', 'ico_var_46', 'if_var_69', 'id', 'ico_var_39', 'ico_var_38', 'ico_var_51', 'ico_var_50', 'ico_var_53', 'ico_var_52', 'ico_var_55', 'ico_var_54', 'ico_var_57', 'ico_var_56', 'ico_var_59', 'ico_var_58', 'if_var_68', 'ib_var_9', 'ico_var_30', 'ib_var_8', 'ico_var_64', 'ib_var_17', 'ib_var_18', 'ib_var_19', 'ico_var_43', 'ib_var_14', 'ib_var_15', 'ib_var_16', 'ico_var_25', 'ib_var_10', 'ib_var_11', 'ib_var_13', 'if_var_76', 'if_var_77', 'if_var_74', 'if_var_75', 'if_var_72', 'if_var_73', 'if_var_70', 'if_var_71', 'ico_var_28', 'ico_var_29', 'ico_var_45', 'if_var_78', 'if_var_79', 'ico_var_42', 'ico_var_37', 'ico_var_40', 'ico_var_41', 'ico_var_60', 'ico_var_47', 'ico_var_62', 'ico_var_63', 'ib_var_6', 'ib_var_7', 'ico_var_48', 'ib_var_5', 'ib_var_2', 'ico_var_35', 'ib_var_21', 'ib_var_1', 'if_var_66', 'icn_var_23', 'icn_var_22', 'ib_var_4', 'icn_var_24']
# STEP 3: DEVELOPING THE MODEL...
# STEP 4: ASSESSING THE MODEL...
# GINI DEVELOPMENT= 1.0
# STEP 5: SUBMITTING THE RESULTS...
# RESULT SUBMISSION:  You are not allowed to send submissions with predict values with less than 3 distinct values. Your csv with predictions had 1 distinct probability values.

# %%
dfo_tosend['pred'].values().unique()
#dfo.isnull().values
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-3a456c01c5b6> in <module>()
# ----> 1 dfo_tosend['pred'].values().unique()
#       2 #dfo.isnull().values
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
def visualize_tree(tree, feature_names):
    """Create tree png using graphviz.

    Args
    ----
    tree -- scikit-learn DecsisionTree.
    feature_names -- list of feature names.
    """
    with open("dt.dot", 'w') as f:
        export_graphviz(tree, out_file=f,
                        feature_names=feature_names)

    command = ["dot", "-Tpng", "dt.dot", "-o", "dt.png"]
    try:
        subprocess.check_call(command)
    except:
        exit("Could not run dot, ie graphviz, to "
             "produce visualization")

        
def psi(bench, comp, group):
    ben_len=len(bench);
    comp_len=len(comp);
    bench.sort();
    comp.sort();
    psi_cut=[];
    n=int(math.floor(ben_len/group));
    for i in range(1,group):
        lowercut=bench[(i-1)*n+1];
        if i!=group:
            uppercut=bench[(i*n)];
            ben_cnt=n;
        else:
            uppercut=bench[-1];
            ben_cnt=ben_len-group*(n-1)
    comp_cnt = len([i for i in comp if i > lowercut and i<=uppercut]);
    ben_pct=(ben_cnt+0.0)/ben_len;
    comp_pct=(comp_cnt+0.0)/comp_len;
    if comp_pct > 0.0:
        psi_cut.append((ben_pct-comp_pct)*math.log(ben_pct/(comp_pct)));
    else:
        psi_cut.append(0);
    psi=sum(psi_cut);
    return psi;
    
print "STEP 1: DOING MY TRANSFORMATIONS..."
#Será necesario transformar las variables categoricas ordinales, en variables 
#Utilizamos el PSI para localizar cambios incorrectos en variables así como localizar NaN
print " ------------ PSI for DEV dataset-------------"
import re
import math
list_inputs = set()
var_to_check = set()
for var_name in df.columns:
    if re.search('^i',var_name):
        list_inputs.add(var_name)
for var_name in list_inputs:
    psi_value=psi(bench=list(df[var_name]),comp=list(df[var_name]),group=max(2,min((len(set(df[var_name]))),10)));
    if psi_value > 0.1:
        print "psi for ", var_name, " = ", psi_value
        var_to_check.add(var_name)

print " ------------ PSI for OOT dataset-------------"
list_inputs = set()
var_to_check = set()
for var_name in dfo.columns:
    if re.search('^i',var_name):
        list_inputs.add(var_name)
for var_name in list_inputs:
    psi_value=psi(bench=list(dfo[var_name]),comp=list(dfo[var_name]),group=max(2,min((len(set(dfo[var_name]))),10)));
    if psi_value > 0.1:
        print "psi for ", var_name, " = ", psi_value
        var_to_check.add(var_name)

dfo1 = dfo.fillna(dfo.mean())
        
print "STEP 2: SELECTING CHARACTERISTICS TO ENTER INTO THE MODEL..."
#in_model = list_inputs #['ib_var_1','icn_var_22','ico_var_25','if_var_65']
#in_model = ['ib_var_1','icn_var_22','ico_var_25','if_var_65']
####-------------------------------------------#####
from sklearn.ensemble import ExtraTreesClassifier

list_inputs = list(set(list_inputs))
X = df[list_inputs]
y = df[output_var]

print "STEP 2.1: FEATURE IMPORTANCE WITH RANDOM FOREST..."
# Build a forest and compute the feature importances
forest = ExtraTreesClassifier(n_estimators=250,
                              random_state=0)
forest.fit(X, y)
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]
# Print the feature ranking
in_model = set()
print("Feature ranking:")
for f in range(70):
    print("%d. feature %s (%f) " % (f + 1, list_inputs[indices[f]], importances[indices[f]] ))
    in_model.add(list_inputs[indices[f]])

in_model = list(in_model) 
print in_model
####-------------------------------------------#####

print "STEP 3: DEVELOPING THE MODEL..."
X = df[list(in_model)]
y = df[output_var]

Xo = dfo1[list(set(in_model))]

#model = sm.Logit(y,X)
from sklearn import tree
try:
#     model = sm.GLM(y,X, family = sm.families.Binomial())
#     result = model.fit()
#     print result.summary()
#     y_pred = result.predict(X)
#     yo_pred = result.predict(Xo)
    
    model = tree.DecisionTreeClassifier()
    result = model.fit(X, y)
    #print result.summary()
    y_pred = result.predict(X)
    yo_pred = result.predict(Xo)
#   visualize_tree(result, X.columns)
    
except np.linalg.linalg.LinAlgError as err:
    if 'Singular matrix' in err.message:
        print "MODEL-INVALID (Singular Matrix)"
    else:
        raise

print "STEP 4: ASSESSING THE MODEL..."
# CALCULATING GINI PERFORMANCE ON DEVELOPMENT SAMPLE
from sklearn.metrics import roc_auc_score
gini_score = 2*roc_auc_score(df[output_var], y_pred)-1
print "GINI DEVELOPMENT=", gini_score
# Out:
# STEP 1: DOING MY TRANSFORMATIONS...
#  ------------ PSI for DEV dataset-------------
# psi for  ib_var_20  =  0.17451251714
# psi for  ib_var_19  =  0.275016288497
# psi for  ib_var_15  =  0.230828737949
# psi for  ib_var_16  =  0.208713388894
# psi for  ib_var_17  =  0.267449779291
#  ------------ PSI for OOT dataset-------------
# STEP 2: SELECTING CHARACTERISTICS TO ENTER INTO THE MODEL...
# STEP 2.1: FEATURE IMPORTANCE WITH RANDOM FOREST...
# Feature ranking:
# 1. feature if_var_68 (0.026441)
# 2. feature if_var_79 (0.022224)
# 3. feature icn_var_24 (0.020946)
# 4. feature ico_var_35 (0.020115)
# 5. feature if_var_65 (0.019753)
# 6. feature if_var_72 (0.019365)
# 7. feature if_var_69 (0.019271)
# 8. feature id (0.017966)
# 9. feature if_var_76 (0.017957)
# 10. feature if_var_70 (0.017495)
# 11. feature if_var_81 (0.017361)
# 12. feature if_var_67 (0.017300)
# 13. feature if_var_71 (0.017178)
# 14. feature ico_var_34 (0.017042)
# 15. feature ico_var_36 (0.016965)
# 16. feature ico_var_31 (0.016831)
# 17. feature if_var_75 (0.016701)
# 18. feature if_var_77 (0.016472)
# 19. feature ico_var_56 (0.016343)
# 20. feature if_var_80 (0.016309)
# 21. feature if_var_78 (0.015884)
# 22. feature ico_var_52 (0.015404)
# 23. feature ico_var_29 (0.014772)
# 24. feature if_var_73 (0.014643)
# 25. feature ib_var_5 (0.014359)
# 26. feature ico_var_55 (0.014254)
# 27. feature icn_var_22 (0.014212)
# 28. feature ico_var_57 (0.014135)
# 29. feature ico_var_59 (0.014130)
# 30. feature ico_var_27 (0.014028)
# 31. feature ib_var_2 (0.014015)
# 32. feature ico_var_39 (0.013957)
# 33. feature ico_var_41 (0.013929)
# 34. feature ico_var_42 (0.013790)
# 35. feature ico_var_33 (0.013691)
# 36. feature ico_var_47 (0.013397)
# 37. feature ico_var_26 (0.013315)
# 38. feature ico_var_53 (0.012909)
# 39. feature ico_var_43 (0.012718)
# 40. feature ico_var_54 (0.012528)
# 41. feature ico_var_48 (0.012479)
# 42. feature ico_var_37 (0.012382)
# 43. feature ico_var_46 (0.012366)
# 44. feature ico_var_60 (0.012362)
# 45. feature ico_var_38 (0.012302)
# 46. feature ico_var_40 (0.012144)
# 47. feature ico_var_63 (0.012103)
# 48. feature ico_var_30 (0.011914)
# 49. feature ico_var_51 (0.011701)
# 50. feature ib_var_4 (0.011683)
# 51. feature ico_var_62 (0.011670)
# 52. feature ico_var_25 (0.011530)
# 53. feature ico_var_61 (0.011518)
# 54. feature ico_var_64 (0.011323)
# 55. feature ico_var_28 (0.011256)
# 56. feature ib_var_6 (0.011233)
# 57. feature ico_var_49 (0.011023)
# 58. feature ib_var_14 (0.010976)
# 59. feature ico_var_32 (0.010930)
# 60. feature ico_var_44 (0.010900)
# 61. feature ico_var_58 (0.010873)
# 62. feature if_var_74 (0.010858)
# 63. feature ico_var_45 (0.010395)
# 64. feature ib_var_13 (0.009379)
# 65. feature ico_var_50 (0.009068)
# 66. feature ib_var_18 (0.009014)
# 67. feature ib_var_21 (0.008641)
# 68. feature icn_var_23 (0.007212)
# 69. feature ib_var_19 (0.005553)
# 70. feature ib_var_3 (0.005251)
# ['ico_var_49', 'ico_var_26', 'if_var_81', 'if_var_80', 'ico_var_37', 'ico_var_27', 'ib_var_3', 'if_var_65', 'ico_var_36', 'if_var_67', 'ico_var_34', 'ico_var_33', 'ico_var_32', 'ico_var_31', 'ico_var_30', 'if_var_69', 'id', 'ico_var_39', 'ico_var_38', 'ico_var_51', 'ico_var_50', 'ico_var_53', 'ico_var_52', 'ico_var_55', 'ico_var_54', 'ico_var_57', 'ico_var_56', 'ico_var_59', 'ico_var_44', 'if_var_68', 'ico_var_64', 'ib_var_18', 'ib_var_19', 'ico_var_45', 'ib_var_14', 'ico_var_25', 'ib_var_13', 'if_var_76', 'if_var_77', 'if_var_74', 'if_var_75', 'if_var_72', 'if_var_73', 'if_var_70', 'if_var_71', 'ico_var_28', 'ico_var_29', 'if_var_78', 'if_var_79', 'ico_var_42', 'ico_var_43', 'ico_var_40', 'ico_var_41', 'ico_var_46', 'ico_var_47', 'ico_var_62', 'ico_var_63', 'ib_var_6', 'ico_var_48', 'ib_var_5', 'ib_var_2', 'ico_var_35', 'ib_var_21', 'ico_var_60', 'ico_var_61', 'ico_var_58', 'icn_var_23', 'icn_var_22', 'ib_var_4', 'icn_var_24']
# STEP 3: DEVELOPING THE MODEL...
# STEP 4: ASSESSING THE MODEL...
# GINI DEVELOPMENT= 1.0

# %%
df['ib_var_17'].describe()
#df[df['ib_var_20']<1.0]['ib_var_20'].count()
#len(df)
# Out:
# count    864.000000
# mean       0.930556
# std        0.254356
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: ib_var_17, dtype: float64

# %%
df['ib_var_15'].isnull().any()
#df[df['ib_var_20']<1.0]['ib_var_20'].count()
#len(df)
# Out:
# False

# %%
# %matplotlib inline  
df.head(5)
df['if_var_65'].describe()
# Out:
# count    864.000000
# mean      38.409722
# std        8.677094
# min       21.000000
# 25%       32.000000
# 50%       38.000000
# 75%       44.000000
# max       63.000000
# Name: if_var_65, dtype: float64

# %%
dfo['if_var_65'].describe()
# Out:
# count    2967.000000
# mean       38.665993
# std         8.629404
# min        18.000000
# 25%        32.000000
# 50%        38.000000
# 75%        45.000000
# max        81.000000
# Name: if_var_65, dtype: float64

# %%
dfo.isnull().any().any()
dfo1 = dfo.fillna(dfo.mean())
dfo1.isnull().any().any()
# Out:
# False

# %%
print "STEP 5: SUBMITTING THE RESULTS..."
dfo['pred'] = yo_pred
dfo_tosend = dfo[list(['id','pred'])]
# Out:
# STEP 5: SUBMITTING THE RESULTS...

# %%
dfo_tosend
# Out:
#         id  pred
# 0        1     0
# 1        2     0
# 2        3     1
# 3        4     1
# 4        5     1
# 5        6     1
# 6        7     1
# 7        8     1
# 8        9     1
# 9       10     1
# 10      11     1
# 11      12     1
# 12      13     1
# 13      14     1
# 14      15     1
# 15      16     1
# 16      17     1
# 17      18     1
# 18      19     1
# 19      20     1
# 20      21     1
# 21      22     1
# 22      23     1
# 23      24     1
# 24      25     1
# 25      26     1
# 26      27     1
# 27      28     1
# 28      29     1
# 29      30     1
# ...    ...   ...
# 2937  2938     1
# 2938  2939     1
# 2939  2940     1
# 2940  2941     1
# 2941  2942     1
# 2942  2943     1
# 2943  2944     1
# 2944  2945     1
# 2945  2946     1
# 2946  2947     1
# 2947  2948     1
# 2948  2949     1
# 2949  2950     1
# 2950  2951     1
# 2951  2952     1
# 2952  2953     1
# 2953  2954     1
# 2954  2955     1
# 2955  2956     1
# 2956  2957     1
# 2957  2958     1
# 2958  2959     1
# 2959  2960     1
# 2960  2961     1
# 2961  2962     1
# 2962  2963     1
# 2963  2964     1
# 2964  2965     1
# 2965  2966     1
# 2966  2967     1
#
# [2967 rows x 2 columns]
