# %%
import json
import pandas as pd
import numpy as np
import re
import nltk

# %%
def processUser(tweet,df):
    userId = int(tweet['user']['id'])
    name = tweet['user']['name']
    location = tweet['user']['location']
    url = tweet['user']['url']
    followers = tweet['user']['followers_count']
    lang = tweet['user']['lang']
    profile_image = tweet['user']['profile_image_url']
    following = tweet['user']['following']
    df.loc[userId] = [name,location,url,followers,lang,profile_image,following]

def processTweet(tweet):
    id = tweet['id']
    userId = tweet['user']['id']
    #print decoded['user']['id']
    processUser(tweet, dfusers)
    geo = tweet['geo']
    coordinates = tweet['coordinates']
    timestamp = tweet['timestamp_ms']
    tweet = tweet['text']
    source = tweet['source']
    isretweeted = False 
    if 'retweeted_status' in tweet:
        if tweet['retweeted_status'] is not 'null':
            isretweeted = True
    lat = 'null'
    lon = 'null'
    polarity = 'null'
    try:
        dftweets.loc[id] = [userId,geo,coordinates,timestamp,tweet,source,isretweeted,lat,lon, polarity]
        print dftweets
    except Exception as e:
        print 'ERRRROR'

# %%
def create_node(user):
    return True

def create_relationship(tweet)
    return True
# Out:
#   File "<ipython-input-6-79adbb6571c2>", line 4
#     def create_relationship(tweet)
#                                   ^
# SyntaxError: invalid syntax

# %%
dfusers = pd.DataFrame(columns=['name','location','url','followers','lang','profile_image','following'])
dftweets = pd.DataFrame(columns=['userId','geo','coordinates','timestamp','tweet','source','isretweeted','lang','lat','lon','polarity'])

# %%
file = open('C:\\Users\\Alberto\\PycharmProjects\\twitterExtraction\\CarmenaTweets.txt','r')
decoded = ''
counter = 0
for line in file:
    counter+=1
    
    try:
        if counter==1:
                print line
        decoded = json.loads(line)
    except Exception as e:
        print e,':',decoded['id'] 
        
    try:
        id = decoded['id']
        userId = str(decoded['user']['id'])
        #print decoded['user']['id']
        processUser(decoded, dfusers)
        geo = decoded['geo']
        coordinates = decoded['coordinates']
        timestamp = decoded['timestamp_ms']
        tweet = decoded['text']
        tweet = tweet.lower()
        # www.* or https?://* to URL
        tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))','URL',tweet)
        #@username to AT_USER
        tweet = re.sub('@[^\s]+','AT_USER',tweet)
        #Remove additional white spaces
        tweet = re.sub('[\s]+', ' ', tweet)
        #Replace #word with word
        tweet = re.sub(r'#([^\s]+)', r'\1', tweet)
        #trim
        tweet = tweet.strip('\'"') 
        source = decoded['source']
        isretweeted = False 
        if 'retweeted_status' in decoded:
            if decoded['retweeted_status'] is not 'null':
                isretweeted = True
        lang = decoded['lang']
        lat = 'null'
        lon = 'null'
        polarity = 'null'
        try:
            dftweets.loc[id] = [userId,geo,coordinates,timestamp,tweet,source,isretweeted,lang,lat,lon, polarity]
        except Exception as e:
            print e
    except Exception as a:
        print a.args,':','error processing tweet'
# Out:
# {"created_at":"Sun Nov 20 15:11:52 +0000 2016","id":800355989086203905,"id_str":"800355989086203905","text":"RT @elmundoes: El edificio (no okupado) que posee en Barcelona la concejal de Carmena que defiende a los okupas en Madrid\u2026 ","source":"\u003ca href=\"http:\/\/twitter.com\" rel=\"nofollow\"\u003eTwitter Web Client\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":799032032017993733,"id_str":"799032032017993733","name":"GRUPO METRO MENDOZA","screen_name":"GRUPO_METRO_MZA","location":"Mendoza, Argentina","url":"http:\/\/www.grupometromza.com","description":"GRUPO METRO MENDOZA.\nPRODUCTORA DE SE\u00d1AL Y CONTENIDOS PARA RADIO Y TV . AGENCIA DE PUBLICIDAD Y PROMOCIONES PUBLICITARIAS.\nRADIOS AM Y FM . DIARIOS DIGITALES.","protected":false,"verified":false,"followers_count":24,"friends_count":353,"listed_count":5,"favourites_count":3,"statuses_count":1132,"created_at":"Wed Nov 16 23:30:56 +0000 2016","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":"es","contributors_enabled":false,"is_translator":false,"profile_background_color":"000000","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_tile":false,"profile_link_color":"981CEB","profile_sidebar_border_color":"000000","profile_sidebar_fill_color":"000000","profile_text_color":"000000","profile_use_background_image":false,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/799035690814242817\/vJ2LhVeh_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/799035690814242817\/vJ2LhVeh_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/799032032017993733\/1479339858","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Sun Nov 20 15:11:04 +0000 2016","id":800355789588283392,"id_str":"800355789588283392","text":"El edificio (no okupado) que posee en Barcelona la concejal de Carmena que defiende a los okupas en Madrid\u2026 https:\/\/t.co\/0wta0r2Da5","display_text_range":[0,140],"source":"\u003ca href=\"http:\/\/www.socialflow.com\" rel=\"nofollow\"\u003eSocialFlow\u003c\/a\u003e","truncated":true,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":14436030,"id_str":"14436030","name":"EL MUNDO","screen_name":"elmundoes","location":null,"url":"http:\/\/www.elmundo.es\/","description":"- Cuenta oficial del diario EL MUNDO - \ud83d\udcf7 Sara, ni\u00f1a y ap\u00e1trida en un campo de  refugiados de Debaga (Irak) - Zohra Bensemra\/Reuters.","protected":false,"verified":true,"followers_count":2621501,"friends_count":1299,"listed_count":27129,"favourites_count":2007,"statuses_count":129927,"created_at":"Fri Apr 18 18:29:25 +0000 2008","utc_offset":3600,"time_zone":"Madrid","geo_enabled":true,"lang":"es","contributors_enabled":false,"is_translator":false,"profile_background_color":"FFFFFF","profile_background_image_url":"http:\/\/pbs.twimg.com\/profile_background_images\/378800000115939016\/779ad75e2323ba50d1bfdc6142005b56.png","profile_background_image_url_https":"https:\/\/pbs.twimg.com\/profile_background_images\/378800000115939016\/779ad75e2323ba50d1bfdc6142005b56.png","profile_background_tile":false,"profile_link_color":"0084B4","profile_sidebar_border_color":"FFFFFF","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/796694803723522052\/7JwuAJ8D_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/ ...

# %%
dftweets.head(5)
# Out:
#                                 userId   geo coordinates      timestamp  \
# 800355989086203905  799032032017993733  None        None  1479654712350
# 800355991057530880          2326149346  None        None  1479654712820
# 800355991892037632           752958026  None        None  1479654713019
# 800355992147881988          2382475370  None        None  1479654713080
# 800355997126512640          2405391592  None        None  1479654714267
#
#                                                                 tweet  \
# 800355989086203905  rt AT_USER el edificio (no okupado) que posee ...
# 800355991057530880  rt AT_USER lo de alsasua no es terrorismo. esp...
# 800355991892037632  rt AT_USER el 'cara al sol' cierra la misa en ...
# 800355992147881988  ... podemos entrenar ahora si... quieres. no t...
# 800355997126512640                        rt AT_USER 😂😂😂😂😂👇 URL
#
#                                                                source  \
# 800355989086203905  <a href="http://twitter.com" rel="nofollow">Tw...
# 800355991057530880  <a href="http://twitter.com/download/iphone" r...
# 800355991892037632  <a href="http://twitter.com/download/android" ...
# 800355992147881988  <a href="http://twitter.com/download/android" ...
# 800355997126512640  <a href="http://twitter.com/download/android" ...
#
#                    isretweeted lang   lat   lon polarity
# 800355989086203905        True   es  null  null     null
# 800355991057530880        True   es  null  null     null
# 800355991892037632        True   es  null  null     null
# 800355992147881988       False   es  null  null     null
# 800355997126512640        True  und  null  null     null

# %%
len(dftweets)
# Out:
# 7398

# %%
dfusers.head(5)
# Out:
#                                     name                        location  \
# 799032032017993733   GRUPO METRO MENDOZA              Mendoza, Argentina
# 2326149346                    Pepe López                            None
# 752958026                             XD               Barcelona, España
# 2382475370                     Rαι Blαĸe                      Estudiando
# 2405391592          angel jurado sánchez  Pedro Muñoz, Castilla-La Manch
#
#                                              url  followers lang  \
# 799032032017993733  http://www.grupometromza.com       24.0   es
# 2326149346                                  None      329.0   es
# 752958026                                   None       62.0   es
# 2382475370                                  None      112.0   es
# 2405391592                                  None      304.0   es
#
#                                                         profile_image  \
# 799032032017993733  http://pbs.twimg.com/profile_images/7990356908...
# 2326149346          http://pbs.twimg.com/profile_images/4310926238...
# 752958026           http://pbs.twimg.com/profile_images/7344675448...
# 2382475370          http://pbs.twimg.com/profile_images/7888527558...
# 2405391592          http://pbs.twimg.com/profile_images/7508086238...
#
#                    following
# 799032032017993733      None
# 2326149346              None
# 752958026               None
# 2382475370              None
# 2405391592              None

# %%
len(dfusers)
# Out:
# 5573

# %%
len(dftweets[dftweets['lang']=='es'])
# Out:
# 7317

# %%
dftweets.to_csv('tweets_df.csv', encoding='utf-8')

# %%
dfusers.to_csv('users_df.csv', encoding='utf-8')

# %% [markdown]
# ## Carga a partir de DataFrame ya tratado

# %%
dftweets = pd.read_csv('tweets_df.csv', encoding='utf-8')

# %%
dfusers= pd.read_csv('users_df.csv', encoding='utf-8')

# %% [markdown]
# Cargamos el corpus tagueado

# %%
from lxml import objectify
xml = objectify.parse(open('general-tweets-train-tagged.xml'))
#sample tweet object
general_tweets_corpus_train = pd.DataFrame(columns=('content', 'polarity', 'agreement'))
root = xml.getroot()
tweets = root.getchildren()
for i in range(0,len(tweets)):
    tweet = tweets[i]
    row = dict(zip(['content', 'polarity', 'agreement'], [tweet.content.text, tweet.sentiments.polarity.value.text, tweet.sentiments.polarity.type.text]))
    row_s = pd.Series(row)
    row_s.name = i
    general_tweets_corpus_train = general_tweets_corpus_train.append(row_s)
general_tweets_corpus_train.to_csv('general-tweets-train-tagged.csv', index=False, encoding='utf-8')

# %%
general_tweets_corpus_train.head(5)
# Out:
#                                              content polarity     agreement
# 0        Salgo de #VeoTV , que día más largoooooo...     NONE     AGREEMENT
# 1  @PauladeLasHeras No te libraras de ayudar me/n...      NEU  DISAGREEMENT
# 2                          @marodriguezb Gracias MAR        P     AGREEMENT
# 3  Off pensando en el regalito Sinde, la que se v...       N+     AGREEMENT
# 4  Conozco a alguien q es adicto al drama! Ja ja ...       P+     AGREEMENT

# %%
tweets_corpus = general_tweets_corpus_train.copy()
tweets_corpus = tweets_corpus.query('agreement != "DISAGREEMENT" and polarity != "NONE"')
tweets_corpus.head(5)
# Out:
#                                              content polarity  agreement
# 2                          @marodriguezb Gracias MAR        P  AGREEMENT
# 3  Off pensando en el regalito Sinde, la que se v...       N+  AGREEMENT
# 4  Conozco a alguien q es adicto al drama! Ja ja ...       P+  AGREEMENT
# 6  Toca @crackoviadeTV3 . Grabación dl especial N...       P+  AGREEMENT
# 8  Buen día todos! Lo primero mandar un abrazo gr...       P+  AGREEMENT

# %%
#remove links
tweets_corpus = tweets_corpus[-tweets_corpus.content.str.contains('^http.*$')]

tweets_corpus.shape
# Out:
# (4995, 3)

# %% [markdown]
# ### Tokenizamos y hacemos Steming

# %% [markdown]
# ### Evaluacion del modelo

# %%
general_tweets_corpus_train.ix[general_tweets_corpus_train['polarity']=='P+', 'polarity'] = 'P'
general_tweets_corpus_train.ix[general_tweets_corpus_train['polarity']=='N+', 'polarity'] = 'N'
general_tweets_corpus_train.ix[general_tweets_corpus_train['polarity']=='NONE', 'polarity'] = 'NEU'
#general_tweets_corpus_train.head(5)
general_tweets_corpus_train[general_tweets_corpus_train['polarity']=='N'][0:2]
# Out:
#                                               content polarity  agreement  \
# 3   Off pensando en el regalito Sinde, la que se v...        N  AGREEMENT
# 12                  #programascambiados caca d ajuste        N  AGREEMENT
#
#                                                 words
# 3   [off, pensando, en, el, regalito, sinde,, la, ...
# 12             [#programascambiados, caca, d, ajuste]

# %%
subcorpus = []
general_tweets_corpus_train['words'] = general_tweets_corpus_train['content'].str.lower().str.split(' ')
general_tweets_corpus_train.head(5)
subcorpus = general_tweets_corpus_train[['words','polarity']]
tweets = [tuple(x) for x in subcorpus[0:1500].values]
# Out:
# [([u'salgo',
#    u'de',
#    u'#veotv',
#    u',',
#    u'que',
#    u'd\xeda',
#    u'm\xe1s',
#    u'largoooooo...'],
#   'NEU'),
#  (['@pauladelasheras',
#    'no',
#    'te',
#    'libraras',
#    'de',
#    'ayudar',
#    'me/nos.',
#    'besos',
#    'y',
#    'gracias'],
#   'NEU'),
#  (['@marodriguezb', 'gracias', 'mar'], 'P'),
#  (['off',
#    'pensando',
#    'en',
#    'el',
#    'regalito',
#    'sinde,',
#    'la',
#    'que',
#    'se',
#    'va',
#    'de',
#    'la',
#    'sgae',
#    'cuando',
#    'se',
#    'van',
#    'sus',
#    'corruptos.',
#    'intento',
#    'no',
#    'sacar',
#    'conclusiones',
#    '(lo',
#    'intento)'],
#   'N'),
#  (['conozco',
#    'a',
#    'alguien',
#    'q',
#    'es',
#    'adicto',
#    'al',
#    'drama!',
#    'ja',
#    'ja',
#    'ja',
#    'te',
#    'suena',
#    'd',
#    'algo!'],
#   'P'),
#  ([u'rt',
#    u'@fabhddzc:',
#    u'si',
#    u'amas',
#    u'a',
#    u'alguien,',
#    u'd\xe9jalo',
#    u'libre.',
#    u'si',
#    u'grita',
#    u'ese',
#    u'hombre',
#    u'es',
#    u'm\xedo',
#    u'era',
#    u'@paurubio...'],
#   'NEU'),
#  ([u'toca',
#    u'@crackoviadetv3',
#    u'.',
#    u'grabaci\xf3n',
#    u'dl',
#    u'especial',
#    u'navide\xf1o...mari',
#    u'crismas!'],
#   'P'),
#  ([u'hoy',
#    u'asisitir\xe9',
#    u'en',
#    u'madrid',
#    u'a',
#    u'un',
#    u'seminario',
#    u'sobre',
#    u'la',
#    u'estrategia',
#    u'espa\xf1ola',
#    u'de',
#    u'seguridad',
#    u'organizado',
#    u'por',
#    u'faes.'],
#   'NEU'),
#  ([u'buen',
#    u'd\xeda',
#    u'todos!',
#    u'lo',
#    u'primero',
#    u'mandar',
#    u'un',
#    u'abrazo',
#    u'grande',
#    u'a',
#    u'miguel',
#    u'y',
#    u'a',
#    u'su',
#    u'familia',
#    u'@libertadmontes',
#    u'hoy',
#    u'podr\xeda',
#    u'ser',
#    u'un',
#    u'd\xeda',
#    u'para',
#    u'la',
#    u'grandeza',
#    u'humana.'],
#   'P'),
#  ([u'desde',
#    u'el',
#    u'esca\xf1o.',
#    u'todo',
#    u'listo',
#    u'para',
#    u'empezar',
#    u'#endiascomohoy',
#    u'en',
#    u'el',
#    u'congreso',
#    u'http://t.co/mu2yigcb'],
#   'P'),
#  ([u'bd\xedas.',
#    u'em',
#    u'no',
#    u'se',
#    u'ira',
#    u'de',
#    u'puente.',
#    u'si',
#    u'vosotros',
#    u'os',
#    u'vais',
#    u'no',
#    u'dejeis',
#    u'de',
#    u'llevar',
#    u'la',
#    u'tableta',
#    u'o',
#    u'el',
#    u'pc',
#    u'y',
#    u'desde',
#    u'luego',
#    u'orbyt.',
#    u'de',
#    u'momento',
#    u'no',
#    u'digo',
#    u'm\xe1s.'],
#   'P'),
#  ([u'un',
#    u'sistema',
#    u'econ\xf3mico',
#    u'q',
#    u'recorta',
#    u'dinero',
#    u'para',
#    u'prestaciones',
#    u'sociales',
#    u'y',
#    u'refuerza',
#    u'con',
#    u'bill\xf3n',
#    u'y',
#    u'medio',
#    u'd',
#    u'euros',
#    u'a',
#    u'los',
#    u'bancos,',
#    u'no',
#    u'necesita',
#    u'repensarse?'],
#   'P'),
#  (['#programascambiados', 'caca', 'd', 'ajuste'], 'N'),
#  (['buen', 'viernes'], 'P'),
#  ([u'\u201c@adri_22_22:',
#    u'#programascambiados',
#    u'es',
#    u'tt',
#    u'gracias',
#    u'a',
#    u'@carlos_latre\u201d',
#    u'gracias',
#    u'por',
#    u'el',
#    u'buen',
#    u'rato',
#    u'amigos!!;)'],
#   'P'),
#  ([u'noooooos',
#    u'd\xedas!',
#    u'me',
#    u'he',
#    u'dormidoooooo',
#    u'ya',
#    u'estoy',
#    u'en',
#    u'el',
#    u'taxi',
#    u'camino',
#    u'al',
#    u'aeropuerto,',
#    u'en',
#    u'7',
#    u'minutos',
#    u'vestida',
#    u'y',
#    u'maleta',
#    u'hecha.',
#    u'que',
#    u'habr\xe9',
#    u'metido',
#    u'dios',
#    u'mio!?'],
#   'NEU'),
#  ([u'vamos',
#    u'a',
#    u'por',
#    u'el',
#    u'viernes',
#    u'(@',
#    u'ayuntamiento',
#    u'de',
#    u'm\xe1laga)',
#    u'[pic]:',
#    u'http://t.co/lzdvsocu'],
#   'NEU'),
#  ([u'la',
#    u'universidad',
#    u'conf\xeda',
#    u'en',
#    u'de',
#    u'la',
#    u'calle',
#    u'para',
#    u'encarar',
#    u'sus',
#    u'retos',
#    u'm\xe1s',
#    u'ambiciosos',
#    u'http://t.co/7dzppija'],
#   'P'),
#  ([u'\xbfme',
#    u'ayud\xe1is',
#    u'a',
#    u'que',
#    u'#indultoneiro',
#    u'sea',
#    u'tt?',
#    u'por',
#    u'si',
#    u'zapatero',
#    u'quiere',
#    u'alguna',
#    u'sugerencia',
#    u'para',
#    u'el',
#    u'\xfaltimo',
#    u'consejo',
#    u'de',
#    u'ministros',
#    u'http://t.co/qao9uvsg'],
#   'P'),
#  ([u'abcdesevilla.es:',
#    u'recio',
#    u'no',
#    u'tiene',
#    u'\xabindicios',
#    u'potentes\xbb',
#    u'para',
#    u'denunciar',
#    u'a',
#    u'los',
#    u'responsables',
#    u'de',
#    u'los',
#    u'ere',
#    u'http://t.co/wldss1yq'],
#   'N'),
#  ([u'abcdesevilla.es:',
#    u'cuatro',
#    u'altos',
#    u'cargos',
#    u'de',
#    u'empleo,',
#    u'denunciados',
#    u'por',
#    u'retirar',
#    u'la',
#    u'prejubilaci\xf3n',
#    u'a',
#    u'extrabajadores',
#    u'http://t.co/lwhxzbub'],
#   'N'),
#  ([u'la',
#    u'marcha',
#    u'atr\xe1s',
#    u'del',
#    u'pp',
#    u'en',
#    u'posponer',
#    u'devoluci\xf3n',
#    u'ccaa',
#    u'es',
#    u'un',
#    u'resbal\xf3n.',
#    u'deber\xeda',
#    u'asumir',
#    u'fallo',
#    u'y',
#    u'no',
#    u'mentir',
#    u'diciendo',
#    u'que',
#    u'no',
#    u'conoce',
#    u'estado',
#    u'cuentas'],
#   'N'),
#  (['viernes',
#    'negro:',
#    'aumenta',
#    'el',
#    'paro',
#    'en',
#    'noviembre',
#    'y',
#    'disminuyen',
#    'los',
#    'afiliados',
#    'a',
#    'la',
#    'seguridad',
#    'social;',
#    'esta',
#    'es',
#    'la',
#    'triste',
#    '#herenciapsoe'],
#   'N'),
#  ([u'accidente',
#    u'en',
#    u'bus-vao',
#    u'a-6',
#    u'km.',
#    u'12.',
#    u'motorista',
#    u'de',
#    u'30',
#    u'a\xf1os',
#    u'herido',
#    u'menos',
#    u'grave.',
#    u'@samur_pc',
#    u'traslada',
#    u'a',
#    u'hospital',
#    u'doce',
#    u'de',
#    u'octubre',
#    u'v\xeda',
#    u'@emergenciasmad'],
#   'N'),
#  ([u'"la',
#    u'verdadera',
#    u'seriedad',
#    u'es',
#    u'c\xf3mica".',
#    u'niall',
#    u'binns',
#    u'retrata',
#    u'a',
#    u'nicanor',
#    u'parra,',
#    u'premio',
#    u'cervantes.',
#    u'http://t.co/axytq1by'],
#   'P'),
#  ([u'#ff',
#    u'a',
#    u'ti,',
#    u'que',
#    u'deseas',
#    u'desesperadamente',
#    u'hacerme',
#    u'#ff,',
#    u'pero',
#    u'no',
#    u'lo',
#    u'haces',
#    u'por',
#    u'el',
#    u'qu\xe9',
#    u'dir\xe1n.'],
#   'N'),
#  ([u'mis',
#    u'#ff',
#    u'xa',
#    u'@merpastor',
#    u'x',
#    u'volver',
#    u'a',
#    u'sonre\xedr,',
#    u'a',
#    u'@gfvara',
#    u'x',
#    u'ser',
#    u'tan',
#    u'autentico,',
#    u'a',
#    u'@24horas_rne',
#    u'x',
#    u'su',
#    u'subid\xf2n',
#    u'y',
#    u'a',
#    u'@carmendelriego',
#    u'x',
#    u'su',
#    u'victoria'],
#   'P'),
#  (['agradezco',
#    'a',
#    'trabajadores',
#    'y',
#    'sindicatos',
#    'la',
#    'desconvocatoria',
#    'de',
#    'la',
#    'huelga',
#    'en',
#    'el',
#    'aeropuerto.',
#    'me',
#    'he',
#    'comprometido',
#    'a',
#    'mediar',
#    '#sevillahoy'],
#   'P'),
#  (['#ff',
#    'a',
#    '@rdscubrenavidad',
#    'por',
#    'ser',
#    'una',
#    'gran',
#    'iniciativa',
#    'que',
#    'en',
#    'estos',
#    'momentos',
#    'se',
#    'necesita.',
#    'hay',
#    'que',
#    'recordar',
#    'lo',
#    'importante',
#    'y',
#    'verdadero!'],
#   'P'),
#  ([u'"hasta',
#    u'ahora,',
#    u'los',
#    u'fil\xf3sofos',
#    u'han',
#    u'tratado',
#    u'de',
#    u'comprender',
#    u'el',
#    u'mundo;',
#    u'de',
#    u'lo',
#    u'que',
#    u'se',
#    u'trata,',
#    u'sin',
#    u'embargo,',
#    u'es',
#    u'de',
#    u'cambiarlo"'],
#   'NEU'),
#  ([u'open',
#    u'master',
#    u'class@javiersolana',
#    u'&pedro',
#    u'alonso',
#    u'on',
#    u'"global',
#    u'health',
#    u'challenges&global',
#    u'governance"@esadegeo@isglobalorg',
#    u'http://t.co/uzhgwbib\u2026',
#    u'.'],
#   'NEU'),
#  (['3.tercer',
#    'acto.acuerdo',
#    'bancos',
#    'centrales',
#    'para',
#    'dar',
#    'un',
#    'poco',
#    'de',
#    'tiempo.'],
#   'P'),
#  (['soy',
#    'consciente',
#    'de',
#    'que',
#    'estamos',
#    'pidiendo',
#    'un',
#    'gran',
#    'esfuerzo',
#    'a',
#    'las',
#    'familias',
#    'castellanomanchegas.'],
#   'N'),
#  ([u'eguiguren:',
#    u'el',
#    u'gobierno',
#    u'ha',
#    u'negociado',
#    u'con',
#    u'eta.',
#    u'llevamos',
#    u'dos',
#    u'a\xf1os',
#    u'denunci\xe1ndolo.',
#    u'http://t.co/gsdgb8nv'],
#   'N'),
#  (['no', 'se', 'ha', 'aprobado', 'la', 'ley', 'sinde'], 'N'),
#  (['se',
#    'puede',
#    'entender',
#    'que',
#    'la',
#    'misma',
#    'solidaridad',
#    'que',
#    'pide',
#    'el',
#    'pv',
#    'en',
#    'sanidad',
#    'la',
#    'tenga',
#    'el',
#    'pv',
#    'en',
#    'cuanto',
#    'a',
#    'fiscalidad.',
#    'la',
#    'rioja',
#    'pierde',
#    'siempre.'],
#   'NEU'),
#  ([u'\xa1\xa1mucho',
#    u'\xe1nimo',
#    u'hoy',
#    u'para',
#    u'"la',
#    u'armada"!!',
#    u'\xa1\xa1espero',
#    u'que',
#    u'pod\xe1is',
#    u'brindarnos',
#    u'la',
#    u'quinta',
#    u'copa',
#    u'davis!!',
#    u'\xa1\xa1\xa1mucha',
#    u'suerte!!!',
#    u'http://t.co/whsk2vv6'],
#   'P'),
#  ([u'blanco,',
#    u'ministro',
#    u'portavoz',
#    u'en',
#    u'funciones,',
#    u'desacredita',
#    u'de',
#    u'forma',
#    u'rotunda',
#    u'al',
#    u'pte',
#    u'del',
#    u'pse,',
#    u'jes\xfas',
#    u'eguiguren:"no',
#    u'sabe',
#    u'de',
#    u'lo',
#    u'que',
#    u'habla,',
#    u'no',
#    u'es',
#    u'cierto"'],
#   'N'),
#  ([u'desgraciadamente',
#    u'el',
#    u'paro',
#    u'en',
#    u'espa\xf1a',
#    u'sigue',
#    u'creciendo.',
#    u'madrid',
#    u'va',
#    u'mejorando',
#    u'con',
#    u'8.000',
#    u'cotizantes',
#    u'm\xe1s',
#    u'y',
#    u'4.000',
#    u'desempleados',
#    u'menos.'],
#   'N'),
#  (['en',
#    'el',
#    'blog:',
#    'defender',
#    'la',
#    'solidaridad',
#    'http://t.co/8sddyc8j'],
#   'NEU'),
#  (['#ff',
#    'de',
#    'vuelta',
#    ';-))',
#    '@pepemaras',
#    '@popularescyl',
#    '@anamariavielba',
#    '@marmarev',
#    '@ajimnezvelayos',
#    '@jmoreta23',
#    '@dllanosg',
#    '@c_floriano'],
#   'P'),
#  ([u'qu\xe9',
#    u'graciosos',
#    u'los',
#    u'"laicos"',
#    u'socialistas.',
#    u'le',
#    u'meten',
#    u'el',
#    u'amazing',
#    u'grace',
#    u'a',
#    u'un',
#    u'anuncio',
#    u'de',
#    u'la',
#    u'dgt.',
#    u'si',
#    u'se',
#    u'descuidan',
#    u'le',
#    u'ponen',
#    u'el',
#    u'pange',
#    u'lingua!'],
#   'N'),
#  (['ya',
#    'he',
#    'presentado',
#    'la',
#    'credencial',
#    'de',
#    'diputado',
#    'en',
#    'el',
#    'congreso',
#    'en',
#    'plena',
#    'jornada',
#    'de',
#    'puertas',
#    'abiertas.',
#    '#psnpsoe'],
#   'NEU'),
#  ([u'el',
#    u'protocolo',
#    u'de',
#    u'iu',
#    u'supone',
#    u'aportar',
#    u'parte',
#    u'del',
#    u'salario,',
#    u'pero',
#    u'no',
#    u'renunciar',
#    u'al',
#    u'seguro',
#    u'de',
#    u'vida,',
#    u'accidente',
#    u'y',
#    u'a',
#    u'la',
#    u'prestaci\xf3n',
#    u'social',
#    u'complementaria'],
#   'NEU'),
#  (['el', 'post', 'de', 'hoy', 'en', 'mi', 'blog', 'http://t.co/nzhcgrxn'],
#   'NEU'),
#  (['me', 'encanta', 'ver', 'por', 'aqui', '', 'a', '@tudnie', ';-))'], 'P'),
#  ([u'si',
#    u'est\xe1n',
#    u'por',
#    u'valencia',
#    u'espa\xf1a',
#    u'les',
#    u'recomiendo',
#    u'esta',
#    u'exposici\xf3n',
#    u'!!',
#    u'http://t.co/hkjrpj9b'],
#   'P'),
#  ([u'la',
#    u'gran',
#    u'noche',
#    u'de',
#    u'los',
#    u'abanderados',
#    u'2.0',
#    u'-',
#    u'la',
#    u'opini\xf3n',
#    u'de',
#    u'm\xe1laga',
#    u'http://t.co/yyu7uxth'],
#   'NEU'),
#  ([u'\u201c@martacerame:',
#    u'@maria_rey',
#    u'amigaaaaa!!!!!\u201d',
#    u'holaaaa',
#    u'guapaaaa!'],
#   'P'),
#  ([u'el',
#    u'juez',
#    u'imputa',
#    u'a',
#    u'dos',
#    u'directivos',
#    u'de',
#    u'la',
#    u'ciudad',
#    u'de',
#    u'las',
#    u'artes',
#    u'y',
#    u'ciencias',
#    u'de',
#    u'valencia',
#    u'por',
#    u'el',
#    u'caso',
#    u'urdangar\xedn.',
#    u'parece',
#    u'que',
#    u'todos',
#    u'lo',
#    u'est\xe1n',
#    u'menos',
#    u'\xe9l'],
#   'N'),
#  (['firma',
#    'de',
#    'discos,',
#    'martes,',
#    '6',
#    'de',
#    'diciembre',
#    'en',
#    'el',
#    'cine',
#    'callao',
#    'a',
#    'las',
#    '18',
#    'horas',
#    'http://t.co/eljgcola'],
#   'NEU'),
#  (['el',
#    'desempleo',
#    'en',
#    'ee',
#    'uu',
#    'baja',
#    'a',
#    'los',
#    'niveles',
#    'de',
#    'marzo',
#    'de',
#    '2009',
#    'http://t.co/2rkkqqfg'],
#   'P'),
#  (['seguimos',
#    '(@',
#    'unidad',
#    'de',
#    'cuidados',
#    'paliativos',
#    'hospital',
#    'civil)',
#    '[pic]:',
#    'http://t.co/7bqeqfy1'],
#   'NEU'),
#  ([u'ya',
#    u'salio',
#    u'el',
#    u'sorteo',
#    u'de',
#    u'la',
#    u'eurocopa',
#    u'2012:',
#    u'espa\xf1a',
#    u'italia',
#    u'croacia',
#    u'e',
#    u'irlanda.',
#    u'a',
#    u'por',
#    u'ellos!!!!!'],
#   'NEU'),
#  ([u'granado',
#    u'reconoce',
#    u'que',
#    u'da',
#    u'los',
#    u'datos',
#    u'de',
#    u'paro',
#    u'"con',
#    u'objetividad"',
#    u'por',
#    u'estar',
#    u'en',
#    u'interinidad.',
#    u'\xbfy',
#    u'antes?',
#    u'@telediariointer',
#    u'20:30'],
#   'N'),
#  ([u'coraz\xf3n',
#    u'part\xedo:',
#    u'espa\xf1a',
#    u'e',
#    u'irlanda',
#    u'se',
#    u'enfrentar\xe1n',
#    u'en',
#    u'la',
#    u'eurocopa.'],
#   'N'),
#  ([u'transparencia',
#    u'internacional',
#    u'espa\xf1a',
#    u'ocupa',
#    u'n.',
#    u'31',
#    u'en',
#    u'ranking',
#    u'182',
#    u'pdetr\xe1s',
#    u'detr\xe1s',
#    u'de',
#    u'chipre,',
#    u'emiratos',
#    u'arabes,',
#    u'qatar...urge',
#    u'ley',
#    u'transparencia',
#    u'ya'],
#   'N'),
#  ([u'rt',
#    u'@fanclubmases:',
#    u'\xe9stas',
#    u'navidades',
#    u'regala',
#    u'solidaridad:#positivegeneration',
#    u'(cont)',
#    u'http://t.co/bksu1dzv'],
#   'P'),
#  ([u'\xbfcrisis',
#    u'de',
#    u'identidad?',
#    u'rt',
#    u'@loidalois',
#    u'@evaoregan',
#    u'\xa1\xa1\xa1t\xfa',
#    u'eres',
#    u'espa\xf1ola',
#    u'por',
#    u'encima',
#    u'de',
#    u'todo!!!'],
#   'N'),
#  (['el',
#    'teleton',
#    'hace',
#    'un',
#    'gran',
#    'servicio',
#    'social.',
#    'y',
#    'voy',
#    'a',
#    'apoyarlo',
#    'por',
#    'supuesto.',
#    'rt',
#    '@karlagglez:',
#    '(cont)',
#    'http://t.co/hs601n32'],
#   'P'),
#  ([u'cospedal',
#    u'deber\xeda',
#    u'pedir',
#    u'perd\xf3n',
#    u'por',
#    u'mentir',
#    u'y',
#    u'utilizar',
#    u'de',
#    u'forma',
#    u'demag\xf3gica',
#    u'la',
#    u'rebaja',
#    u'sueldo',
#    u'funcionarios...la',
#    u'que',
#    u'ahora',
#    u'aplica',
#    u'sin',
#    u'pudor'],
#   'N'),
#  ([u'as\xed',
#    u'me',
#    u'gusta,',
#    u'm\xf3nica',
#    u'\u201c@moniromaba:',
#    u'@pedroj_ramirez.',
#    u'a',
#    u'la',
#    u'orden',
#    u'jefe.',
#    u'cualquiera',
#    u'te',
#    u'va',
#    u'a',
#    u'discutir.',
#    u'ipad+orbyt+trabajo.\u201d'],
#   'P'),
#  (['eso',
#    'es',
#    'amigos.',
#    'rt',
#    '@hombressanzeros:',
#    '@alejandrosanz',
#    '#navidadsanzerasolidaria',
#    'todos',
#    'a',
#    'comprar',
#    '(cont)',
#    'http://t.co/y4ouji31'],
#   'NEU'),
#  ([u'hace',
#    u'cinco',
#    u'meses',
#    u'el',
#    u'pp',
#    u'me',
#    u'comunic\xf3',
#    u'por',
#    u'escrito',
#    u'que',
#    u'su',
#    u'interlocutor',
#    u'preferente',
#    u'era',
#    u'iu.',
#    u'ello',
#    u'le',
#    u'permiti\xf3',
#    u'gobernar.',
#    u'ahora',
#    u'pide',
#    u'consensos.'],
#   'P'),
#  ([u'bienvenidos',
#    u'a',
#    u'la',
#    u'brigada',
#    u'anti-vara,',
#    u'pero',
#    u'esta',
#    u'regi\xf3n',
#    u'tiene',
#    u'un',
#    u'problema',
#    u'm\xe1s.',
#    u'iu',
#    u'deja',
#    u'tirado',
#    u'a',
#    u'monago',
#    u'5',
#    u'meses',
#    u'despu\xe9s',
#    u'de',
#    u'su',
#    u'nombramiento.'],
#   'N'),
#  ([u'@gfvara',
#    u'la',
#    u'ley',
#    u'del',
#    u'embudo...caracter\xedstica',
#    u'de',
#    u'la',
#    u'derecha',
#    u'espa\xf1ola.',
#    u'animo'],
#   'N'),
#  ([u'eso',
#    u'no',
#    u'es',
#    u'cierto,',
#    u'nos',
#    u'llevamos',
#    u'de',
#    u'maravilla.',
#    u'rt',
#    u'@deyra_love_btr:',
#    u'@alejandrosanz',
#    u'',
#    u'\xac\xac',
#    u'por',
#    u'qe!!!',
#    u'(cont)',
#    u'http://t.co/7dyf7sus'],
#   'P'),
#  ([u'espa\xf1a',
#    u'se',
#    u'pone',
#    u'a',
#    u'1',
#    u'punto',
#    u'de',
#    u'ganar',
#    u'su',
#    u'quinta',
#    u'davis.sevilla,',
#    u'd',
#    u'nuevo',
#    u'talism\xe1n.ma\xf1ana,22h',
#    u'@giraldatv.es',
#    u'http://t.co/ns8tozqr'],
#   'P'),
#  ([u'bueno:',
#    u'espa\xf1a',
#    u'a',
#    u'un',
#    u'punto',
#    u'de',
#    u'ganar',
#    u'la',
#    u'5\xaa',
#    u'copa',
#    u'davis.',
#    u'felicidades',
#    u'al',
#    u'equipo!!!'],
#   'P'),
#  ([u'durante',
#    u'la',
#    u'campa\u0144a,',
#    u'cospedal',
#    u'dec\xeda',
#    u'lo',
#    u'que',
#    u'o\xeda',
#    u'en',
#    u'casa,',
#    u'ahora',
#    u'ya',
#    u'hace',
#    u'lo',
#    u'que',
#    u'oye',
#    u'en',
#    u'casa.',
#    u'http://t.co/caqpmxjm'],
#   'NEU'),
#  ([u'@ssantiagosegura',
#    u'@angyfdz',
#    u'@flofdez',
#    u'borrado',
#    u'est\xe1',
#    u'amiguetes!!',
#    u'un',
#    u'abruzo!!;)'],
#   'P'),
#  ([u'para',
#    u'nadaaaa...',
#    u'sabeis',
#    u'que',
#    u'no',
#    u'es',
#    u'asi.',
#    u'a',
#    u'veces',
#    u'no',
#    u'coincidimos,',
#    u'es',
#    u'todo.',
#    u'os',
#    u'mando',
#    u'mucho',
#    u'cari\xf1o,rt',
#    u'(cont)',
#    u'http://t.co/nwqigok5'],
#   'P'),
#  ([u'adi\xf3s',
#    u'al',
#    u'd\xeda',
#    u'en',
#    u'el',
#    u'q',
#    u'casi',
#    u'ha',
#    u'culminado',
#    u'el',
#    u'"destape"',
#    u'dl',
#    u'estado',
#    u'de',
#    u'bienestar?',
#    u'q',
#    u'nos',
#    u'va',
#    u'a',
#    u'quedar',
#    u'despu\xe9s',
#    u'd',
#    u'q',
#    u'se',
#    u'lo',
#    u'gastasen',
#    u'casi',
#    u'todo'],
#   'N'),
#  (['auan,',
#    'apeich,',
#    'agromenauer...lucas',
#    'grijander',
#    'y',
#    'su',
#    'progenitor...',
#    'http://t.co/q957cptb'],
#   'NEU'),
#  ([u'"la',
#    u'risa',
#    u'ilumina',
#    u'las',
#    u'almas',
#    u'que',
#    u'est\xe1n',
#    u'ba\xf1adas',
#    u'de',
#    u'tristeza,',
#    u'la',
#    u'sonrisa',
#    u'es',
#    u'la',
#    u'tibia',
#    u'caricia',
#    u'para',
#    u'la',
#    u'helada',
#    u'soledad"w.h.',
#    u'patrick'],
#   'P'),
#  ([u'detener',
#    u'la',
#    u'carrera',
#    u'nuclear',
#    u'de',
#    u'ir\xe1n',
#    u'deber\xeda',
#    u'ser',
#    u'una',
#    u'prioridad',
#    u'estrat\xe9gica',
#    u'm\xe1xima',
#    u'para',
#    u'occidente.'],
#   'N'),
#  ([u'a',
#    u'ver',
#    u'si',
#    u'lo',
#    u'entiendo:',
#    u'como',
#    u'banco',
#    u'central',
#    u'europeo',
#    u'no',
#    u'puede',
#    u'prestar',
#    u'a',
#    u'los',
#    u'gobiernos,',
#    u'prestar\xe1',
#    u'al',
#    u'fmi',
#    u'para',
#    u'q',
#    u'este,',
#    u'q',
#    u'si',
#    u'puede,lo',
#    u'haga.',
#    u'europa!'],
#   'P'),
#  ([u'altos',
#    u'cargos',
#    u'recelan',
#    u'del',
#    u'exhaustivo',
#    u'traspaso',
#    u'de',
#    u'poderes.',
#    u'aseguran',
#    u'que',
#    u'se',
#    u'ha',
#    u'convertido',
#    u'en',
#    u'fiscalizaci\xf3n',
#    u'.',
#    u'http://t.co/zto5m1tw'],
#   'N'),
#  (['buenos',
#    'dias,',
#    'que',
#    'buenos',
#    'eran/siguen',
#    'siendo',
#    'talking',
#    'heads...'],
#   'P'),
#  (['@ssantiagosegura',
#    'jijijiji',
#    'y',
#    'el',
#    'q',
#    'se',
#    'sibe',
#    'a',
#    'la',
#    'mesa',
#    'dl',
#    'jurado',
#    'es',
#    'el',
#    'verdadero',
#    'manolo',
#    'escobar!!;))))',
#    'haciendo',
#    'd',
#    'lady',
#    'marmalade!!!;))',
#    'jojijii'],
#   'P'),
#  (['#malaga',
#    'plaza',
#    'de',
#    'la',
#    'merced',
#    '',
#    '',
#    '@',
#    'plaza',
#    'de',
#    'la',
#    'merced',
#    'http://t.co/4xscgs1a'],
#   'NEU'),
#  ([u'los',
#    u'resultados',
#    u'preliminares',
#    u'en',
#    u'egipto',
#    u'auguran',
#    u'un',
#    u'profundo',
#    u'cambio',
#    u'con',
#    u'consecuencias',
#    u'regionales.falta',
#    u'voto',
#    u'rural',
#    u'q',
#    u'atenuar\xe1',
#    u'algo',
#    u'resultados.'],
#   'N'),
#  ([u'tranquilidad',
#    u'en',
#    u'las',
#    u'carreteras',
#    u'en',
#    u'el',
#    u'segundo',
#    u'd\xeda',
#    u'de',
#    u'puente',
#    u'de',
#    u'la',
#    u'constituci\xf3n',
#    u'-',
#    u'http://t.co/nrk2uftq'],
#   'P'),
#  (['gracias',
#    'por',
#    'la',
#    'hospitalidad!!!',
#    ';-)',
#    'rt',
#    '@isabelatortlini',
#    'bienvenido',
#    'don',
#    '@aarbeloa17',
#    'a',
#    'mi',
#    'humilde',
#    'morada',
#    ';)'],
#   'P'),
#  ([u'en',
#    u'el',
#    u'espol\xf3n,',
#    u'conmemorando',
#    u'el',
#    u'd\xeda',
#    u'de',
#    u'la',
#    u'discapacidad',
#    u'http://t.co/52olz4vl'],
#   'P'),
#  ([u'as\xed',
#    u'es',
#    u'el',
#    u'bel\xe9n',
#    u'del',
#    u'ayuntamiento',
#    u'http://t.co/s6ocgz6i'],
#   'NEU'),
#  ([u'los',
#    u'v\xe1ndalos',
#    u'le',
#    u'arrancan',
#    u'de',
#    u'nuevo',
#    u'el',
#    u'l\xe1piz',
#    u'a',
#    u'picasso',
#    u'http://t.co/lfynuarl'],
#   'N'),
#  ([u'esto',
#    u'es',
#    u'apoyar',
#    u'de',
#    u'verdad:',
#    u'la',
#    u'@diputacionmlg',
#    u'',
#    u'reducir\xe1',
#    u'impuestos',
#    u'a',
#    u'96',
#    u'pueblos',
#    u'http://t.co/vigtat1k'],
#   'P'),
#  ([u'un',
#    u'poco',
#    u'd',
#    u'agua',
#    u'fria',
#    u'despues',
#    u'dl',
#    u'entrenamiento',
#    u'esta',
#    u'ma\xf1ana.',
#    u'ahora',
#    u'a',
#    u'comer',
#    u'un',
#    u'poco',
#    u'd',
#    u'pasta',
#    u'y',
#    u'descanso',
#    u'total',
#    u'para',
#    u'esta',
#    u'noche',
#    u'q',
#    u'sera',
#    u'muy',
#    u'dificil!'],
#   'N'),
#  ([u'que',
#    u'corra',
#    u'el',
#    u'dewars!!!\u201c@dewarsspain:',
#    u'@jordievole',
#    u'@buenafuente',
#    u'@julia_otero',
#    u'@santi_millan',
#    u'gracias',
#    u'jordi\u201d'],
#   'P'),
#  (['detenida',
#    'la',
#    'jefa',
#    'de',
#    'una',
#    'prestigiosa',
#    'ong',
#    'rusa',
#    'de',
#    'control',
#    'electoral',
#    'http://t.co/lewfa7bo'],
#   'P'),
#  ([u'porque',
#    u'no',
#    u'tenemos',
#    u'programa.',
#    u'gracias',
#    u'@kimytwitera:',
#    u'@buenafuente',
#    u'buenafuente',
#    u'por',
#    u'q',
#    u'ya',
#    u'no',
#    u'dais',
#    u'tanta',
#    u'risa???\xbf\xbf\xbf\xbf???\u201d'],
#   'N'),
#  ([u'mi',
#    u'art\xedculo',
#    u'en',
#    u'esd:',
#    u'"la',
#    u'testarudez',
#    u'del',
#    u'consejero',
#    u'de',
#    u'salud',
#    u'riojano',
#    u'pone',
#    u'a',
#    u'sanz',
#    u'en',
#    u'la',
#    u'picota"',
#    u'',
#    u'http://t.co/m9poedn7'],
#   'N'),
#  ([u'noelia,',
#    u'noelia,',
#    u'noelia...\u201c@njimenez79:',
#    u'',
#    u'me',
#    u'parezco',
#    u'a',
#    u'@pedroj_ramirez',
#    u'en',
#    u'el',
#    u'manejo',
#    u'del',
#    u'ipad.',
#    u'a',
#    u'ver',
#    u'si',
#    u'empiezo',
#    u'a',
#    u'parecerme',
#    u'en',
#    u'lectores!\u201d'],
#   'NEU'),
#  ([u'la',
#    u'vida',
#    u'no',
#    u'se',
#    u'mide',
#    u'por',
#    u'las',
#    u'veces',
#    u'que',
#    u'respiramos,',
#    u'sino',
#    u'por',
#    u'aquellos',
#    u'momentos',
#    u'que',
#    u'nos',
#    u'dejan',
#    u'sin',
#    u'aliento',
#    u'(v\xeda',
#    u'@ifilosofia)'],
#   'NEU'),
#  ([u'sinceramente,',
#    u'estoy',
#    u'observando',
#    u'la',
#    u'zona',
#    u'de',
#    u'"',
#    u'recreo"',
#    u'psiqui\xe1trica',
#    u'del',
#    u'h.civil',
#    u'y',
#    u'es',
#    u'pat\xe9tico',
#    u'lo',
#    u'que',
#    u'veo',
#    u'http://t.co/ve8bhpjs'],
#   'N'),
#  ([u'con',
#    u'fina,',
#    u'mi',
#    u'mujer,',
#    u'amigos',
#    u'y',
#    u'el',
#    u'reparto',
#    u'de',
#    u'"iceberg",',
#    u'nueva',
#    u'pel\xedcula',
#    u'de',
#    u'gabriel',
#    u'vel\xe1zquez.por',
#    u'gabri',
#    u'no',
#    u'pasan',
#    u'los',
#    u'a\xf1os.',
#    u'http://t.co/n2chjhtr'],
#   'P'),
#  ([u'.',
#    u'@diario_sur',
#    u'as\xed',
#    u'esta',
#    u'la',
#    u'zona',
#    u'de',
#    u'"recreo"',
#    u'psiqui\xe1trica',
#    u'en',
#    u'el',
#    u'hospital',
#    u'civil',
#    u'.',
#    u'pat\xe9tico',
#    u'.',
#    u'son',
#    u'personas',
#    u'http://t.co/qdcw1ama'],
#   'N'),
#  ([u'me',
#    u'reservo',
#    u'd\xf3nde',
#    u'y',
#    u'c\xf3mo',
#    u'deposito',
#    u'mis',
#    u'ahorros',
#    u'con',
#    u'mi',
#    u'familia.',
#    u's\xf3lo',
#    u'estoy',
#    u'obligado',
#    u'a',
#    u'la',
#    u'trasparencia',
#    u'p\xfablica',
#    u'aunque',
#    u'veo',
#    u'que',
#    u'hay',
#    u'mucho',
#    u'experto.'],
#   'N'),
#  (['nada',
#    'como',
#    'unos',
#    'rollitos',
#    'de',
#    'vez',
#    'en',
#    'cuando',
#    'http://t.co/5hjjprcz'],
#   'NEU'),
#  ([u'bien',
#    u'que',
#    u'lo',
#    u'siento',
#    u'si',
#    u'es',
#    u'as\xed.la',
#    u'uedila',
#    u'la',
#    u'bienvenida',
#    u'ayer.esperemos',
#    u'que',
#    u'aun',
#    u'salga',
#    u'adelante.'],
#   'N'),
#  ([u'rt@franhervias:upyd',
#    u'pacta',
#    u'con',
#    u'cascos',
#    u'para',
#    u'tener',
#    u'grupo.a',
#    u'pesar',
#    u'd',
#    u'que',
#    u'en',
#    u'2008',
#    u'dec\xedan',
#    u'que',
#    u'no',
#    u'era',
#    u'l\xedcito',
#    u'este',
#    u'tipo',
#    u'd',
#    u'pactos',
#    u'http://t.co/fg5cvwm9'],
#   'NEU'),
#  ([u'bueno,',
#    u'a',
#    u'ver',
#    u'qu\xe9',
#    u'hace',
#    u'el',
#    u'madrid.',
#    u'lo',
#    u'comentamos',
#    u'dentro',
#    u'de',
#    u'un',
#    u'rato',
#    u'con',
#    u'edu',
#    u'en',
#    u'radio',
#    u'marca.'],
#   'NEU'),
#  ([u'se\xf1ora',
#    u'',
#    u'@mjmonteroc',
#    u'mire',
#    u'usted',
#    u'el',
#    u'estado',
#    u'de',
#    u'la',
#    u'zona',
#    u'de',
#    u'"',
#    u'recreo"',
#    u'de',
#    u'psiquiatr\xeda',
#    u'del',
#    u'hospital',
#    u'civil',
#    u'de',
#    u'#malaga',
#    u'http://t.co/uaaabf17'],
#   'NEU'),
#  (['gracias', 'amigos!!!', 'ya', 'somos', '200.000!!!;)'], 'P'),
#  ([u'ey',
#    u'@ivangeba',
#    u'que',
#    u'si',
#    u'esta',
#    u'aqu\xed',
#    u'la',
#    u'consejera',
#    u'de',
#    u'salud',
#    u'@mjmonteroc'],
#   'NEU'),
#  (['@carlos_latre',
#    'twitcam,',
#    'twitcam,',
#    'twitcam,',
#    'twitcam,',
#    'twitcam,',
#    'twitcam',
#    '!!!'],
#   'NEU'),
#  ([u'ojala',
#    u'en',
#    u'espa\xf1a',
#    u'fuera',
#    u'igual',
#    u'rt',
#    u'@cdperiodismo:',
#    u'en',
#    u'brasil',
#    u'se',
#    u'necesitar\xe1',
#    u'diploma',
#    u'para',
#    u'ejercer',
#    u'el',
#    u'periodismo',
#    u'http://t.co/sroi6dhx'],
#   'NEU'),
#  ([u'preciosa',
#    u'de',
#    u'verdad',
#    u'-',
#    u'perd\xf3name',
#    u'by',
#    u'pablo',
#    u'albor\xe1n,',
#    u'from',
#    u'#soundhound',
#    u'http://t.co/u0cabr3x'],
#   'P'),
#  ([u'ataque',
#    u'de',
#    u'inyecci\xf3n',
#    u'sql',
#    u'masivo',
#    u'http://t.co/q4uspkrl'],
#   'N'),
#  (['descansando', '2', 'http://t.co/1legidgw'], 'NEU'),
#  ([u'mira',
#    u'@sblanco',
#    u'nuestro',
#    u'\xe1rbol',
#    u';-))',
#    u'http://t.co/gjbkxmpv'],
#   'P'),
#  ([u'je,je!!!',
#    u'eso',
#    u'es',
#    u'bueno',
#    u'@mkreyes80:',
#    u'@buenafuente',
#    u'me',
#    u'has',
#    u'hecho',
#    u'llorar...',
#    u'de',
#    u'risa!\u201d'],
#   'P'),
#  (['rt',
#    '@nosesiaporto:',
#    'vamos',
#    'chilenos',
#    '!',
#    'ultimo',
#    'esfuerzo!',
#    'al',
#    'banco!',
#    'queda',
#    'poco',
#    'y',
#    'lo',
#    'lograremos!!!',
#    'la',
#    'teleton',
#    'te',
#    'necesita!!!'],
#   'P'),
#  ([u'ya',
#    u'estamos.',
#    u'\xbfpor',
#    u'qu\xe9',
#    u'no',
#    u'me',
#    u'duermo?',
#    u'lo',
#    u'voy',
#    u'a',
#    u'intentar,',
#    u'no',
#    u'debe',
#    u'ser',
#    u'tan',
#    u'dif\xedcil.'],
#   'P'),
#  ([u'rt',
#    u'@betolash:',
#    u'a',
#    u'ver',
#    u'pau',
#    u'\xbfcu\xe1nto',
#    u'es',
#    u'4x4?',
#    u'un',
#    u'jeep',
#    u'todo',
#    u'terreno',
#    u'maestra',
#    u'#multiplicocomopaulinarubio',
#    u'ja',
#    u'ja',
#    u'ja',
#    u'muy',
#    u'bueno!'],
#   'P'),
#  ([u'por',
#    u'qu\xe9',
#    u'los',
#    u'medios',
#    u'de',
#    u'comunicaci\xf3n',
#    u'se',
#    u'han',
#    u'llenado',
#    u'de',
#    u'anuncios',
#    u'oficiales?',
#    u'no',
#    u'hab\xeda',
#    u'q',
#    u'recortar',
#    u'el',
#    u'gasto',
#    u'publico?',
#    u'quien',
#    u'lo',
#    u'denuncia?'],
#   'N'),
#  ([u'buenos',
#    u'dias',
#    u'y',
#    u'mil',
#    u'gracias',
#    u'rt',
#    u'@pvcmalaga:',
#    u'buen',
#    u'd\xeda',
#    u'@mariviromero,mi',
#    u'concejala',
#    u'favorita.'],
#   'P'),
#  ([u'.',
#    u'@javierarenas_pp',
#    u'',
#    u'critica',
#    u'que',
#    u'@pepegrinan',
#    u'pida',
#    u'a',
#    u'@marianorajoy',
#    u'una',
#    u'reuni\xf3n',
#    u'que',
#    u'niega',
#    u'a',
#    u'sus',
#    u'alcaldes',
#    u'',
#    u'http://t.co/5omab1us'],
#   'N'),
#  (['.',
#    '@marianorajoy',
#    ':',
#    '',
#    '"salir',
#    'adelante',
#    'no',
#    'es',
#    'tarea',
#    'de',
#    'un',
#    'gobierno',
#    'solo"',
#    '',
#    'http://t.co/mjsq4fz1'],
#   'NEU'),
#  ([u'krugman:',
#    u'la',
#    u'austeridad',
#    u'est\xe1',
#    u'matando',
#    u'al',
#    u'euro',
#    u'http://t.co/cbrl2rj8',
#    u'via',
#    u'@el_pais'],
#   'N'),
#  ([u'.@sgueina:',
#    u'"\xbfqui\xe9n',
#    u'es',
#    u'el',
#    u'tapado',
#    u'del',
#    u'psoe?',
#    u'la',
#    u'respuesta',
#    u'est\xe1',
#    u'en',
#    u'mi',
#    u'blog',
#    u'http://t.co/afkafvrl\u201d\xbfs\xf3lo',
#    u'ha',
#    u'le\xeddo',
#    u'dos',
#    u'libros?"',
#    u'era',
#    u'una',
#    u'met\xe1fora.'],
#   'N'),
#  ([u'.@rutenca',
#    u'.@sgueina',
#    u'"el',
#    u'tapado',
#    u'ha',
#    u'leido',
#    u'm\xe1s',
#    u'de',
#    u'2!',
#    u'es',
#    u'licenciado',
#    u'en',
#    u'historia',
#    u'contemporanea',
#    u'y',
#    u'master',
#    u'en',
#    u'integraci\xf3n',
#    u'europea..\u201dviva',
#    u'la',
#    u'iron\xeda'],
#   'NEU'),
#  ([';-))',
#    'rt',
#    '@cacmalaga:',
#    'http://t.co/afmbiyxk',
#    '@cacmalaga',
#    '#arte',
#    '#cultura',
#    '#pintura',
#    '#museo',
#    '#museums'],
#   'P'),
#  ([u'rajoy',
#    u'quiere',
#    u'que',
#    u'espa\xf1a',
#    u'vuelva',
#    u'a',
#    u'tener',
#    u'relevancia',
#    u'en',
#    u'europa',
#    u'http://t.co/rghplkbr'],
#   'P'),
#  ([u'pol\xedticos',
#    u'q',
#    u'no',
#    u'responden.',
#    u'"en',
#    u'ning\xfan',
#    u'pa\xeds',
#    u'dl',
#    u'mundo',
#    u'homologable',
#    u'al',
#    u'nstro',
#    u'se',
#    u'tolera',
#    u'semejante',
#    u'pr\xe1ctica"',
#    u'http://t.co/7hoil9hr',
#    u'via',
#    u'@antonlosada'],
#   'N'),
#  (['@evaoregan',
#    '@antonlosada',
#    'obviamente,',
#    'contar',
#    'que',
#    'son',
#    'declaraciones',
#    'q',
#    'no',
#    'ha',
#    'permitido',
#    'preguntas.'],
#   'N'),
#  ([u'no',
#    u'pod\xeda',
#    u'faltar,',
#    u'dominguito',
#    u'en',
#    u'mi',
#    u'tierra',
#    u'y',
#    u'final',
#    u'de',
#    u'la',
#    u'davis.',
#    u'con',
#    u'el',
#    u'cu\xf1ao',
#    u'(@carlos_muela',
#    u').',
#    u'http://t.co/l28aoidr'],
#   'P'),
#  (['palmas',
#    'por',
#    'sevillanas',
#    'para',
#    'animar',
#    'a',
#    'rafa!!',
#    '#sevillaciudadtalisman',
#    '#copadavis'],
#   'P'),
#  ([u'reci\xe9n',
#    u'llegada',
#    u'a',
#    u'madrid!!por',
#    u'fin',
#    u'en',
#    u'casitaaa',
#    u'pero',
#    u'que',
#    u'fr\xedo!!no',
#    u'me',
#    u'quiero',
#    u'ni',
#    u'imaginar',
#    u'como',
#    u'har\xe1',
#    u'en',
#    u'la',
#    u'sierra',
#    u'y',
#    u'mas',
#    u'cuando',
#    u'sea',
#    u'de',
#    u'noche....'],
#   'NEU'),
#  (['retazos', 'de', 'una', 'primera', 'dama', 'http://t.co/168s72nj'], 'NEU'),
#  ([u"'chico",
#    u'&',
#    u"rita',",
#    u'premio',
#    u'europeo',
#    u'a',
#    u'la',
#    u'mejor',
#    u'cinta',
#    u'de',
#    u'animaci\xf3n',
#    u'http://t.co/ff7giise'],
#   'P'),
#  ([u'vamos',
#    u'equipo!!',
#    u'vamos',
#    u'nadal!!',
#    u'toda',
#    u'espa\xf1a',
#    u'esta',
#    u'en',
#    u'tu',
#    u'mano!!',
#    u'eres',
#    u'el',
#    u'mejor',
#    u'y',
#    u'contigo',
#    u'todos',
#    u'vamos',
#    u'a',
#    u'ser',
#    u'campeones!!',
#    u'tambi\xe9n',
#    u'elorrio'],
#   'P'),
#  (['otro',
#    'passing',
#    'escalofriante',
#    'sobre',
#    'la',
#    'linea',
#    'pone',
#    'a',
#    'nadal',
#    '5',
#    'a',
#    '1',
#    'en',
#    'el',
#    'tercero.la',
#    'ensaladera,',
#    'mas',
#    'cerca.#vamosrafa',
#    '#copadavis',
#    'ole',
#    '@rafaelnadal!!'],
#   'P'),
#  ([u'buen',
#    u'art\xedculo',
#    u'de',
#    u'ld.',
#    u'hay',
#    u'que',
#    u'arrimar',
#    u'el',
#    u'hombro.',
#    u'la',
#    u'asociaci\xf3n',
#    u'de',
#    u'ayuda',
#    u'a',
#    u'las',
#    u'v\xedctimas',
#    u'del',
#    u'11-m,',
#    u'al',
#    u'borde',
#    u'del',
#    u'cierre',
#    u'http://t.co/ryyx6ksh'],
#   'NEU'),
#  ([u'dicen',
#    u'q',
#    u'esta',
#    u'el',
#    u'rey',
#    u'en',
#    u'la',
#    u'cartuja.',
#    u'hoy',
#    u'es',
#    u'el',
#    u'dia',
#    u'en',
#    u'q',
#    u'tve',
#    u'tendr\xeda',
#    u'q',
#    u'sacarle',
#    u'todo',
#    u'el',
#    u'rato,hacer',
#    u'patria.',
#    u'sera',
#    u'la',
#    u'imparcialidad...'],
#   'P'),
#  (['menudo',
#    'break',
#    'en',
#    'blanco',
#    'ha',
#    'logrado',
#    'delpotro.',
#    'vamos',
#    'a',
#    'sufrir',
#    'hasta',
#    'el',
#    'final.',
#    'los',
#    'hinchas',
#    'argentinos',
#    'descentran',
#    'a',
#    'rafa.'],
#   'NEU'),
#  ([u'\u201c@beagarciachv:',
#    u'@edurnity',
#    u'mi',
#    u'segundo',
#    u'apellido',
#    u'es',
#    u'camello!',
#    u'tendr\xe9',
#    u'algo',
#    u'que',
#    u'ver',
#    u'con',
#    u'los',
#    u'reyes',
#    u'magos???\u201dte',
#    u'doy',
#    u'mi',
#    u'carta',
#    u'y',
#    u'se',
#    u'la',
#    u'das??jajja',
#    u'bss!'],
#   'P'),
#  ([u'\u201c@marinitamf:',
#    u'@edurnity',
#    u'ojo,',
#    u'que',
#    u'yo',
#    u'me',
#    u'apellido',
#    u'"molas",',
#    u'tal',
#    u'cual!',
#    u'y',
#    u'no',
#    u'es',
#    u'broma.\u201den',
#    u'serio??',
#    u'como',
#    u'mola!!',
#    u'jajjaja'],
#   'P'),
#  (['viaje',
#    'a',
#    'las',
#    'embajadas',
#    'catalanas',
#    'del',
#    'derroche',
#    '-',
#    'abc.es',
#    'http://t.co/sd2lv37r',
#    'via',
#    '@abc_es'],
#   'N'),
#  ([u'este',
#    u'set',
#    u'lo',
#    u'est\xe1',
#    u'ganando',
#    u'el',
#    u'p\xfablico',
#    u'argentino.',
#    u'del',
#    u'potro',
#    u'hab\xeda',
#    u'tirado',
#    u'la',
#    u'toalla,',
#    u'comenzaron',
#    u'a',
#    u'cantar',
#    u'y',
#    u'van',
#    u'ganado.',
#    u'rafa',
#    u'puede!',
#    u'#vamosrafa'],
#   'P'),
#  ([u'\u201c@ryankuletz:',
#    u'creo',
#    u'que',
#    u'@edurnity',
#    u'se',
#    u'ha',
#    u'puesto',
#    u'a',
#    u'responder',
#    u'tweets',
#    u'sobre',
#    u'apellidos',
#    u'por',
#    u'el',
#    u'iphone.',
#    u'#cosasquenuncaentenderas',
#    u':)\u201djaajjajajja'],
#   'P'),
#  ([u'amonestado',
#    u'el',
#    u'p\xfablico',
#    u'argentino',
#    u'en',
#    u'la',
#    u'cartuja!!!'],
#   'N'),
#  ([u'...',
#    u'y',
#    u'rafa',
#    u'saluda',
#    u'a',
#    u'todo',
#    u'el',
#    u'equipo',
#    u'argentino.',
#    u'qu\xe9',
#    u'talla',
#    u'de',
#    u'campe\xf3n!!'],
#   'P'),
#  ([u'la',
#    u'quinta',
#    u'ensaladera.',
#    u'nadal',
#    u'saludando',
#    u'al',
#    u'equipo',
#    u'argentino.',
#    u'y',
#    u'ahora',
#    u'al',
#    u'p\xfablico.',
#    u'oe,',
#    u'oe,',
#    u'oe'],
#   'P'),
#  ([u'ya',
#    u'esta',
#    u'aqu\xed.',
#    u'ya',
#    u'lleg\xf3',
#    u'por',
#    u'fin',
#    u'la',
#    u'quinta',
#    u'ensaladera.',
#    u'gracias',
#    u'a',
#    u'todos',
#    u'los',
#    u'miembros',
#    u'del',
#    u'equipo',
#    u'hoy',
#    u'mucha',
#    u'gente',
#    u'dormir\xe1',
#    u'feliz.'],
#   'P'),
#  ([u'que',
#    u'grande,',
#    u'ese',
#    u'abrazo',
#    u'de',
#    u'nadal',
#    u'con',
#    u'todo',
#    u'el',
#    u'equipo',
#    u'argentino',
#    u'impresionante.',
#    u'como',
#    u'sabe',
#    u'ganar',
#    u'este',
#    u'campe\xf3n!!!'],
#   'P'),
#  (['grandioso', 'rafa', 'nadal!!!!!'], 'P'),
#  ([u'el',
#    u'p\xfablico',
#    u'que',
#    u'cante',
#    u'gritando',
#    u'sin',
#    u'parar:',
#    u'"por',
#    u'eso',
#    u'yo',
#    u'te',
#    u'quiero',
#    u'dar',
#    u'rafa',
#    u'mi',
#    u'coraz\xf3n,',
#    u'yo',
#    u'te',
#    u'sigo',
#    u'a',
#    u'todas',
#    u'partes..."',
#    u'\xa1gracias',
#    u'por',
#    u'ser',
#    u'espa\xf1ol!'],
#   'P'),
#  ([u'el',
#    u'camino',
#    u'no',
#    u'puede',
#    u'ser',
#    u'otro',
#    u'que',
#    u'm\xe1s',
#    u'europa',
#    u'#enmiblog'],
#   'NEU'),
#  ([u'el',
#    u'partido',
#    u'de',
#    u'putin/medveded',
#    u'(rusia',
#    u'unida)',
#    u'gana',
#    u'los',
#    u'comicios',
#    u'pero',
#    u'sufre',
#    u'una',
#    u'fuerte',
#    u'ca\xeda.',
#    u'segundo',
#    u'partido',
#    u'm\xe1s',
#    u'votado:',
#    u'partido',
#    u'comunista.'],
#   'NEU'),
#  ([u'madrid',
#    u'ciudad',
#    u'sin',
#    u'ni\xf1os,',
#    u'aumenta',
#    u'el',
#    u'n\xfamero',
#    u'de',
#    u'personas',
#    u'que',
#    u'viven',
#    u'solas.'],
#   'NEU'),
#  ([u'felicidades',
#    u'a',
#    u'@rafaelnadal',
#    u'y',
#    u'a',
#    u'todo',
#    u'el',
#    u'equipo',
#    u'espa\xf1ol',
#    u'de',
#    u'copa',
#    u'davis.',
#    u'todo',
#    u'un',
#    u'ejemplo',
#    u'de',
#    u'esfuerzo,',
#    u'ilusi\xf3n',
#    u'y',
#    u'superaci\xf3n.',
#    u'rbcb'],
#   'P'),
#  ([u'#donaundia',
#    u'los',
#    u'1000',
#    u'primeros',
#    u'd\xedas',
#    u'cruciales',
#    u'para',
#    u'la',
#    u'vida',
#    u'del',
#    u'ni\xf1o',
#    u'http://t.co/jlujz5nk',
#    u'entra',
#    u'y',
#    u'colabora',
#    u'(',
#    u'rts',
#    u'plis',
#    u')'],
#   'NEU'),
#  ([u'estoy',
#    u'viendo',
#    u'los',
#    u'editoriales',
#    u'\u201c@jjesusmelian:',
#    u'@pedroj_ramirez',
#    u'cuentalo',
#    u'ya',
#    u'q',
#    u'estamos',
#    u'en',
#    u'el',
#    u'descanso\u201d'],
#   'NEU'),
#  ([u'fant\xe1sticas,',
#    u'a',
#    u'cual',
#    u'mejor',
#    u'\u201c@marisolcovelo.',
#    u'qu\xe9',
#    u'os',
#    u'parece',
#    u'mi',
#    u'foto',
#    u'de',
#    u'#elprimernaufragio',
#    u'?http://t.co/zjczrogc',
#    u'http://t.co/ch3jjgx1\u201d'],
#   'P'),
#  (['fin', 'a', 'la', 'impunidad', 'en', '#internet', 'http://t.co/j7walds3'],
#   'P'),
#  ([u'a',
#    u'mi',
#    u'me',
#    u'parece',
#    u'muy',
#    u'digno',
#    u'que',
#    u'la',
#    u'ministra',
#    u'italiana',
#    u'de',
#    u'trabajo',
#    u'llore.',
#    u'no',
#    u'me',
#    u'lo',
#    u'parec\xedan',
#    u'las',
#    u'risas',
#    u'de',
#    u'berlusconi.'],
#   'N'),
#  ([u'"una',
#    u'entrevista',
#    u'es',
#    u'un',
#    u'punto',
#    u'intermedio',
#    u'entre',
#    u'una',
#    u'sesi\xf3n',
#    u'de',
#    u'psicoan\xe1lisis',
#    u'y',
#    u'un',
#    u'concurso.',
#    u'a',
#    u'veces',
#    u'no',
#    u'tengo',
#    u'respuestas"',
#    u'fellini'],
#   'NEU'),
#  ([u'en',
#    u'el',
#    u'blog:',
#    u'l\xe1grimas',
#    u'tecn\xf3cratas',
#    u'http://t.co/y7k9awbr'],
#   'N'),
#  (['"los',
#    'ministros',
#    'd',
#    '@marianorajoy',
#    ':',
#    'fin',
#    'de',
#    'la',
#    'ineptocracia"',
#    '@semanaldigital',
#    '@ppopular',
#    'http://t.co/prsx6xan'],
#   'N'),
#  ([u'portada',
#    u'de',
#    u'p\xfablico',
#    u'de',
#    u'ma\xf1ana:',
#    u'urdangarin',
#    u'sa.',
#    u'dentro,',
#    u'la',
#    u'lista',
#    u'de',
#    u'las',
#    u'103',
#    u'entidades',
#    u'que',
#    u'pagaron',
#    u'a',
#    u'n\xf3os',
#    u'http://t.co/bp1bfcl6'],
#   'N'),
#  ([u'a',
#    u'por',
#    u'@crackoviadetv3',
#    u'!!;))',
#    u'buenos',
#    u'd\xedas',
#    u'queridos',
#    u'twiteros!!;))'],
#   'P'),
#  (['gracias', 'venezuela!!!', 'http://t.co/udcradky'], 'P'),
#  ([u'bd\xedas,',
#    u'elisabeth.',
#    u'estoy',
#    u'muy',
#    u'orgulloso',
#    u'de',
#    u'que',
#    u'em',
#    u'haya',
#    u'localizado',
#    u'en',
#    u'un',
#    u'remoto',
#    u'lugar',
#    u'de',
#    u'rumania',
#    u'al',
#    u'testigo',
#    u'que',
#    u'no',
#    u'acudi\xf3',
#    u'al',
#    u'juicio.'],
#   'P'),
#  ([u'\xbfc\xf3mo',
#    u'se',
#    u'explica',
#    u'que',
#    u'miles',
#    u'de',
#    u'espa\xf1oles',
#    u'se',
#    u'ausenten',
#    u'en',
#    u'masa',
#    u'del',
#    u'trabajo',
#    u'durante',
#    u'el',
#    u'"puente",',
#    u'mientras',
#    u'en',
#    u'espa\xf1a',
#    u'hay',
#    u'5',
#    u'millones',
#    u'de',
#    u'parados?'],
#   'N'),
#  ([u'mas',
#    u'es',
#    u'presidente',
#    u'auton\xf3mico',
#    u'porque',
#    u'tenemos',
#    u'autogobierno',
#    u'gracias',
#    u'a',
#    u'la',
#    u'constituci\xf3n,pero',
#    u'ni',
#    u'la',
#    u'cumple',
#    u'ni',
#    u'la',
#    u'hace',
#    u'cumplir',
#    u'#fueradelaley'],
#   'N'),
#  ([u'sobre',
#    u'"accidentes"...',
#    u'rt',
#    u'@santigonzalez10',
#    u'\xe9l',
#    u'hab\xeda',
#    u'llegado',
#    u'antes',
#    u'http://t.co/yqjnqebs'],
#   'N'),
#  (['http://t.co/ewfmz5fc',
#    'una',
#    'lectura',
#    'de',
#    'lo',
#    'que',
#    'ha',
#    'ocurrido',
#    'este',
#    'fin',
#    'd',
#    'semana',
#    'en',
#    '#rusia',
#    'con',
#    '#putin',
#    'y',
#    'su',
#    'partido',
#    'en',
#    '@larazon_es'],
#   'NEU'),
#  ([u'dani',
#    u'garc\xeda',
#    u'recoge',
#    u'en',
#    u'un',
#    u'libro',
#    u'50',
#    u'tapas',
#    u'para',
#    u'acercar',
#    u'la',
#    u'cocina',
#    u'a',
#    u'la',
#    u'sociedad',
#    u'http://t.co/se4fab9z'],
#   'P'),
#  (['el',
#    'voluntariado',
#    'invisible',
#    'http://t.co/cd64wfzf',
#    '#diadelvoluntariado'],
#   'NEU'),
#  ([u'el',
#    u'gobierno',
#    u'chino',
#    u'cree',
#    u'que',
#    u'el',
#    u'pa\xeds',
#    u'"no',
#    u'est\xe1',
#    u'preparado"',
#    u'para',
#    u'protestas',
#    u'sociales',
#    u'-',
#    u'http://t.co/tymt3omq'],
#   'N'),
#  (['en',
#    'el',
#    'congreso.',
#    'entregando',
#    'el',
#    'acta',
#    'y',
#    'haciendo',
#    'todo',
#    'el',
#    'papeleo.',
#    'luego',
#    'os',
#    'cuento',
#    'como',
#    'queda',
#    'la',
#    'cosa!'],
#   'NEU'),
#  (['que',
#    'vistas',
#    'tiene',
#    'mi',
#    'amigo',
#    '@djdimartino',
#    '',
#    'desde',
#    'su',
#    'casa',
#    'en',
#    'almeria!',
#    'y',
#    'esta',
#    'tarde',
#    'y',
#    'esta',
#    'noche',
#    'con',
#    'el',
#    'en',
#    'discoteca',
#    'caramelo'],
#   'NEU'),
#  ([u'upyd',
#    u'y',
#    u'amaiur',
#    u'recurriran',
#    u'a',
#    u'la',
#    u'justicia',
#    u'si',
#    u'no',
#    u'logran',
#    u'grupo.',
#    u'la',
#    u'justicia',
#    u'ya',
#    u'di\xf3',
#    u'todo',
#    u'el',
#    u'poder',
#    u'a',
#    u'la',
#    u'mesa',
#    u'del',
#    u'congreso',
#    u'en',
#    u'caso',
#    u'similar.'],
#   'N'),
#  ([u'hoy',
#    u'abordaremos',
#    u'en',
#    u'@13tv_aldia',
#    u'@13television',
#    u'la',
#    u'gesti\xf3n',
#    u'privada',
#    u'de',
#    u'los',
#    u'hospitales',
#    u'p\xfablicos.',
#    u'\xbfqu\xe9',
#    u'ganamos',
#    u'los',
#    u'ciudadanos?',
#    u'\xbfqu\xe9',
#    u'perdemos?'],
#   'NEU'),
#  (['sin',
#    'miedo',
#    'by',
#    'rosana,',
#    'from',
#    '#soundhound',
#    'http://t.co/pl93oefg'],
#   'NEU'),
#  ([u'y',
#    u'mientras',
#    u'tanto,',
#    u'el',
#    u'verdadero',
#    u'problema',
#    u'se',
#    u'agrava',
#    u'a\xf1o',
#    u'tras',
#    u'a\xf1o',
#    u'http://t.co/j4stxbl8'],
#   'N'),
#  ([u'el',
#    u'sector',
#    u'del',
#    u'lujo',
#    u'cierra',
#    u'el',
#    u'ejercicio',
#    u'con',
#    u'un',
#    u'25%',
#    u'm\xe1s',
#    u'de',
#    u'beneficios.',
#    u'\xbfqui\xe9n',
#    u'sufre',
#    u'la',
#    u'crisis?',
#    u'pues',
#    u'eso...'],
#   'NEU'),
#  (['que',
#    'bonito',
#    'despliegue',
#    'de',
#    'seguridad',
#    'en',
#    'alfonso',
#    'xii.',
#    'contravigilancia',
#    'en',
#    'toda',
#    'la',
#    'manzana.',
#    'y',
#    'no',
#    'es',
#    'nadie',
#    'del',
#    'gobierno!!!!'],
#   'P'),
#  ([u'uno',
#    u'de',
#    u'los',
#    u'desaf\xedos',
#    u'del',
#    u'periodismo.',
#    u'encontrar',
#    u'su',
#    u'sitio',
#    u'para',
#    u'no',
#    u'perder',
#    u'la',
#    u'vigilancia',
#    u'del',
#    u'poder',
#    u'via',
#    u'@clarin_com',
#    u'http://t.co/vgpqhjvs'],
#   'P'),
#  ([u'el',
#    u'@ppandaluz',
#    u'no',
#    u'aceptar\xe1',
#    u'el',
#    u'caramelo',
#    u'de',
#    u'una',
#    u'presidencia',
#    u'de',
#    u'dos',
#    u'a\xf1os',
#    u'en',
#    u'la',
#    u'famp',
#    u'si',
#    u'no',
#    u'hay',
#    u'refundaci\xf3n',
#    u'http://t.co/tagf97e6',
#    u'',
#    u'@europapress_es'],
#   'N'),
#  ([u's\xed,',
#    u'raritos',
#    u'q',
#    u'somos...',
#    u'',
#    u'"si',
#    u'yo',
#    u'fuera',
#    u'espa\xf1a',
#    u'y',
#    u'se',
#    u'tratara',
#    u'de',
#    u'elegir',
#    u'entre',
#    u'2',
#    u'o',
#    u'3',
#    u'a\xf1os',
#    u'de',
#    u'caos',
#    u'y',
#    u'20',
#    u'o',
#    u'30',
#    u'en',
#    u'la',
#    u'miseria..."',
#    u'http://t.co/69om6a3r'],
#   'N'),
#  (['rt',
#    '@perezhilton',
#    '@paurubio',
#    'que',
#    'triste',
#    'es',
#    'esto,',
#    'pau!',
#    'http://t.co/zkf4lzoh',
#    '@jonahmowryreal',
#    '&lt;3!',
#    'http://t.co/hbdznwj5'],
#   'N'),
#  ([u'joooooo',
#    u':-)',
#    u'rt',
#    u'@xaviconde',
#    u'me',
#    u'dice',
#    u'@tonicanto1,',
#    u'que',
#    u'quiere',
#    u'rapear',
#    u'una',
#    u'estrofa',
#    u'del',
#    u'villancico.',
#    u'lo',
#    u'siento',
#    u'toni,',
#    u'aqu\xed',
#    u'tenemos',
#    u'a',
#    u'@padrinomc.'],
#   'P'),
#  ([u'en',
#    u'estos',
#    u'd\xedas',
#    u'de',
#    u'traspaso',
#    u'de',
#    u'poderes',
#    u'os',
#    u'recomiendo',
#    u'seguir',
#    u'a',
#    u'3',
#    u'personas',
#    u'claves',
#    u'en',
#    u'el',
#    u'proceso',
#    u'@sorayapp',
#    u'@jlayllon',
#    u'y',
#    u'@fatimabanez',
#    u'entre',
#    u'otros'],
#   'NEU'),
#  ([u'entiendo',
#    u'que',
#    u'cnn',
#    u'conecte',
#    u'por',
#    u'skype',
#    u'con',
#    u'disidentes',
#    u'en',
#    u'siria',
#    u'pero',
#    u'que',
#    u'la',
#    u'mayor\xeda',
#    u'de',
#    u'las',
#    u'conexiones',
#    u'ya',
#    u'sean',
#    u'por',
#    u'c\xe1mara',
#    u'de',
#    u'm\xf3vil',
#    u'...'],
#   'NEU'),
#  ([u'detienen',
#    u'a',
#    u'dos',
#    u'sospechosos',
#    u'por',
#    u'secuestro',
#    u'cooperantes',
#    u'espa\xf1oles',
#    u'en',
#    u'tinduf.',
#    u'intentaron',
#    u'venderlos',
#    u'a',
#    u'aqmi.',
#    u'http://t.co/kkormmiw',
#    u'v',
#    u'@plazaro67'],
#   'N'),
#  ([u'#icanadmit',
#    u',',
#    u'#elcomecocos10',
#    u',',
#    u'merkel',
#    u'y',
#    u'sarkozy',
#    u'y',
#    u'#cuatrotuiteros',
#    u',',
#    u'los',
#    u'tt',
#    u'esta',
#    u'tarde',
#    u'en',
#    u'espa\xf1a'],
#   'NEU'),
#  ([u'el',
#    u'@ppopular',
#    u'no',
#    u'descarta',
#    u'otra',
#    u'ronda',
#    u'de',
#    u'reuniones',
#    u'con',
#    u'ministerios',
#    u'para',
#    u'traspaso',
#    u'de',
#    u'poderes,',
#    u'despu\xe9s',
#    u'de',
#    u'recibir',
#    u'informaci\xf3n',
#    u'pedida',
#    u'al',
#    u'gobierno'],
#   'NEU'),
#  ([u'toda',
#    u'suya',
#    u'\u201c@juliosandreu:',
#    u's\xed',
#    u'sr.',
#    u'la',
#    u'he',
#    u'grabado.',
#    u'un',
#    u'saludo',
#    u'desde',
#    u'el',
#    u'otro',
#    u'lado,',
#    u'jeje,',
#    u'(',
#    u'de',
#    u'espa\xf1a',
#    u').',
#    u'buena',
#    u'tarde.\u201d'],
#   'P'),
#  ([u'y',
#    u'hable',
#    u'con',
#    u'el',
#    u'coraz\xf3n',
#    u'de',
#    u'los',
#    u'afectos',
#    u'y',
#    u'en',
#    u'esas',
#    u'cosas',
#    u'la',
#    u'justicia',
#    u'habla',
#    u'idiomas',
#    u'diferentes.',
#    u'insisto,',
#    u'dusculpad,',
#    u'pero',
#    u'volver\xeda',
#    u'a',
#    u'hacerlo.'],
#   'NEU'),
#  ([u'entiendo',
#    u'los',
#    u'unfollow.',
#    u'aceptar',
#    u'el',
#    u'desconcierto.',
#    u'y',
#    u'hasta',
#    u'reconocer',
#    u'errores.',
#    u'pero',
#    u'creo',
#    u'fuera',
#    u'de',
#    u'lugar',
#    u'anunciar',
#    u'venganza',
#    u'radiof\xf3nica.',
#    u'eso',
#    u'no'],
#   'P'),
#  ([u';-))))',
#    u'rt',
#    u'@carlosserrato82:',
#    u'#fw',
#    u'para',
#    u'@mariviromero',
#    u'y',
#    u'mucha',
#    u'suerte',
#    u'con',
#    u'tu',
#    u'primera',
#    u'entrevista',
#    u'aqu\xed.',
#    u'el',
#    u'hastag',
#    u'es',
#    u'#ynterviumarivi'],
#   'P'),
#  ([u'"espa\xf1a',
#    u'gasta',
#    u'mas',
#    u'en',
#    u'sanidad',
#    u'que',
#    u'tofo',
#    u'el',
#    u'presupuesto',
#    u'en',
#    u'sanidad"',
#    u'n\xfa\xf1ez',
#    u'feijoo',
#    u'en',
#    u'@gato_directo'],
#   'N'),
#  (['a',
#    'las',
#    '22.30',
#    'mi',
#    'primera',
#    'entrevista',
#    'en',
#    'directo',
#    'en',
#    'twitter.',
#    'si',
#    'quieres',
#    'seguirla',
#    'busca',
#    'el',
#    'hastag',
#    '#ynterviumarivi',
#    'l',
#    'http://t.co/fvxisuny'],
#   'P'),
#  ([u'feliz',
#    u'dia',
#    u'del',
#    u'voluntario...',
#    u'los',
#    u'h\xebroes',
#    u'an\xf3nimos...',
#    u'los',
#    u'del',
#    u'sacrificia',
#    u'por',
#    u'eleccion',
#    u'propia.',
#    u'gracias',
#    u'por',
#    u'tanto.'],
#   'P'),
#  (['gracias',
#    'rt',
#    '@pepemaras:',
#    '#ynterviumarivi',
#    'interesante',
#    'la',
#    'entrevista',
#    'de',
#    '@mariviromero',
#    'nuevas',
#    'herramientas:',
#    'nuevas',
#    'formas',
#    'de',
#    'comunicar'],
#   'P'),
#  ([u'gracias',
#    u'a',
#    u'ti',
#    u'paco',
#    u'rt',
#    u'@pacorengel:',
#    u'#ynterviumarivi',
#    u'@mariviromero',
#    u'much\xedsimas',
#    u'gracias.',
#    u'un',
#    u'beso.',
#    u'la',
#    u'cuelgo',
#    u'en',
#    u'un',
#    u'ratito',
#    u'en',
#    u'http://t.co/yk7peiva'],
#   'P'),
#  ([u'aunque',
#    u'en',
#    u'menor',
#    u'medida,',
#    u'tambi\xe9n',
#    u'lo',
#    u'son',
#    u'muchas',
#    u'que',
#    u'no',
#    u'son',
#    u'madres',
#    u';)',
#    u'@ejoana:',
#    u'supermujeres.',
#    u'gran',
#    u'post',
#    u'de',
#    u'@virginiapalonso',
#    u'http://t.co/sutdmagf'],
#   'P'),
#  ([u'una',
#    u'vez',
#    u'q',
#    u'ha',
#    u'hablado',
#    u'el',
#    u'protectorado',
#    u'franco-alem\xe1n',
#    u'la',
#    u'europa',
#    u'a',
#    u'2',
#    u'o',
#    u'3',
#    u'velocidades',
#    u'est\xe1',
#    u'hecha:',
#    u'ahora',
#    u'falta',
#    u'ver',
#    u'd\xf3nde',
#    u'queda',
#    u'espa\xf1a'],
#   'N'),
#  (['impresionante!',
#    'enhorabuena',
#    'a',
#    '@enpiedeguerra',
#    'y',
#    'un',
#    'beso',
#    'a',
#    '@chiquiesteban',
#    ':',
#    'percebeiros,',
#    'de',
#    'david',
#    'beriain,',
#    'a',
#    'por',
#    'el',
#    'goya!',
#    'http://t.co/cp7ae8sn'],
#   'P'),
#  ([u'sorgi\xf1as,',
#    u'culebras.',
#    u'cabrones',
#    u'negros',
#    u'de',
#    u'barba',
#    u'larga.'],
#   'N'),
#  ([u'...',
#    u'enough',
#    u'today...',
#    u'la',
#    u'semana',
#    u'es',
#    u'larga,',
#    u'y',
#    u'seguramente',
#    u'm\xe1s',
#    u'apasionante',
#    u'de',
#    u'lo',
#    u'recomendable.....'],
#   'P'),
#  ([u'me',
#    u'voy',
#    u'a',
#    u'leer',
#    u'un',
#    u'rato',
#    u"'un",
#    u'd\xeda',
#    u'm\xe1s',
#    u'con',
#    u"vida'",
#    u'de',
#    u'ryszard',
#    u'#kapuscinscki.',
#    u'gran',
#    u'descubrimiento',
#    u'del',
#    u'reportero',
#    u'polaco.',
#    u';)',
#    u'http://t.co/cnha2jy6'],
#   'P'),
#  (['disculpad',
#    'la',
#    'vehemencia.',
#    'pienso',
#    'en',
#    'ello',
#    'para',
#    'una',
#    'peli.'],
#   'NEU'),
#  (['despegando',
#    'ya...que',
#    'lindo',
#    'mi',
#    'pais,',
#    'que',
#    'linda',
#    'mi',
#    'gente!!',
#    '--shak'],
#   'P'),
#  (['synteknosa',
#    'pax',
#    'ahora',
#    'actuando.',
#    'claaro',
#    'que',
#    'si.',
#    'http://t.co/ebzwtsgc'],
#   'NEU'),
#  ([u'bono',
#    u'celebra',
#    u'su',
#    u'\xfaltima',
#    u'fiesta',
#    u'en',
#    u'el',
#    u'congreso',
#    u'y',
#    u'la',
#    u'pregunta',
#    u'es',
#    u'si',
#    u'habr\xe1',
#    u'un',
#    u'viva',
#    u'espa\xf1a!',
#    u'con',
#    u'@juanralucas',
#    u'y',
#    u'en',
#    u'rne,',
#    u'para',
#    u'arrancar.'],
#   'P'),
#  ([u'triste',
#    u'rt',
#    u'@joseplluiscerro:',
#    u'rt',
#    u'@skalistrao:',
#    u'"pap\xe1,',
#    u'\xbfnosotros',
#    u'qu\xe9',
#    u'somos:',
#    u'catalanes',
#    u'o',
#    u'fachas?"',
#    u'::',
#    u'barcelona',
#    u'::',
#    u'catalu\xf1a:',
#    u'http://t.co/7wakfxuo'],
#   'N'),
#  ([u'extorsi\xf3n',
#    u'mafiosa;',
#    u'por',
#    u'carlos',
#    u'garc\xeda',
#    u'-',
#    u'en',
#    u'',
#    u'http://t.co/dbb5qoyt',
#    u'v\xeda',
#    u'@larazon_es'],
#   'N'),
#  ([u'no',
#    u's\xe9',
#    u'de',
#    u'que',
#    u'se',
#    u'sorprenden',
#    u'algunos.',
#    u'el',
#    u'pp',
#    u'presenta',
#    u'unos',
#    u'presupuestos',
#    u'tarde,',
#    u'sin',
# ...
#    u'rajoy'],
#   'N'),
#  ([u'dur\xe1n,',
#    u'ciu,',
#    u'"algunas',
#    u'de',
#    u'las',
#    u'medidas',
#    u'fiscales',
#    u'anunciadas',
#    u'por',
#    u'rajoy',
#    u'son',
#    u'compartidas',
#    u'y',
#    u'ya',
#    u'propuestas',
#    u'por',
#    u'ciu"',
#    u'#investidura'],
#   'NEU'),
#  ([u'parece',
#    u'que',
#    u'no',
#    u'gusta',
#    u'lo',
#    u'de',
#    u'una',
#    u'competencia',
#    u'una',
#    u'administraci\xf3n.',
#    u'pues',
#    u'ganaremos',
#    u'en',
#    u'eficiencia.',
#    u'y',
#    u'hablaremos',
#    u'menos',
#    u'de',
#    u'competencias',
#    u'impropias'],
#   'N'),
#  ([u'#discursorajoy',
#    u'lo',
#    u'bueno-poco-',
#    u'bien',
#    u'explicado.',
#    u'lo',
#    u'malo-',
#    u'mucho-',
#    u'apenas',
#    u'insinuado.',
#    u'conclusi\xf3n:',
#    u'hasta',
#    u'los',
#    u'idus',
#    u'de',
#    u'marzo,',
#    u'no',
#    u'sabremos.'],
#   'NEU'),
#  (['de',
#    'camino',
#    'a',
#    'intereconomia,',
#    'telediario',
#    'con',
#    '@pilarggranja',
#    ',',
#    '15.00:',
#    'discurso',
#    'de',
#    'investidura.'],
#   'NEU'),
#  ([u'rajoy',
#    u'ha',
#    u'recibido',
#    u'una',
#    u'llamada',
#    u'de',
#    u'la',
#    u'presidenta',
#    u'de',
#    u'la',
#    u'avt',
#    u'agradeci\xe9ndole',
#    u'la',
#    u'menci\xf3n',
#    u'inicial',
#    u'a',
#    u'las',
#    u'v\xedctimas',
#    u'del',
#    u'terrorismo'],
#   'P'),
#  ([u'#rajoy',
#    u'dice',
#    u'alonso',
#    u'(pp)',
#    u'que',
#    u'rajoy',
#    u'ha',
#    u'sido',
#    u'muy',
#    u'concreto:',
#    u'16.500',
#    u'millones',
#    u'de',
#    u'recorte.',
#    u'\xbfy',
#    u'de',
#    u'd\xf3nde',
#    u'salen?'],
#   'N'),
#  ([u'rajoy',
#    u'actualizar\xe1',
#    u'pensiones,',
#    u'quitar\xe1',
#    u'puentes',
#    u'y',
#    u'frenar\xe1',
#    u'el',
#    u'uso',
#    u'abusivo',
#    u'del',
#    u'paro',
#    u'http://t.co/w13y7vcf',
#    u'v\xeda',
#    u'@europapress_es'],
#   'P'),
#  ([u'organizaciones',
#    u'agrarias',
#    u'aplauden',
#    u'recuperar',
#    u'el',
#    u'm.',
#    u'de',
#    u'agricultura',
#    u'para',
#    u'dar',
#    u'mayor',
#    u'atenci\xf3n',
#    u'al',
#    u'sector',
#    u'',
#    u'http://t.co/johrhvtg',
#    u'v\xeda',
#    u'@europapress_es'],
#   'P'),
#  ([u'los',
#    u'primeros',
#    u'an\xe1lisis',
#    u'en',
#    u'el',
#    u'pa\xeds',
#    u'sobre',
#    u'el',
#    u'discurso',
#    u'de',
#    u'rajoy.',
#    u'miguel',
#    u'jim\xe9nez',
#    u'analiza',
#    u'la',
#    u'econom\xeda',
#    u'http://t.co/mt8berto'],
#   'NEU'),
#  ([u'repasando',
#    u'discurso',
#    u'#investidura',
#    u'rajoy:',
#    u'el',
#    u'aumento',
#    u'del',
#    u'paro',
#    u'es',
#    u'consecuencia',
#    u'de',
#    u'la',
#    u'intensa',
#    u'destrucci\xf3n',
#    u'de',
#    u'empleo.'],
#   'N'),
#  ([u'#an\xe1lisisrajoy:',
#    u'"el',
#    u'incremento',
#    u'del',
#    u'paro',
#    u'en',
#    u'espa\xf1a',
#    u'se',
#    u'debe,fundamentalmente,',
#    u'a',
#    u'un',
#    u'profundo',
#    u'proceso',
#    u'de',
#    u'destrucci\xf3n',
#    u'de',
#    u'empleo".',
#    u'toma',
#    u'ya!'],
#   'N'),
#  ([u'rajoy:',
#    u'la',
#    u'conmemoraci\xf3n',
#    u'de',
#    u"'la",
#    u"pepa',",
#    u'el',
#    u'"mejor',
#    u'marco',
#    u'para',
#    u'estrechar',
#    u'lazos"',
#    u'con',
#    u'iberoam\xe9rica',
#    u'',
#    u'http://t.co/sosulyzt',
#    u'v\xeda',
#    u'@europapress_es'],
#   'P'),
#  ([u'a\xfan',
#    u'queda',
#    u'mucha',
#    u'sesi\xf3n',
#    u'de',
#    u'investidura,',
#    u'pero',
#    u'ah\xed',
#    u'va',
#    u'un',
#    u'primer',
#    u'an\xe1lisis',
#    u'r\xe1pido',
#    u'del',
#    u'discurso',
#    u'de',
#    u'rajoy',
#    u'http://t.co/huk0nlhp'],
#   'NEU'),
#  ([u'rubalcaba',
#    u'reconoce',
#    u'la',
#    u'mayor\xeda',
#    u'del',
#    u'pp.',
#    u'habla',
#    u'de',
#    u'una',
#    u'participaci\xf3n',
#    u'electoral',
#    u'amplia',
#    u'y',
#    u'reivindica',
#    u'la',
#    u'centralidad',
#    u'del',
#    u'parlamento.',
#    u'anuncia',
#    u'el',
#    u'no.'],
#   'P'),
#  ([u'rubalcaba',
#    u'le',
#    u'pregunta',
#    u'a',
#    u'rajoy,',
#    u'y',
#    u'con',
#    u'raz\xf3n,',
#    u'cu\xe1ndo',
#    u'va',
#    u'a',
#    u'anunciar',
#    u'las',
#    u'malas',
#    u'noticias.'],
#   'N'),
#  ([u'rubalcaba',
#    u'pide',
#    u'"una',
#    u'subida',
#    u'de',
#    u'impuestos',
#    u'selectiva",',
#    u'a',
#    u'quienes',
#    u'm\xe1s',
#    u'tienen',
#    u'y',
#    u'a',
#    u'grandes',
#    u'empresas',
#    u'#investidura'],
#   'N'),
#  ([u'rubalcaba',
#    u'se',
#    u'opone',
#    u'a',
#    u'que',
#    u'haya',
#    u'fondos',
#    u'p\xfablicos',
#    u'para',
#    u'sanear',
#    u'"activos',
#    u't\xf3xicos"',
#    u'#investidura'],
#   'NEU'),
#  ([u'rubalcaba',
#    u'le',
#    u'ha',
#    u'propuesto',
#    u'a',
#    u'rajoy',
#    u'pacto',
#    u'ante',
#    u'europa...',
#    u'por',
#    u'lo',
#    u'dem\xe1s',
#    u'reedici\xf3n',
#    u'del',
#    u'debate',
#    u'electoral'],
#   'P'),
#  (['matiza',
#    'el',
#    'pacto',
#    'constitucional',
#    'de',
#    'estabilidad',
#    'al',
#    '0,5.'],
#   'P'),
#  ([u'rubalcaba',
#    u'logra',
#    u'responder',
#    u'en',
#    u'media',
#    u'hora',
#    u'a',
#    u'todo',
#    u'lo',
#    u'que',
#    u'rajoy',
#    u'dijo',
#    u'en',
#    u'hora',
#    u'y',
#    u'media...',
#    u'se\xf1or,',
#    u'qu\xe9',
#    u'velocidad!',
#    u'#investidura'],
#   'P'),
#  ([u'rubalcaba',
#    u'a',
#    u'rajoy',
#    u'"cualquier',
#    u'retroceso',
#    u'en',
#    u'materia',
#    u'de',
#    u'igualdad',
#    u'',
#    u'contar\xe1',
#    u'con',
#    u'nuestra',
#    u'oposici\xf3n"',
#    u'#investidurarajoy'],
#   'P'),
#  (['rubalcaba',
#    'le',
#    'dice',
#    'a',
#    'rajoy',
#    'que',
#    'tiene',
#    'sospechas',
#    'de',
#    'que',
#    'puede',
#    'recortar',
#    'derechos.',
#    'rajoy',
#    'ni',
#    'le',
#    'mira.',
#    '#investidura'],
#   'N'),
#  ([u'deber\xeda',
#    u'llegar',
#    u'ahora',
#    u'el',
#    u'momento',
#    u'en',
#    u'que',
#    u'rajoy',
#    u'improvise.',
#    u'pero',
#    u'va',
#    u'lleno',
#    u'de',
#    u'papeles',
#    u'a',
#    u'la',
#    u'tribuna.',
#    u'esta',
#    u'aceptando',
#    u'los',
#    u'pactos',
#    u'que',
#    u'ofrec\xeda',
#    u'rubalc'],
#   'N'),
#  ([u'rajoy:',
#    u'"intentar\xe9',
#    u'que',
#    u'no',
#    u'haya"',
#    u'dinero',
#    u'p\xfablico',
#    u'para',
#    u'el',
#    u'sector',
#    u'financiero,',
#    u'aunque',
#    u'dice',
#    u'que',
#    u'hasta',
#    u'ahora,',
#    u'con',
#    u'el',
#    u'frob,',
#    u'lo',
#    u'ha',
#    u'habido',
#    u'#investidura'],
#   'N'),
#  ([u'rajoy',
#    u'habla',
#    u'de',
#    u'recaudaci\xf3n...',
#    u'pero',
#    u'no',
#    u'menciona',
#    u'la',
#    u'lucha',
#    u'contra',
#    u'el',
#    u'fraude.'],
#   'N'),
#  ([u'rajoy',
#    u'no',
#    u'quiere',
#    u'aplausos',
#    u'de',
#    u'm\xe1s.',
#    u'manda',
#    u'sentar',
#    u'con',
#    u'un',
#    u'gesto',
#    u'a',
#    u'su',
#    u'portavoz,',
#    u'alfonso',
#    u'alonso,',
#    u'para',
#    u'acallar',
#    u'al',
#    u'grupo',
#    u'que',
#    u'...',
#    u'http://t.co/husqdh95'],
#   'N'),
#  ([u'rubalcaba',
#    u'calcula',
#    u'que',
#    u'rajoy',
#    u'ha',
#    u'anunciado',
#    u'10.000',
#    u'millones',
#    u'de',
#    u'euros',
#    u'en',
#    u'rebajas',
#    u'fiscales...',
#    u'"\xbfy',
#    u'los',
#    u'ingresos?",',
#    u'se',
#    u'pregunta',
#    u'#investidura'],
#   'NEU'),
#  ([u'la',
#    u'cuenta',
#    u'de',
#    u'gastos',
#    u'fiscales',
#    u'propuesta',
#    u'por',
#    u'rajoy',
#    u'es',
#    u'voluntarista,',
#    u'un',
#    u'poco',
#    u'electoral.',
#    u'\xbfhabr\xe1n',
#    u'hecho',
#    u'los',
#    u'n\xfameros?',
#    u'temo',
#    u'que',
#    u'no'],
#   'N'),
#  ([u'nada',
#    u'le',
#    u'gustar\xeda',
#    u'tanto',
#    u'al',
#    u'pp',
#    u'como',
#    u'tener',
#    u'a',
#    u'rubal',
#    u'enfrente',
#    u'4',
#    u'a\xf1os',
#    u'siendo',
#    u'reh\xe9n',
#    u'de',
#    u'su',
#    u'pasado.',
#    u'el',
#    u'psoe',
#    u'estar\xe1',
#    u'loco',
#    u'si',
#    u'no',
#    u'se',
#    u'renueva.'],
#   'NEU'),
#  ([u'lo',
#    u'del',
#    u'bachillerato',
#    u'de',
#    u'tres',
#    u'a\xf1os',
#    u'es',
#    u'"poner',
#    u'todo',
#    u'patas',
#    u'arriba",',
#    u'dice',
#    u'rubalcaba',
#    u'sobre',
#    u'propuesta',
#    u'de',
#    u'rajoy.',
#    u'#investidura'],
#   'N'),
#  ([u'"los',
#    u'pa\xedses',
#    u'de',
#    u'europa',
#    u'que',
#    u'nos',
#    u'est\xe1n',
#    u'mirando".',
#    u'esa',
#    u'apelaci\xf3n',
#    u'la',
#    u'usa',
#    u'rubalcaba',
#    u'para',
#    u'saber',
#    u'si',
#    u'rajoy',
#    u'cambiar\xe1',
#    u'la',
#    u'jubilaci\xf3n',
#    u'ahora',
#    u'a',
#    u'...'],
#   'NEU'),
#  ([u'@salomega',
#    u'no',
#    u'lo',
#    u'sabia!',
#    u'lo',
#    u'dijo',
#    u'cada',
#    u'd\xeda',
#    u'en',
#    u'sus',
#    u'm\xedtines',
#    u'de',
#    u'campa\xf1a'],
#   'N'),
#  ([u'@pilarggranja',
#    u'te',
#    u'aseguro',
#    u'que',
#    u'no',
#    u'me',
#    u'esperaba',
#    u'su',
#    u'nivel.',
#    u'el',
#    u'grupo',
#    u'pp',
#    u'se',
#    u'est\xe1',
#    u'creciendo',
#    u'por',
#    u'momentos.'],
#   'NEU'),
#  (['tanto',
#    'recortar,',
#    'rajoy',
#    'va',
#    'a',
#    'empezar',
#    'por',
#    'las',
#    'consonantes.',
#    'se',
#    'salta',
#    'una',
#    'de',
#    'cada',
#    'dos.',
#    '(le',
#    'he',
#    'dao,',
#    'senao)'],
#   'N'),
#  ([u'onc\xf3logos',
#    u'espa\xf1oles',
#    u'denuncian',
#    u'"dificultades"',
#    u'en',
#    u'el',
#    u'uso',
#    u'de',
#    u'nuevas',
#    u'terapias',
#    u'contra',
#    u'el',
#    u'c\xe1ncer.',
#    u'hablan',
#    u'de',
#    u'obst\xe1culos',
#    u'administrativos.',
#    u'tremendo'],
#   'N'),
#  (['@iescolar',
#    'perdona,',
#    'pero',
#    'eso',
#    'lo',
#    'respeta:',
#    'solo',
#    'pide',
#    'que',
#    'no',
#    'se',
#    'llame',
#    '"matrimonio"',
#    'porque',
#    'no',
#    'hay',
#    '"mater".'],
#   'P'),
#  (['le', 'toca', 'el', 'turno', 'a', 'duan', '(ciu)', '#investidura'], 'NEU'),
#  ([u'esta',
#    u'noche',
#    u'm',
#    u'acompa\xf1an',
#    u'en',
#    u'@dham_13tv',
#    u'esther',
#    u'ja\xe9n,',
#    u'@noeliamtnez',
#    u',',
#    u'ma',
#    u'gozalo,',
#    u'@pazmacazaga',
#    u',',
#    u'mar\xeda',
#    u'claver',
#    u'y',
#    u'pablo',
#    u'casado',
#    u'...'],
#   'NEU'),
#  ([u'contin\xfaa',
#    u'ciu',
#    u'con',
#    u'austeridad,',
#    u'rigor',
#    u'y',
#    u'solidaridad,',
#    u'mediante',
#    u'ley',
#    u'\xf3mnibus(',
#    u'un',
#    u'sarcasmo),',
#    u's\xf3lo',
#    u'alg\xfan',
#    u'pellizco',
#    u'con',
#    u'el',
#    u'estatut.'],
#   'N'),
#  ([u'dur\xe1n',
#    u'(ciu)',
#    u'da',
#    u'su',
#    u'apoyo',
#    u'al',
#    u'rajoy',
#    u'para',
#    u'"revisar"',
#    u'el',
#    u'seguro',
#    u'de',
#    u'paro,',
#    u'no',
#    u'para',
#    u'"suprimir",',
#    u'aclara',
#    u'por',
#    u'si',
#    u'acaso...',
#    u'#investidura'],
#   'P'),
#  ([u'es',
#    u'ponerse',
#    u'....\u201c@olgacs78:',
#    u'@buenafuente',
#    u'no',
#    u'te',
#    u'veo',
#    u'yo',
#    u'de',
#    u'burbuja',
#    u'de',
#    u'freixenet!!!!',
#    u'jejejeje\u201d'],
#   'NEU'),
#  ([u'dur\xe1n',
#    u'(ciu)',
#    u'se',
#    u'declara',
#    u'"enormemente',
#    u'preocupado"',
#    u'por',
#    u'la',
#    u'"recentralizaci\xf3n"',
#    u'que',
#    u'cree',
#    u'ver',
#    u'en',
#    u'las',
#    u'medidas',
#    u'de',
#    u'rajoy',
#    u'#investidura'],
#   'N'),
#  ([u'duran',
#    u'pide',
#    u'el',
#    u'pacto',
#    u'de',
#    u'cumplimiento',
#    u'fiscal',
#    u'con',
#    u'catalu\xf1a.',
#    u'afirma',
#    u'que',
#    u'solo',
#    u'asi',
#    u'podr\xe1',
#    u'ser',
#    u'la',
#    u'locomotora',
#    u'econ\xf3mica',
#    u'de',
#    u'espa\xf1a.'],
#   'P'),
#  ([u'lo',
#    u'de',
#    u'"espa\xf1a',
#    u'nos',
#    u'est\xe1',
#    u'haciendo',
#    u'm\xe1s',
#    u'pobres"',
#    u'de',
#    u'dur\xe1n',
#    u'es',
#    u'literal'],
#   'N'),
#  ([u'rajoy',
#    u'busca',
#    u'al',
#    u'menos',
#    u'la',
#    u'abstenci\xf3n',
#    u'de',
#    u'ciu.',
#    u'dice',
#    u'que',
#    u'est\xe1',
#    u'de',
#    u'acuerdo',
#    u'con',
#    u'su',
#    u'filosof\xeda.',
#    u'y',
#    u'le',
#    u'recuerda',
#    u'que',
#    u'el',
#    u'pp',
#    u'apoya',
#    u'a',
#    u'ciu',
#    u'en',
#    u'catalu\xf1a.'],
#   'P'),
#  ([u'hay',
#    u'4.023',
#    u'empresas,',
#    u'organismos',
#    u'y',
#    u'entidades',
#    u'publicas,',
#    u'dice',
#    u'rajoy.',
#    u'y',
#    u'mucho',
#    u'absentismo,',
#    u'a\xf1ade.habla',
#    u'de',
#    u'recortar',
#    u'empleo',
#    u'publico,',
#    u'sin',
#    u'cuantificar'],
#   'N'),
#  (['denuncia',
#    'la',
#    'reforma',
#    'constitucional',
#    'y',
#    'el',
#    'golpe',
#    'de',
#    'los',
#    'mercados,',
#    'pidiendo',
#    'la',
#    'denuncia',
#    'de',
#    'deuda',
#    'ilegitima.'],
#   'N'),
#  (['se',
#    'suceden',
#    'los',
#    'portavoces',
#    'de',
#    'iu',
#    'en',
#    'el',
#    'congreso.',
#    'ahora',
#    'se',
#    'estrena',
#    '',
#    '@jcoscu,',
#    'de',
#    'icv.el',
#    'pleno',
#    'se',
#    'cierra',
#    'esta',
#    'noche',
#    'con',
#    'upyd.',
#    '#investidurarajoy'],
#   'NEU'),
#  ([u'y',
#    u'ahora',
#    u'qu\xe9',
#    u'`pasar\xe1',
#    u'en',
#    u'el',
#    u'gobierno?',
#    u'http://t.co/nqo4ldfc'],
#   'NEU'),
#  (['revista',
#    'de',
#    'prensa',
#    '(abc',
#    'punto',
#    'radio,',
#    '19',
#    'de',
#    'diciembre)',
#    'http://t.co/r9abktwm'],
#   'NEU'),
#  ([u'mi',
#    u'gran',
#    u'amigo',
#    u'@fgarea',
#    u'cumple',
#    u'a\xf1os.',
#    u'no',
#    u's\xe9',
#    u'',
#    u'cuantos',
#    u'son',
#    u'pero',
#    u'no',
#    u'demasiados',
#    u'jajaja.',
#    u'felicidades'],
#   'P'),
#  ([u'empieza',
#    u'rosa',
#    u'd\xedez',
#    u'como',
#    u'vasca',
#    u'y',
#    u'espa\xf1ola',
#    u'asumiendo',
#    u'su',
#    u'responsabilidad,',
#    u'leal',
#    u'oposici\xf3n',
#    u'',
#    u'y',
#    u'dice',
#    u'que',
#    u'el',
#    u'debate',
#    u'lo',
#    u'gana',
#    u'rajoy.',
#    u'yo',
#    u'no',
#    u'dir\xeda',
#    u'tanto'],
#   'P'),
#  (['holaaa',
#    'mis',
#    'tweeps!',
#    'un',
#    'dia',
#    'maravilloso',
#    'para',
#    'hacer',
#    'un',
#    'twitcam',
#    'como',
#    'os',
#    'he',
#    'prometido',
#    'sera',
#    'a',
#    'las',
#    '6:00',
#    'pm',
#    '(hora',
#    'de',
#    'mexico)',
#    'nos',
#    'vemos',
#    'pronto!!!'],
#   'P'),
#  ([u'se',
#    u'recomienda',
#    u'a',
#    u'rosa',
#    u'd\xedez',
#    u'foniatra',
#    u'al',
#    u'canto,',
#    u'con',
#    u'ese',
#    u'tono',
#    u'de',
#    u'voz',
#    u'le',
#    u'van',
#    u'a',
#    u'salir',
#    u'unos',
#    u'p\xf3lipos',
#    u'como',
#    u'monaguillos',
#    u'si',
#    u'no',
#    u'se',
#    u'cuida.'],
#   'N'),
#  ([u'aqu\xed',
#    u'os',
#    u'dejo',
#    u'la',
#    u'\xfaltima',
#    u'foto',
#    u'de',
#    u'la',
#    u'celebraci\xf3n',
#    u'de',
#    u'ayer',
#    u'despu\xe9s',
#    u'de',
#    u'ganar',
#    u'el',
#    u'mundialito.',
#    u'ahora',
#    u'a',
#    u'pensar',
#    u'en',
#    u'el',
#    u'jueves.'],
#   'P'),
#  (['rubalcaba',
#    'ya',
#    'se',
#    'marcha',
#    'del',
#    'congreso.',
#    'acaba',
#    'de',
#    'ponerse',
#    'el',
#    'abrigo',
#    'y',
#    'se',
#    'va',
#    'escaleras',
#    'arriba',
#    'con',
#    'dos',
#    'carteras',
#    'en',
#    'la',
#    'mano',
#    '#investidura'],
#   'NEU'),
#  (['rajoy',
#    'y',
#    'rosa',
#    'diez',
#    'apuran',
#    'los',
#    'ultimos',
#    'minutos',
#    'del',
#    'debate.',
#    'se',
#    'enzarzan',
#    'a',
#    'cuenta',
#    'de',
#    'la',
#    'ley',
#    'electoral'],
#   'N'),
#  ([u'ha',
#    u'dicho',
#    u'rajoy',
#    u'en',
#    u'#investidura',
#    u'que',
#    u'para',
#    u'mantener',
#    u'el',
#    u'estado',
#    u'de',
#    u'bienestar',
#    u'en',
#    u'espa\xf1a',
#    u'hay',
#    u'que',
#    u'crear',
#    u'puestos',
#    u'de',
#    u'trabajo...',
#    u'es',
#    u'el',
#    u'\xfanico',
#    u'modo'],
#   'P'),
#  ([u'balance',
#    u'de',
#    u'la',
#    u'1\xaa',
#    u'jornada',
#    u'del',
#    u'debate:',
#    u'en',
#    u'este',
#    u'parlamento',
#    u'se',
#    u'va',
#    u'a',
#    u'oir',
#    u'de',
#    u'todo',
#    u'pero',
#    u'nada',
#    u'lo',
#    u'que',
#    u'se',
#    u'diga',
#    u'va',
#    u'a',
#    u'importar',
#    u'demasiado.'],
#   'N'),
#  ([u'se',
#    u'nos',
#    u'ha',
#    u'ido',
#    u'el',
#    u'maestro',
#    u'h\xe9ctor',
#    u'n\xfa\xf1ez.',
#    u'una',
#    u'gran',
#    u'p\xe9rdida.',
#    u'un',
#    u'sentido',
#    u'abrazo',
#    u'para',
#    u'la',
#    u'familia',
#    u'y',
#    u'el',
#    u'f\xfatbol',
#    u'uruguayo.',
#    u'dep'],
#   'N'),
#  ([u'jejeje',
#    u'check.',
#    u'rt',
#    u'@sullymoralesvsz:',
#    u'que',
#    u'@alejandrosanz',
#    u'acepte',
#    u'hacer',
#    u'twittcam',
#    u'\u2611,hacer',
#    u'q',
#    u'(cont)',
#    u'http://t.co/xxzjwlqm'],
#   'NEU'),
#  (['empezamos',
#    '...?',
#    '(@alejandrosanz',
#    'live',
#    'on',
#    'http://t.co/5u2pzfzx)'],
#   'NEU'),
#  (['vale',
#    'ya',
#    'casi',
#    'casi',
#    '...',
#    'veo',
#    'que',
#    'cada',
#    'minuto',
#    'somos',
#    'mas!',
#    '(@alejandrosanz',
#    'live',
#    'on',
#    'http://t.co/5u2pzfzx)'],
#   'P'),
#  ([u'aqu\xed',
#    u'estoy',
#    u'con',
#    u'@lopolito',
#    u'@labalonso',
#    u'listos',
#    u'y',
#    u'aqu\xed',
#    u'vamos...',
#    u'(@alejandrosanz',
#    u'live',
#    u'on',
#    u'http://t.co/5u2pzfzx)'],
#   'P'),
#  ...]

# %%
def get_words_in_tweets(tweets):
    all_words = []
    for (words, sentiment) in tweets:
        all_words.extend(words)
    return all_words


def get_word_features(wordlist):
    wordlist = nltk.FreqDist(wordlist)
    word_features = wordlist.keys()
    return word_features

word_features = get_word_features(get_words_in_tweets(tweets))

def extract_features(document):
    document_words = set(document)
    features = {}
    for word in word_features:
        features['contains(%s)' % word] = (word in document_words)
    return features

# %%
def classify_tweet(tweet):
    return classifier.classify(extract_features(nltk.word_tokenize(tweet)))

# %%
from nltk.tokenize import word_tokenize
from nltk.classify import NaiveBayesClassifier

# get the training set and train the Naive Bayes Classifier
training_set = nltk.classify.util.apply_features(extract_features, tweets)

# %%
NBClassifier = nltk.NaiveBayesClassifier.train(training_set)

# %% [raw]
# import nltk
# #Proceso de Tweets
# def processTweet(tweet):
#     tweet = tweet.lower()
#     # www.* or https?://* to URL
#     tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))','URL',tweet)
#     #@username to AT_USER
#     tweet = re.sub('@[^\s]+','AT_USER',tweet)
#     #Remove additional white spaces
#     tweet = re.sub('[\s]+', ' ', tweet)
#     #Replace #word with word
#     tweet = re.sub(r'#([^\s]+)', r'\1', tweet)
#     #trim
#     tweet = tweet.strip('\'"')
#     return tweet
#
# #print NBClassifier.classify(extract_features(getFeatureVector(processedTweet('RT @Misssione: Madrid lleno de hojas ca\u00eddas que con la lluvia, te resbalas. \u00bfSe har\u00e1 cargo Carmena y su equipo de los da\u00f1os que suframos lo\u2026')))) + '\n'
#
# extract = dftweets[0:50]
# for row in extract.iterrows():
#     print row['tweet'] + '---->' + NBClassifier.classify(extract_features(nltk.word_tokenize(processTweet(row['tweet']))))
