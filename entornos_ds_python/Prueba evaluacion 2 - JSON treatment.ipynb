# %% [markdown]
# # Prueba de evaluacion. Tratamiento de JSON
# #### El primer paso es cargar las librerías necesarias para la ejecuion

# %%
import json
import urllib2
import requests as rq
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Se consulta el catalogo de Boards de la página 4chan y se evalua el tipo de contenido y la respuesta

# %%
r = rq.get('https://a.4cdn.org/boards.json')
print r.status_code
print r.headers['content-type']
print r.text[:1000]
# Out:
# 200
# application/json
# {"boards":[{"board":"3","title":"3DCG","ws_board":1,"per_page":15,"pages":10,"max_filesize":4194304,"max_webm_filesize":3145728,"max_comment_chars":2000,"max_webm_duration":120,"bump_limit":310,"image_limit":150,"cooldowns":{"threads":600,"replies":60,"images":60},"meta_description":"\u0026quot;\/3\/ - 3DCG\u0026quot; is 4chan's board for 3D modeling and imagery.","is_archived":1},{"board":"a","title":"Anime \u0026 Manga","ws_board":1,"per_page":15,"pages":10,"max_filesize":4194304,"max_webm_filesize":3145728,"max_comment_chars":2000,"max_webm_duration":120,"bump_limit":500,"image_limit":250,"cooldowns":{"threads":600,"replies":60,"images":60},"meta_description":"\u0026quot;\/a\/ - Anime \u0026amp; Manga\u0026quot; is 4chan's imageboard dedicated to the discussion of Japanese animation and manga.","spoilers":1,"custom_spoilers":1,"is_archived":1,"json_tail_size":50},{"board":"aco","title":"Adult Cartoons","ws_board":0,"per_page":15,"pages":10,"max_filesize":4194304,"max_webm_filesize":

# %% [markdown]
# Se obtiene el contexto en texto y se transforma en un objeto JSON para navegar com osi fuera un diccionario

# %%
boards = json.loads(r.text)
print type(boards)
print(json.dumps(boards, indent=3))
# Out:
# <type 'dict'>
# {
#    "boards": [
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/3/ - 3DCG&quot; is 4chan's board for 3D modeling and imagery.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "3DCG",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "board": "3",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/a/ - Anime &amp; Manga&quot; is 4chan's imageboard dedicated to the discussion of Japanese animation and manga.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Anime & Manga",
#          "spoilers": 1,
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "custom_spoilers": 1,
#          "json_tail_size": 50,
#          "board": "a",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 500,
#          "image_limit": 250,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/aco/ - Adult Cartoons&quot; is 4chan's imageboard for posting western-styled adult cartoon artwork.",
#          "cooldowns": {
#             "images": 30,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Adult Cartoons",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 0,
#          "max_filesize": 4194304,
#          "json_tail_size": 50,
#          "board": "aco",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 300,
#          "image_limit": 250,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/adv/ - Advice&quot; is 4chan's board for giving and receiving advice. ",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Advice",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "json_tail_size": 50,
#          "board": "adv",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/an/ - Animals &amp; Nature&quot; is 4chan's imageboard for posting pictures of animals, pets, and nature.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Animals & Nature",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "board": "an",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/asp/ - Alternative Sports &amp; Wrestling&quot; is 4chan's imageboard for the discussion of alternative and extreme sports such as wrestling and paintball.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Alternative Sports & Wrestling",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "board": "asp",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/b/ - Random&quot; is the birthplace of Anonymous, and where people go to discuss random topics and create memes on 4chan.",
#          "cooldowns": {
#             "images": 15,
#             "threads": 60,
#             "replies": 15
#          },
#          "title": "Random",
#          "max_comment_chars": 2000,
#          "forced_anon": 1,
#          "ws_board": 0,
#          "max_filesize": 2097152,
#          "json_tail_size": 50,
#          "board": "b",
#          "max_webm_filesize": 2097152,
#          "per_page": 15,
#          "bump_limit": 300,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/biz/ - Business &amp; Finance&quot; is 4chan's imageboard for the discussion of business and finance, and cryptocurrencies such as Bitcoin and Dogecoin.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Business & Finance",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "user_ids": 1,
#          "board": "biz",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/c/ - Anime/Cute&quot; is 4chan's imageboard for cute and moe anime images.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Anime/Cute",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "board": "c",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/cgl/ - Cosplay &amp; EGL&quot; is 4chan's imageboard for the discussion of cosplay, elegant gothic lolita (EGL), and anime conventions.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Cosplay & EGL",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "board": "cgl",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/ck/ - Food &amp; Cooking&quot; is 4chan's imageboard for food pictures and cooking recipes.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Food & Cooking",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "json_tail_size": 50,
#          "board": "ck",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/cm/ - Cute/Male&quot; is 4chan's imageboard for posting pictures of cute anime males.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Cute/Male",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "board": "cm",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/co/ - Comics &amp; Cartoons&quot; is 4chan's imageboard dedicated to the discussion of Western cartoons and comics.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Comics & Cartoons",
#          "spoilers": 1,
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "custom_spoilers": 5,
#          "json_tail_size": 50,
#          "board": "co",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 500,
#          "image_limit": 250,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/d/ - Hentai/Alternative&quot; is 4chan's imageboard for alternative hentai images.",
#          "cooldowns": {
#             "images": 30,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Hentai/Alternative",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 0,
#          "max_filesize": 4194304,
#          "json_tail_size": 50,
#          "board": "d",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 300,
#          "image_limit": 250,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/diy/ - Do It Yourself&quot; is 4chan's imageboard for DIY/do it yourself projects, home improvement, and makers.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Do It Yourself",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "board": "diy",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/e/ - Ecchi&quot; is 4chan's imageboard for suggestive (ecchi) hentai images.",
#          "cooldowns": {
#             "images": 30,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Ecchi",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 0,
#          "max_filesize": 4194304,
#          "json_tail_size": 50,
#          "board": "e",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 300,
#          "image_limit": 250,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/f/ - Flash&quot; is 4chan's upload board for sharing Adobe Flash files (SWFs).",
#          "cooldowns": {
#             "images": 30,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Flash",
#          "max_comment_chars": 2000,
#          "ws_board": 0,
#          "max_filesize": 10485760,
#          "board": "f",
#          "max_webm_filesize": 3145728,
#          "per_page": 30,
#          "bump_limit": 300,
#          "image_limit": 250,
#          "pages": 1
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/fa/ - Fashion&quot; is 4chan's imageboard for images and discussion relating to fashion and apparel.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Fashion",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "json_tail_size": 50,
#          "board": "fa",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/fit/ - Fitness&quot; is 4chan's imageboard for weightlifting, health, and fitness.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Fitness",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "json_tail_size": 50,
#          "board": "fit",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/g/ - Technology&quot; is 4chan's imageboard for discussing computer hardware and software, programming, and general technology.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Technology",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "json_tail_size": 50,
#          "code_tags": 1,
#          "board": "g",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/gd/ - Graphic Design&quot; is 4chan's imageboard for graphic design.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Graphic Design",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 8388608,
#          "board": "gd",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 300,
#          "meta_description": "&quot;/gif/ - Adult GIF&quot; is 4chan's imageboard dedicated to animated adult GIFs and WEBMs.",
#          "cooldowns": {
#             "images": 30,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Adult GIF",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 0,
#          "max_filesize": 4194304,
#          "json_tail_size": 50,
#          "board": "gif",
#          "webm_audio": 1,
#          "max_webm_filesize": 4194304,
#          "per_page": 15,
#          "bump_limit": 300,
#          "image_limit": 250,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/h/ - Hentai&quot; is 4chan's imageboard for adult Japanese anime hentai images.",
#          "cooldowns": {
#             "images": 30,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Hentai",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 0,
#          "max_filesize": 4194304,
#          "json_tail_size": 50,
#          "board": "h",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 300,
#          "image_limit": 250,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/hc/ - Hardcore&quot; is 4chan's imageboard for the posting of adult hardcore pornography.",
#          "cooldowns": {
#             "images": 30,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Hardcore",
#          "min_image_width": 500,
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 0,
#          "max_filesize": 8388608,
#          "json_tail_size": 50,
#          "min_image_height": 500,
#          "board": "hc",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 300,
#          "image_limit": 250,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/his/ - History &amp; Humanities&quot; is 4chan's board for discussing and debating history.",
#          "cooldowns": {
#             "images": 15,
#             "threads": 60,
#             "replies": 15
#          },
#          "title": "History & Humanities",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "json_tail_size": 50,
#          "board": "his",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/hm/ - Handsome Men&quot; is 4chan's imageboard dedicated to sharing adult images of handsome men.",
#          "cooldowns": {
#             "images": 30,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Handsome Men",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 0,
#          "max_filesize": 8388608,
#          "board": "hm",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 300,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/hr/ - High Resolution&quot; is 4chan's imageboard for the sharing of high resolution images.",
#          "cooldowns": {
#             "images": 30,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "High Resolution",
#          "min_image_width": 1000,
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 0,
#          "max_filesize": 8388608,
#          "min_image_height": 1000,
#          "board": "hr",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 300,
#          "image_limit": 250,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/i/ - Oekaki&quot; is 4chan's oekaki board for drawing and sharing art.",
#          "cooldowns": {
#             "images": 30,
#             "threads": 600,
#             "replies": 60
#          },
#          "oekaki": 1,
#          "title": "Oekaki",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 0,
#          "max_filesize": 4194304,
#          "board": "i",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 300,
#          "image_limit": 250,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/ic/ - Artwork/Critique&quot; is 4chan's imageboard for the discussion and critique of art.",
#          "cooldowns": {
#             "images": 30,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Artwork/Critique",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 0,
#          "max_filesize": 4194304,
#          "board": "ic",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 300,
#          "image_limit": 250,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/int/ - International&quot; is 4chan's international board, for the exchange of foreign language and culture.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "International",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "json_tail_size": 50,
#          "board": "int",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "country_flags": 1,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/jp/ - Otaku Culture&quot; is 4chan's board for discussing Japanese otaku culture.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 3600,
#             "replies": 60
#          },
#          "title": "Otaku Culture",
#          "spoilers": 1,
#          "is_archived": 1,
#          "max_comment_chars": 5000,
#          "sjis_tags": 1,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "custom_spoilers": 1,
#          "json_tail_size": 50,
#          "board": "jp",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 300,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/k/ - Weapons&quot; is 4chan's imageboard for discussing all types of weaponry, from military tanks to guns and knives.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Weapons",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "json_tail_size": 50,
#          "board": "k",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/lgbt/ - LGBT&quot; is 4chan's imageboard for Lesbian-Gay-Bisexual-Transgender-Queer and sexuality discussion.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "LGBT",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "json_tail_size": 50,
#          "board": "lgbt",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/lit/ - Literature&quot; is 4chan's board for the discussion of books, authors, and literature.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Literature",
#          "spoilers": 1,
#          "is_archived": 1,
#          "max_comment_chars": 3000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "custom_spoilers": 1,
#          "board": "lit",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/m/ - Mecha&quot; is 4chan's imageboard for discussing Japanese mecha robots and anime, like Gundam and Macross.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Mecha",
#          "spoilers": 1,
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "custom_spoilers": 4,
#          "board": "m",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/mlp/ - Pony&quot; is 4chan's imageboard dedicated to the discussion of My Little Pony: Friendship is Magic.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Pony",
#          "spoilers": 1,
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "custom_spoilers": 1,
#          "json_tail_size": 50,
#          "board": "mlp",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 500,
#          "image_limit": 250,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/mu/ - Music&quot; is 4chan's imageboard for discussing all types of music.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Music",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "json_tail_size": 50,
#          "board": "mu",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/n/ - Transportation&quot; is 4chan's imageboard for discussing modes of transportation like trains and bicycles.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Transportation",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "board": "n",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/news/ - Current News; is 4chan's board for current news. ",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Current News",
#          "spoilers": 1,
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "custom_spoilers": 1,
#          "board": "news",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 500,
#          "image_limit": 250,
#          "pages": 10,
#          "text_only": 1,
#          "require_subject": 1
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/o/ - Auto&quot; is 4chan's imageboard for discussing cars and motorcycles.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Auto",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "board": "o",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/out/ - Outdoors&quot; is 4chan's imageboard for discussing survivalist skills and outdoor activities such as hiking.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Outdoors",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 5242880,
#          "board": "out",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/p/ - Photography&quot; is 4chan's imageboard for sharing and critiquing photos.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Photography",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 5242880,
#          "board": "p",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/po/ - Papercraft &amp; Origami&quot; is 4chan's imageboard for posting papercraft and origami templates and instructions.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Papercraft & Origami",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 8388608,
#          "board": "po",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/pol/ - Politically Incorrect&quot; is 4chan's board for discussing and debating politics and current events.",
#          "cooldowns": {
#             "images": 15,
#             "threads": 60,
#             "replies": 15
#          },
#          "title": "Politically Incorrect",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 0,
#          "max_filesize": 4194304,
#          "user_ids": 1,
#          "json_tail_size": 50,
#          "board": "pol",
#          "max_webm_filesize": 3145728,
#          "per_page": 20,
#          "bump_limit": 300,
#          "country_flags": 1,
#          "image_limit": 250,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/qa/ - Question &amp; Answer&quot; is 4chan's imageboard for question and answer threads.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Question & Answer",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "json_tail_size": 50,
#          "board": "qa",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/qst/ - Quests&quot; is 4chan's imageboard for grinding XP.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "oekaki": 1,
#          "title": "Quests",
#          "spoilers": 1,
#          "is_archived": 1,
#          "max_comment_chars": 3000,
#          "ws_board": 1,
#          "max_filesize": 8388608,
#          "user_ids": 1,
#          "json_tail_size": 50,
#          "board": "qst",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 750,
#          "image_limit": 250,
#          "pages": 10,
#          "require_subject": 1
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/r/ - Request&quot; is 4chan's imageboard dedicated to fulfilling all types of user requests.",
#          "cooldowns": {
#             "images": 30,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Adult Requests",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 0,
#          "max_filesize": 8388608,
#          "board": "r",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 300,
#          "image_limit": 250,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/r9k/ - ROBOT9001&quot; is a board for hanging out and posting greentext stories.",
#          "cooldowns": {
#             "images": 30,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "ROBOT9001",
#          "spoilers": 1,
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 0,
#          "max_filesize": 2097152,
#          "json_tail_size": 50,
#          "board": "r9k",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 500,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/s/ - Sexy Beautiful Women&quot; is 4chan's imageboard dedicated to sharing images of softcore pornography.",
#          "cooldowns": {
#             "images": 30,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Sexy Beautiful Women",
#          "min_image_width": 500,
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 0,
#          "max_filesize": 8388608,
#          "json_tail_size": 50,
#          "min_image_height": 500,
#          "board": "s",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 300,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;[s4s] - Shit 4chan Says&quot; is 4chan's imageboard for posting dank memes :^)",
#          "cooldowns": {
#             "images": 30,
#             "threads": 300,
#             "replies": 60
#          },
#          "title": "Shit 4chan Says",
#          "spoilers": 1,
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 0,
#          "max_filesize": 2097152,
#          "custom_spoilers": 6,
#          "board": "s4s",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 300,
#          "image_limit": 250,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/sci/ - Science &amp; Math&quot; is 4chan's board for the discussion of science and math.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Science & Math",
#          "math_tags": 1,
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "board": "sci",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/soc/ - Cams &amp; Meetups&quot; is 4chan's board for camwhores and meetups.",
#          "cooldowns": {
#             "images": 30,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Cams & Meetups",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "forced_anon": 1,
#          "ws_board": 0,
#          "max_filesize": 5242880,
#          "user_ids": 1,
#          "json_tail_size": 50,
#          "board": "soc",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 500,
#          "image_limit": 250,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/sp/ - Sports&quot; is 4chan's imageboard for sports discussion.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Sports",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "json_tail_size": 50,
#          "board": "sp",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 500,
#          "country_flags": 1,
#          "image_limit": 250,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/t/ - Torrents&quot; is 4chan's imageboard for posting links and descriptions to torrents.",
#          "cooldowns": {
#             "images": 30,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Torrents",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 0,
#          "max_filesize": 4194304,
#          "board": "t",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 300,
#          "image_limit": 250,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/tg/ - Traditional Games&quot; is 4chan's imageboard for discussing traditional gaming, such as board games and tabletop RPGs.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Traditional Games",
#          "spoilers": 1,
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 8388608,
#          "custom_spoilers": 2,
#          "json_tail_size": 50,
#          "board": "tg",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/toy/ - Toys&quot; is 4chan's imageboard for talking about all kinds of toys!",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Toys",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "board": "toy",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/trash/ - Off-topic&quot; is 4chan's imageboard jail for off-topic threads.",
#          "cooldowns": {
#             "images": 30,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Off-Topic",
#          "max_comment_chars": 2000,
#          "forced_anon": 1,
#          "ws_board": 0,
#          "max_filesize": 4194304,
#          "json_tail_size": 50,
#          "board": "trash",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 300,
#          "image_limit": 250,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/trv/ - Travel&quot; is 4chan's imageboard dedicated to travel and the countries of the world.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Travel",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 8388608,
#          "board": "trv",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/tv/ - Television &amp; Film&quot; is 4chan's imageboard dedicated to the discussion of television and film.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Television & Film",
#          "spoilers": 1,
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "custom_spoilers": 5,
#          "json_tail_size": 50,
#          "board": "tv",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/u/ - Yuri&quot; is 4chan's imageboard for yuri hentai images.",
#          "cooldowns": {
#             "images": 30,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Yuri",
#          "spoilers": 1,
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 0,
#          "max_filesize": 4194304,
#          "json_tail_size": 50,
#          "board": "u",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 300,
#          "image_limit": 250,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/v/ - Video Games&quot; is 4chan's imageboard dedicated to the discussion of PC and console video games.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Video Games",
#          "spoilers": 1,
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "custom_spoilers": 1,
#          "json_tail_size": 50,
#          "board": "v",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 500,
#          "image_limit": 250,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/vg/ - Video Game Generals&quot; is 4chan's imageboard dedicated to the discussion of PC and console video games.",
#          "cooldowns": {
#             "images": 120,
#             "threads": 600,
#             "replies": 90
#          },
#          "title": "Video Game Generals",
#          "spoilers": 1,
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "custom_spoilers": 1,
#          "json_tail_size": 50,
#          "board": "vg",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 750,
#          "image_limit": 250,
#          "pages": 10,
#          "require_subject": 1
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/vip/ - Very Important Posts&quot; is 4chan's imageboard for Pass users.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Very Important Posts",
#          "spoilers": 1,
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "sjis_tags": 1,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "json_tail_size": 50,
#          "board": "vip",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 300,
#          "image_limit": 300,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/vp/ - Pok&eacute;mon&quot; is 4chan's imageboard dedicated to discussing the Pok&eacute;mon series of video games and shows.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Pok\u00e9mon",
#          "spoilers": 1,
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "custom_spoilers": 1,
#          "json_tail_size": 50,
#          "board": "vp",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/vr/ - Retro Games&quot; is 4chan's imageboard for discussing retro console video games and classic arcade games.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Retro Games",
#          "spoilers": 1,
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "custom_spoilers": 2,
#          "board": "vr",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 500,
#          "image_limit": 250,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/w/ - Anime/Wallpapers&quot; is 4chan's imageboard for posting Japanese anime wallpapers.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Anime/Wallpapers",
#          "min_image_width": 480,
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 6291456,
#          "min_image_height": 600,
#          "board": "w",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 250,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/wg/ - Wallpapers/General&quot; is 4chan's imageboard for posting general wallpapers.",
#          "cooldowns": {
#             "images": 30,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Wallpapers/General",
#          "min_image_width": 480,
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 0,
#          "max_filesize": 6291456,
#          "min_image_height": 600,
#          "board": "wg",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 300,
#          "image_limit": 250,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 300,
#          "meta_description": "&quot;/wsg/ - Worksafe GIF&quot; is 4chan's imageboard dedicated to sharing worksafe animated GIFs and WEBMs.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Worksafe GIF",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "board": "wsg",
#          "webm_audio": 1,
#          "max_webm_filesize": 4194304,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/wsr/ - Worksafe Requests&quot; is 4chan's imageboard dedicated to fulfilling non-NSFW requests.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Worksafe Requests",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 8388608,
#          "board": "wsr",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/x/ - Paranormal&quot; is 4chan's imageboard for the discussion of paranormal, spooky pictures and conspiracy theories.",
#          "cooldowns": {
#             "images": 60,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Paranormal",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 1,
#          "max_filesize": 4194304,
#          "board": "x",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 310,
#          "image_limit": 150,
#          "pages": 10
#       },
#       {
#          "max_webm_duration": 120,
#          "meta_description": "&quot;/y/ - Yaoi&quot; is 4chan's imageboard for posting adult yaoi hentai images.",
#          "cooldowns": {
#             "images": 30,
#             "threads": 600,
#             "replies": 60
#          },
#          "title": "Yaoi",
#          "is_archived": 1,
#          "max_comment_chars": 2000,
#          "ws_board": 0,
#          "max_filesize": 4194304,
#          "board": "y",
#          "max_webm_filesize": 3145728,
#          "per_page": 15,
#          "bump_limit": 300,
#          "image_limit": 250,
#          "pages": 10
#       }
#    ]
# }

# %% [markdown]
# Se definen dos funciones
#
# * add_row: que volcara la informacion de cada post en un registro del dataframe
#
# * iterate_post: que navegara por todos los post de cada thread,y a su vez por cada thread dentro de cada board seleccionado

# %%
def add_row(pos):
    if ("replies" in pos) and ("fsize" in pos):
        print(pos["no"])
        title = pos["no"]
        metadesc = int(pos["replies"])
        imagesize = int(pos["fsize"])
        postframe.loc[title] = [ metadesc, imagesize]
        
def iterate_board(df, board):
    url = "http://a.4cdn.org/%s/%s.json"
    size = board["pages"] 
    count = 0
    count_thread = 0
    count_post = 0
    for i in range(size):
        #print(i)
        formated_url = url%(board["board"],i+1)
        temp = rq.get(formated_url)
        #print(formated_url)
        page = json.loads(temp.text)
        #print(json.dumps(page, indent=2))
        #print(len(page["threads"]))
        for trh in page["threads"]:
            count_thread = count_thread+ 1
            #print( "hilo", count_thread)
            for post in trh["posts"]:
                count_post += 1
                #print( "post", count_post)
                number = int(post["no"])
                replies = 0
                fsize = 0
                name = post["name"]
                com = ""
                bo = board["board"]
                if ("com" in post):
                    com = post["com"]
                if ("replies" in post):
                    replies = int(post["replies"])
                if ("fsize" in post):
                    fsize = int(post["fsize"])
                df.loc[number] = [bo,replies,fsize,name,com]

# %% [markdown]
# Seleccionamos los 2 boards iniciales de la consulta.
# Los iteramos para generar el dataframe final

# %%
board0= boards["boards"][0]
board1= boards["boards"][1]

#creamos el data frame a explorar
postframe = pd.DataFrame(columns=["board","replies", "fsize","name","com",])

#Completamos el dataframe con todos los post de boar1
iterate_board(postframe, board0)
iterate_board(postframe, board1)

# %%
postframe.size
postframe.head(5)
# Out:
#        board  replies     fsize       name  \
# 248019     3     73.0    3277.0  Anonymous
# 248425     3      0.0   59371.0  Anonymous
# 534631     3     12.0  388359.0  Anonymous
# 536465     3      0.0       0.0  Anonymous
# 536833     3      0.0       0.0  Anonymous
#
#                                                       com
# 248019  So I was cleaning up my hard drive and I found...
# 248425
# 534631  Any amateur architects look to voice chat and ...
# 536465  <a href="#p534631" class="quotelink">&gt;&gt;5...
# 536833  <a href="#p536465" class="quotelink">&gt;&gt;5...

# %% [markdown]
# Consideraremos los post con replies!=0 y fsize!=0 ya que afectaria a la distribucion de ambas variables.
#
# Los post de respuesta a algunos post no contienen datos ni de numero de respuestas ni de tamños de ficheros, por lo que tendremos que filtrar el dataset global para revisar estos datos.

# %%
df_filtered = postframe.loc[(postframe['replies']>0)]
df_filtered = df_filtered.loc[(df_filtered['fsize']>0)]
df_filtered.size
# Out:
# 1440

# %% [markdown]
# Revisamos la media para el primero de los boards.
#
# Parece que la media de respuestas en el board '3' está en torno a 24 respuestas por topic

# %%
pd.DataFrame.describe(df_filtered[df_filtered['board']=='3'])
# Out:
#           replies         fsize
# count  143.000000  1.430000e+02
# mean    27.909091  4.537861e+05
# std     55.799176  7.400378e+05
# min      1.000000  3.277000e+03
# 25%      5.000000  5.107550e+04
# 50%     12.000000  1.610730e+05
# 75%     23.000000  4.853110e+05
# max    333.000000  3.716663e+06

# %% [markdown]
# Sin embargo para el segundo board, parece que la media de respuestas es mucho mayor, en torno a 126

# %%
pd.DataFrame.describe(df_filtered[df_filtered['board']=='a'])
# Out:
#           replies         fsize
# count  145.000000  1.450000e+02
# mean   104.489655  5.113394e+05
# std    130.399073  7.187743e+05
# min      1.000000  4.780000e+03
# 25%     11.000000  7.864700e+04
# 50%     40.000000  2.090570e+05
# 75%    163.000000  6.046400e+05
# max    507.000000  3.914090e+06

# %% [markdown]
# Ploteamos la distribucion del tamaño de los ficheros para los post del primer board. Parece que no siguen una distribución normal, puesto que la mayoria están entre los 5000 y 10000 bytes.

# %%
dfplot = df_filtered.reset_index()
counts, bins, patches = plt.hist(dfplot[dfplot['board']=='a']['fsize'],range=(min(dfplot[dfplot['board']=='a']['fsize']), max(dfplot[dfplot['board']=='a']['fsize'])), bins=100)
#plt.set_xticks(bins)
locs, labels = plt.xticks()
plt.setp(labels, rotation=90)
plt.ylabel('occurences')
plt.xlabel('File size in bytes')

# %%
sns.distplot(dfplot["fsize"], hist=False, rug=False)

# %% [markdown]
# Comprobamos la normalidad. COn un test por debajo de 0.05 significara que la distribucion no es normal, lo que encaja con la gráfica ploteada del tamaño de las imagenes

# %%
from scipy.stats.mstats import normaltest  #Estudiamos si la distribucion es normal o no.
_, pval1 = normaltest(dfplot["fsize"])
print pval1
# Out:
# 2.10259148827e-35
