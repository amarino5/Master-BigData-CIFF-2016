# %%
import pandas as pd
import json
from py2neo import Graph, Node, Relationship
import networkx as nx

# %%
dfusers = pd.DataFrame(columns=['name','description','url','followers','lang','profile_image','following','followers'])
dftweets = pd.DataFrame(columns=['userId','geo','coordinates','timestamp','tweet','source','isretweeted','lang','lat','lon','polarity'])

# %%
dfusers.head(3)
dftweets.head(3)
# Out:
#                              userId   geo coordinates      timestamp  \
# 801190056161484800  SenioritoLuShin  None        None  1479853569437
# 801190058929901572         biferato  None        None  1479853570097
# 801190090080972800      susoglosada  None        None  1479853577524
#
#                                                                 tweet  \
# 801190056161484800  rt @javierjuantur: manuela carmena le hace la ...
# 801190058929901572  rt @xuxipc: dice cifuentes a carmena que no se...
# 801190090080972800  rt @misssione: madrid lleno de hojas caídas qu...
#
#                                                                source  \
# 801190056161484800  <a href="http://twitter.com/download/android" ...
# 801190058929901572  <a href="http://twitter.com" rel="nofollow">Tw...
# 801190090080972800  <a href="http://twitter.com/download/android" ...
#
#                    isretweeted lang   lat   lon polarity
# 801190056161484800        True   es  null  null     null
# 801190058929901572        True   es  null  null     null
# 801190090080972800        True   es  null  null     null

# %%
dftweetslabeled = pd.read_csv('tweets_analyzed.csv', encoding='utf-8')
dftweetslabeled.head(2)
dftweetslabeled=dftweetslabeled.rename(columns = {'Unnamed: 0.1':'id'})
dftweetslabeled.head(1)
# Out:
#    Unnamed: 0                  id              userId  geo coordinates  \
# 0           0  800355989086203905  799032032017993733  NaN         NaN
#
#        timestamp                                              tweet  \
# 0  1479654712350  rt AT_USER el edificio (no okupado) que posee ...
#
#                                               source isretweeted lang   lat  \
# 0  <a href="http://twitter.com" rel="nofollow">Tw...        True   es  null
#
#     lon polarity
# 0  null        P

# %% [markdown]
# Metodos de definicion de clase objeto y tweet para hacer transparente el modelado

# %%
class user_class:
    def __init__(self, name, description, followers, following):
        self.name = name
        self.desc = description
        self.followers = followers
        self.following = following
        #print 'name:',name,'#desc:',description,'#followers:',followers,'#following:',following
    
class tweet_class:
    def __init__(self, name, autor, text, source, retweeted, publisher, polarity):
        self.identifier = name
        self.autor = autor
        self.text = text
        self.source = source
        self.retweeted = retweeted
        self.publisher = publisher
        self.polarity = polarity
        #print 'tweet:',name,'#autor:',autor,'#text:',text,'#polarity:',polarity

# %% [markdown]
# Creacion de grafo dentro de Neo4j

# %%
def create_node_user(user,graph):
    try:
        user_node = Node("User", id=str(user.name), desc=user.desc, followers=user.followers, following=user.following)
        graph.merge(user_node)
    except Exception as e:
        print e.args,':','creating user node graph'
        
    return user_node
    
def create_relationship(tweet,graph):
    #publish relationship when is retwweted from
    #autor the original tweeter user
    #publisher is who publish the RT
    try:   
        tweet_node = Node("Tweet", id=str(tweet.identifier), source=tweet.source, text=tweet.text, retweeted=str(tweet.retweeted), 
                          polarity= tweet.polarity)
        graph.merge(tweet_node)
    except Exception as e:
        print e.args,':','creating tweet node graph'
    
    if (tweet.retweeted):
        pub = create_node_user(tweet.publisher,graph)
        graph.create(rel(tweet_node, "RT_BY", pub))
    else:
        au = create_node_user(tweet.autor,graph)
        graph.create(rel(tweet_node, "CREATED_BY", au))

# %% [markdown]
# Metodos para la creacion de un grafo con NetworkX de python

# %%
##Metodos para crear grafo con NetworkX
import itertools
import random

import matplotlib.pyplot as plt
import networkx as nx
import numpy as np

        
def create_node_user_x(user,g):
    try:
        g.add_node(str(user.name))
#         g[str(user.name)]['type']='user'
#         g[str(user.name)]['desc']=user.desc
#         g[str(user.name)]['followers']=user.followers
#         g[str(user.name)]['following']=user.following
    except Exception as e:
        print e.args,':','create_node_user_x:creating user node graph'
        
    return user
    
def create_relationship_x(tweet,g):
    #publish relationship when is retwweted from
    #autor the original tweeter user
    #publisher is who publish the RT
    try:   
        g.add_node(tweet.identifier)
#         g[tweet.identifier]['source']=tweet.source
#         g[tweet.identifier]['text']=tweet.text
#         g[tweet.identifier]['retweeted']=str(tweet.retweeted)
#         g[tweet.identifier]['polarity']=tweet.polarity
#         print 'Node created:',tweet.identifier
    except Exception as e:
        print e.args,':','create_relationship_x:creating tweet node graph'
    
    if (tweet.retweeted):
        pub = create_node_user_x(tweet.publisher,g)
        g.add_edge(pub.name,tweet.identifier, types='RT_BY')
        print 'Relation created:',pub.name,tweet.identifier,'RT_BY'
        #g.edge[pub.name][tweet.identifier]['type'] = 'RT_BY'
    else:
        print 'Retacion created:',tweet.identifier
        au = create_node_user_x(tweet.autor,g)
        g.add_edge(au.name,tweet.identifier,types='CREATED_BY')
        print 'Relation created:',au.name,tweet.identifier,'CREATED_BY'
        #g.edge[au.name][tweet.identifier]['type'] = 'CREATED_BY'

# %%
def processUser(decoded,df):
    try:
        userId = decoded['user']['id']
        name = decoded['user']['screen_name']
        description = decoded['user']['description']
        url = decoded['user']['url']
        followers = decoded['user']['followers_count']
        lang = decoded['user']['lang']
        profile_image = decoded['user']['profile_image_url']
        following = decoded['user']['following']
        print 'NAME:'+ name
        print 'DESC:'+ description
        print 'FOLLOWERS:'+ str(followers)
        print 'FOLLOWING:'+ str(following)
        #df.loc[userId] = [name,description,url,followers,lang,profile_image,following,followers]
        us = user_class(name, description, str(followers), str(following))
    except Exception as a:
        print a.args,':','processUser: error processing User......'
    return us

def processAutor(decoded):
    try:
        #userId = decoded['retweeted_status']['user']['screen_name']
        name = decoded['retweeted_status']['user']['screen_name']
        description = decoded['retweeted_status']['user']['description']
        #url = decoded['retweeted_status']['user']['screen_name']
        followers = decoded['retweeted_status']['user']['followers_count']
        #lang = decoded['retweeted_status']['user']['screen_name']
        #profile_image = decoded['retweeted_status']['user']['screen_name']
        following = decoded['retweeted_status']['user']['following']
        us = user_class(name, description, followers, following)
    except Exception as a:
        print a.args,':','processAutor:error processing Author......'
    return us

#Proceso de Tweets
def processTweet(decoded,df):
    try:
        #print 'processTweet: procesando .... :',decoded
        identifier = decoded['id']
        #print 'IDENTIFICADOR..............:' + identifier
        publisher = decoded['user']['screen_name']
        geo = decoded['geo']
        coordinates = decoded['coordinates']
        timestamp = decoded['timestamp_ms']
        text = decoded['text']
        text = text.lower()
        source = decoded['source']
        isretweeted = False 
        autor=''
        autor_class = ''
        if 'retweeted_status' in decoded:
            if decoded['retweeted_status'] is not 'null':
                isretweeted = True
                autor = decoded['retweeted_status']['user']['screen_name']
                autor_class = processAutor(decoded)
        lang = decoded['lang']
        lat = 'null'
        lon = 'null'
        polarity = 'null'
        publisher_class = processUser(decoded,df)
        df.loc[identifier] = [publisher,geo,coordinates,timestamp,text,source,isretweeted,lang,lat,lon, polarity] 
        tw = tweet_class(identifier, autor, text, source, isretweeted, publisher, polarity)
    except Exception as a:
        print a.args,':','processTweet: error processing Tweet'
    
    return tw

# %% [markdown]
# Generacion de grafo desde DataFrame

# %%
g=nx.Graph()
dftweetslabeled = pd.read_csv('tweets_analyzed.csv', encoding='utf-8')
dftweetslabeled=dftweetslabeled.rename(columns = {'Unnamed: 0.1':'id'})
sub = dftweetslabeled[:10]
tw = 'null'
for index,row in sub.iterrows(): 
    pub = user_class(row['user_name'], row['user_desc'], row['user_followers'], row['user_following'])
    if (row['isretweeted']):
        autor = user_class(row['autor_name'], row['autor_desc'], row['autor_followers'], row['autor_following'])
    tw = tweet_class(row['id'], autor, row['tweet'], row['source'], row['isretweeted'], pub, row['polarity'])
    try:
        create_relationship_x(tw,g)
    except Exception as a:
        print a.args,':','creating node and relationship'
# Out:
# Relation created: GRUPO_METRO_MZA 800355989086203905 RT_BY
# Relation created: pepelopezperaza 800355991057530880 RT_BY
# Relation created: Reiv4x 800355991892037632 RT_BY
# Relation created: xShyWolf_ 800355992147881988 RT_BY
# Relation created: angeljurado666 800355997126512640 RT_BY
# Relation created: PablodelaMac 800356004424622080 RT_BY
# Relation created: JuanmaSilvaLH 800356015325712385 RT_BY
# Relation created: RamonGismero 800356033025687552 RT_BY
# Relation created: niblick62 800356132388818945 RT_BY
# Relation created: llamaradasrojas 800356177288822784 RT_BY

# %%
print g.nodes()[0:10]
print g.edges()[0:10]
# Out:
# [u'800437744455577600', u'800455531269865472', 'vanessa45079678', 'LidiaSauraB', u'800367174120574981', 'quilla_mari', u'800361441199063040', u'800443801399595008', 'rlmalco60', u'800452033316732928']
# [(u'800437744455577600', u'VranicicVsjnia'), (u'800455531269865472', u'elioferran'), ('vanessa45079678', u'800440565930270720'), ('LidiaSauraB', u'800435020687179776'), (u'800367174120574981', u'MJLetrada'), ('quilla_mari', u'800429818298986496'), (u'800361441199063040', u'fcbofpique4'), (u'800443801399595008', u'BorjaSerratosa'), ('rlmalco60', u'800452192843010048'), (u'800452033316732928', u'luciaguarderia')]

# %%
nx.connected_components(g)
nx.degree(g)
# nx.closeness_centrality(g)
# nx.betweenness_centrality(g)
# nx.pagerank(g, alpha=0.9)
# Out:
# {u'800455531269865472': 1,
#  u'800639847908200448': 1,
#  u'800683193523470336': 1,
#  u'800711940884623360': 1,
#  'CatastrofeGH': 2,
#  u'800659809297055744': 1,
#  'vanessa45079678': 1,
#  u'800361441199063040': 1,
#  u'800721384838234112': 1,
#  'xaviconde': 1,
#  u'800638751680696320': 1,
#  'juanitorrodri': 1,
#  u'800643686560362497': 1,
#  u'800666928574566400': 1,
#  'kittingworks': 2,
#  'kasqass': 1,
#  'Ciutada': 1,
#  'Garamatos': 1,
#  u'800646664340041728': 1,
#  'sufesan': 1,
#  'PlataformaPIRE': 1,
#  'lalogonzalezmen': 1,
#  'RosaCandidaMD': 1,
#  u'800735364960882688': 1,
#  'Kaletes': 1,
#  'carlosrmaribona': 1,
#  u'800367174120574981': 1,
#  'pepbon1': 1,
#  'eduperezb': 1,
#  'deteibols': 2,
#  u'800706189994631168': 1,
#  u'800661695303733248': 1,
#  'lucia_pdll': 1,
#  'NestorTovar32': 1,
#  'malvartinez': 1,
#  u'800675543758807040': 1,
#  u'800732787682766852': 1,
#  u'800711679512150017': 1,
#  u'800630896332304384': 1,
#  u'800726572168843264': 1,
#  'asocvec4caminos': 1,
#  u'800660893650456576': 1,
#  'sosdependencia1': 1,
#  u'800458960977481728': 1,
#  u'800699975525076992': 1,
#  'elenamohino': 1,
#  u'800676474579722240': 1,
#  'brujinma': 1,
#  'JesusRedondoCon': 1,
#  'khalil_M_odeh': 1,
#  u'800712390899879936': 1,
#  u'800432981131329536': 1,
#  'Ellaeslajefa': 1,
#  u'800678664727891968': 1,
#  'PedroJosLucas': 1,
#  u'800443871230496768': 1,
#  u'800726184380297220': 1,
#  u'800679627383521280': 1,
#  'argelia51': 1,
#  u'800706393011589120': 1,
#  u'800690452232019969': 1,
#  'rodrigoamirola': 1,
#  u'800683440030949377': 1,
#  'PaquiPastor': 2,
#  u'800648428506128385': 1,
#  'mlopezcastro': 1,
#  'KiwiMalabarista': 1,
#  u'800735280709763073': 1,
#  u'800731123898863616': 1,
#  'Fran30fernandez': 1,
#  'marina_villares': 1,
#  u'800726486642790400': 1,
#  'ReduRedudaniel': 1,
#  'RMarquezSayun': 1,
#  'jiindignado': 1,
#  u'800630108801339392': 1,
#  'mariaytodos': 2,
#  u'800711514713833476': 1,
#  u'800659469315096578': 1,
#  u'800690377812480001': 1,
#  'Adelita49455610': 1,
#  u'800658598799884288': 1,
#  'Racsonion': 1,
#  u'800684626150821888': 1,
#  'Custos15': 2,
#  'Rafelyto': 1,
#  u'800716778460577792': 1,
#  u'800700306577391616': 1,
#  'mayorpega': 2,
#  u'800693034698555392': 1,
#  'fgamizr': 2,
#  u'800677798612340737': 1,
#  'tempratwitt': 2,
#  u'800451406822080512': 1,
#  'Erremeaaaaches': 1,
#  'elculoderaquel': 1,
#  'Ngr_Nico': 2,
#  u'800632986320437248': 1,
#  'Nora87516067': 3,
#  u'800742504249364480': 1,
#  u'800712133793062913': 1,
#  u'800721912129261568': 1,
#  'antictona': 2,
#  'Tarin83': 1,
#  'focusonliamz': 1,
#  u'800678677784776704': 1,
#  'GanemosJerez': 1,
#  u'800447346534481920': 1,
#  'elenalagebarca': 1,
#  u'800719071004262400': 1,
#  u'800625985146224640': 1,
#  u'800743276236120064': 1,
#  u'800721681920692224': 1,
#  'DominguezUrbina': 1,
#  'ProyectoChina': 1,
#  u'800688871503753217': 1,
#  u'800679614335094784': 1,
#  u'800443425573044224': 1,
#  u'800685060185800704': 1,
#  u'800712969990475776': 1,
#  u'800709791740022784': 1,
#  u'800367572680146944': 1,
#  u'800712306720129024': 1,
#  u'800665434265677824': 1,
#  u'800679309669265408': 1,
#  u'800731388446027776': 1,
#  'doncarioco': 1,
#  u'800717630017372160': 1,
#  'InfoHeaders_Tes': 9,
#  u'800717353596157952': 1,
#  u'800699565255098368': 1,
#  'irenepanea': 1,
#  u'800689754769494016': 1,
#  u'800681628452274177': 1,
#  'MegaProgre': 1,
#  u'800645518003150848': 1,
#  'copito_1902': 1,
#  u'800672897031405568': 1,
#  'MIGUEL___in': 1,
#  u'800731071105167360': 1,
#  u'800445690535092224': 1,
#  u'800642860030640129': 1,
#  'PodemosAhora': 4,
#  u'800718307477200896': 1,
#  u'800688828621225984': 1,
#  u'800691313628696580': 1,
#  u'800630564986515456': 1,
#  u'800661959318392833': 1,
#  'SantosPoved': 1,
#  u'800733377192038405': 1,
#  'Sr_XYZ': 3,
#  'gutierrezma631': 1,
#  'clarcadi': 1,
#  u'800633167854137344': 1,
#  u'800675119119171584': 1,
#  'angelbilbaobust': 1,
#  'palocorlo': 1,
#  'andresnosenada': 1,
#  u'800455962259849216': 1,
#  u'800712919180865540': 1,
#  u'800445261302665216': 1,
#  u'800459247611834368': 1,
#  u'800673533953265664': 1,
#  u'800732632237518849': 1,
#  'platero777': 1,
#  'KikeM_': 1,
#  'homopestis': 2,
#  'dabbidian': 2,
#  u'800726437514932226': 1,
#  'yishrihza_otja': 2,
#  'nenapantiga': 1,
#  'elsoldemerix': 1,
#  'Flan_DeHuevo': 1,
#  u'800679811278635008': 1,
#  'iraidapoveda': 1,
#  'salvadorgrau1': 1,
#  u'800732764677046272': 1,
#  u'800715333040533504': 1,
#  u'800430051095244800': 1,
#  'Alejandrofdz_95': 1,
#  u'800713549647663104': 1,
#  u'800647350050029568': 1,
#  'evabaltartorres': 1,
#  'quimcs58': 1,
#  'roberto_saez': 1,
#  u'800699601267388416': 1,
#  u'800360910833360896': 1,
#  u'800732232109281280': 1,
#  'JuntasPodemosCM': 1,
#  'AngelSa05989620': 2,
#  u'800699850937470976': 1,
#  u'800714894127415297': 1,
#  u'800670731222720512': 1,
#  u'800711757178269697': 1,
#  'catifh': 1,
#  'ATTACNavarra': 1,
#  u'800730013884682240': 1,
#  u'800728966029971457': 1,
#  u'800741368444297216': 1,
#  u'800675201138774016': 1,
#  u'800727865167781888': 1,
#  u'800721810392227840': 1,
#  u'800708570895351808': 1,
#  'AnaPerezMartin': 2,
#  u'800710139468808192': 1,
#  'LolaypPelota': 1,
#  u'800700594088357888': 1,
#  'seguragc': 5,
#  u'800670856804466689': 1,
#  u'800682420660015104': 1,
#  'Ernesto_Reyna_7': 1,
#  u'800430813481271296': 1,
#  u'800722038163902464': 1,
#  u'800680721807511552': 1,
#  'alexlavapies': 1,
#  u'800685452302962688': 1,
#  u'800699501866520576': 1,
#  u'800721625624834048': 1,
#  u'800655359161597952': 1,
#  u'800719231054581760': 1,
#  'pzmonika': 1,
#  'JosAntonioMill2': 1,
#  u'800741623420358656': 1,
#  'CuberoLuis': 1,
#  'estheruqui78': 1,
#  'ignacioramos9': 1,
#  u'800695539423645696': 1,
#  'ManoLareu': 3,
#  u'800734336462925824': 1,
#  u'800361441438011393': 1,
#  u'800702343943745537': 1,
#  u'800690470636634112': 1,
#  'Mercede23860814': 1,
#  u'800729538074411008': 1,
#  u'800723323139346432': 1,
#  'arrifinu': 1,
#  'and_hueso': 1,
#  u'800654040031838208': 1,
#  u'800659861016973312': 1,
#  'AhoraFuencarral': 5,
#  'SANMARTINPERU': 1,
#  u'800654278847119362': 1,
#  'ExpresionNoti': 1,
#  u'800683972250451968': 1,
#  u'800670645130526720': 1,
#  u'800360979196420096': 1,
#  'blythe_club': 7,
#  'megarciaalzaga': 1,
#  'nano581': 1,
#  'albeguren': 2,
#  'erbonono': 1,
#  u'800367182765035525': 1,
#  'haudrugerty1980': 1,
#  'Krohm_ES': 2,
#  'DavidCfd': 1,
#  'CapitanVallo': 1,
#  u'800460149072613376': 1,
#  u'800724198419271680': 1,
#  'espartano533': 1,
#  'AgusCardoso02': 1,
#  'radioklara': 2,
#  u'800711681198424064': 1,
#  u'800698022787239937': 1,
#  'RadaGonzalez': 1,
#  u'800726552220672000': 1,
#  'Alex20III': 1,
#  'ruizlecue': 1,
#  u'800692260870426624': 1,
#  u'800464484867436544': 1,
#  u'800643491487510528': 1,
#  u'800357081647878145': 1,
#  'elmolinofuenla': 1,
#  'beabarmart': 3,
#  u'800645900376932352': 1,
#  'iescolar': 3,
#  u'800713418894409728': 1,
#  u'800641546978807808': 1,
#  u'800688018952634368': 1,
#  u'800737364700262405': 1,
#  'niazdvsn': 1,
#  u'800698390472486912': 1,
#  'DelMrsn89578': 1,
#  u'800638512848478208': 1,
#  'SanchezCedillo': 1,
#  u'800718685203824640': 1,
#  u'800454322765103104': 1,
#  '99682gabi': 1,
#  u'800711691399024640': 1,
#  u'800460935852920832': 1,
#  'j_n_g_8': 1,
#  u'800363387712483328': 1,
#  'jmlatorre1400': 1,
#  'nunoxcris': 1,
#  u'800362083208589312': 1,
#  'RaulMarTol': 1,
#  u'800694728840855554': 1,
#  'sadratak': 1,
#  u'800684547352432640': 1,
#  '1061.0': 1,
#  'juandiazheredia': 1,
#  'Jauregu03138733': 1,
#  'hastaelnavo': 1,
#  'valorysensatez': 1,
#  'sophie_CLM': 1,
#  u'800729203448676357': 1,
#  u'800660845734703104': 1,
#  'BrunoAKSG': 1,
#  u'800738941288779777': 1,
#  'maripicb': 1,
#  'Susana45922784': 1,
#  u'800687978117033984': 1,
#  u'800452431242899456': 1,
#  'ITEPREGUNTO0': 1,
#  'redghost_76': 1,
#  u'800662840986271744': 1,
#  u'800362658465599488': 1,
#  u'800683934564700160': 1,
#  'albert_poux': 1,
#  u'800630461928091648': 1,
#  'edivernois': 1,
#  'Palcharco': 1,
#  'boschsjoan': 1,
#  u'800635032285147136': 1,
#  u'800743297249488896': 1,
#  u'800367058903068672': 1,
#  u'800693549658439680': 1,
#  u'800682676147646464': 1,
#  u'800726598089523200': 1,
#  'DaniAlonsoArias': 1,
#  u'800672898704936961': 1,
#  u'800686561973014529': 1,
#  'elalegria73': 1,
#  'alcazar_miguel': 1,
#  'fcopaton': 2,
#  u'800358412139843585': 1,
#  u'800705539722407936': 1,
#  'DOLLYANGARITA': 2,
#  's_chusita': 2,
#  u'800661069689593856': 1,
#  '5SOSwithShawn': 1,
#  'moncho__1': 1,
#  'DRF______': 1,
#  u'800632265751416833': 1,
#  'foxagmu': 2,
#  u'800677564196986881': 1,
#  'Beibiyein': 1,
#  u'800733022211477505': 1,
#  'YessicaGarciaG': 1,
#  u'800649804128931841': 1,
#  'silviapadronll': 1,
#  'conelmazo_dando': 7,
#  'trabajadorsamur': 1,
#  'sandriita895': 1,
#  'carlosmavel': 1,
#  u'800685216285229056': 1,
#  u'800712395203248129': 1,
#  u'800726568058454016': 1,
#  'lorenawolves_47': 1,
#  u'800702916885704704': 1,
#  u'800683657748852736': 1,
#  u'800664107582111745': 1,
#  u'800697767081508864': 1,
#  'redrerick': 1,
#  'yukuve': 1,
#  u'800678833833832448': 1,
#  'iinqpe': 1,
#  u'800628476235710464': 1,
#  u'800703386924388352': 1,
#  u'800639829029646336': 1,
#  u'800736692697059330': 1,
#  'pacoalmazan5': 2,
#  'AntonioLopez78': 1,
#  'Canesky': 2,
#  u'800723399618097152': 1,
#  u'800673703608614913': 1,
#  u'800676857729449986': 1,
#  u'800671303434809348': 1,
#  'rosmitamom': 1,
#  u'800710826369884160': 1,
#  'Joserayan1959': 1,
#  'LolitaLobby': 3,
#  u'800732224928804864': 1,
#  u'800727510380085248': 1,
#  'MiguelGarcaNava': 1,
#  u'800660103712096256': 1,
#  u'800729659772141574': 1,
#  'FranRuizGirona': 1,
#  u'800724652406386688': 1,
#  u'800437177750425600': 1,
#  'chelivega': 2,
#  u'800460210745708544': 1,
#  u'800651566814466048': 1,
#  u'800681511125073924': 1,
#  u'800731142253137921': 1,
#  u'800699972748333057': 1,
#  u'800687851297906688': 1,
#  'RaqMichael': 1,
#  u'800714887873884160': 1,
#  'gestholtur': 3,
#  u'800462768147075072': 1,
#  u'800696804245377024': 1,
#  u'800678713054461953': 1,
#  '3S5pepe': 3,
#  'ticomalacara': 1,
#  u'800677938521772032': 1,
#  'xavifillol': 1,
#  'gemabelen55': 1,
#  u'800711051700502528': 1,
#  u'800698973396709376': 1,
#  u'800671380723400704': 1,
#  'PauMLSB': 2,
#  u'800648344133599232': 1,
#  u'800628471273820160': 1,
#  u'800674285761232898': 1,
#  'Herrero1946Jose': 1,
#  u'800712789937430530': 1,
#  u'800636599985913857': 1,
#  u'800681305881145344': 1,
#  u'800733793514651648': 1,
#  'uatm82': 1,
#  u'800687963139096576': 1,
#  u'800701122793050112': 1,
#  'jbaamonde75': 1,
#  u'800687534649016320': 1,
#  'enriqueeseberri': 1,
#  'Jonamigob': 1,
#  'FrentePop': 1,
#  u'800712388601384961': 1,
#  'EnterateFutboI': 1,
#  'Silvi1967Sid': 1,
#  u'800713643948212224': 1,
#  'tiempodebolsa': 3,
#  u'800439231919243265': 1,
#  u'800733241724506112': 1,
#  'Margarita_Landi': 1,
#  u'800649343745327105': 1,
#  'contrastado': 1,
#  'eulaliobe': 1,
#  u'800637660310159362': 1,
#  u'800678285827051520': 1,
#  'MiguelPinedoPav': 1,
#  u'800720303156445184': 1,
#  u'800365008148463616': 1,
#  u'800689006765862913': 1,
#  u'800359657118306304': 1,
#  'montseramonv': 1,
#  'alexeina': 2,
#  'equoalcala': 1,
#  u'800685640174239744': 1,
#  u'800713427153014784': 1,
#  u'800721623062118400': 1,
#  u'800668158415798272': 1,
#  'ecabejo': 1,
#  'ytrio_': 1,
#  u'800680121803952128': 1,
#  'FJRealMadridCF': 1,
#  u'800701559591968768': 1,
#  u'800358630923104256': 1,
#  'femikutre': 1,
#  'Christianbatata': 1,
#  'Fabriv992': 1,
#  u'800734857957609473': 1,
#  u'800727635961659393': 1,
#  'JuanaVaras': 2,
#  u'800716897687740416': 1,
#  u'800464578371080193': 1,
#  'MeneAvila': 1,
#  u'800677196234944512': 1,
#  'CarlosArroyo4': 1,
#  u'800705494977511425': 1,
#  'EsmirnaRD': 1,
#  'marcedber': 1,
#  'carlosavila232': 3,
#  u'800698851057430528': 1,
#  u'800683909147230208': 1,
#  'jazminGomez_x20': 1,
#  'telemadrid': 2,
#  'Monicamox1': 2,
#  u'800673992763838464': 1,
#  u'800438708692455424': 1,
#  'roodrii_segovia': 1,
#  u'800430861824835584': 1,
#  u'800732105164595200': 1,
#  'valenciaimagen1': 1,
#  u'800709909352448000': 1,
#  'dra_jessica': 1,
#  'Alcon_Abogados': 1,
#  u'800627462086529024': 1,
#  'CoromotoLeila': 1,
#  'erevillamx': 1,
#  'agatagomail': 2,
#  'SmilerSwiftie5H': 1,
#  'XIMABISO': 3,
#  'albertopena1': 1,
#  u'800699807694196736': 1,
#  u'800695045703827456': 1,
#  u'800675617796567040': 1,
#  u'800733542015782913': 1,
#  u'800688248766930944': 1,
#  'mirinqn2005': 1,
#  'anpeigaz': 1,
#  'MIRBIL2014': 2,
#  'colladov61': 1,
#  u'800638312889389056': 1,
#  u'800660173543051264': 1,
#  u'800727278086811649': 1,
#  'Montimer94': 2,
#  u'800729982112825344': 1,
#  u'800687040945946624': 1,
#  u'800679851254542336': 1,
#  u'800439045629349888': 1,
#  'josemp': 1,
#  'ddsewd': 2,
#  u'800700836464705536': 1,
#  u'800716109439713281': 1,
#  u'800658397452505088': 1,
#  u'800697429410594816': 1,
#  u'800681951623606274': 1,
#  'vanja_shari': 1,
#  u'800741047718526977': 1,
#  'DoaErreQueErre': 1,
#  u'800715508110729216': 1,
#  'Ingoguma_': 1,
#  u'800667500438519808': 1,
#  u'800662494763094016': 1,
#  'MirentxuCastro': 1,
#  u'800649367464067072': 1,
#  u'800719501226446848': 1,
#  'SaraSomosaguas': 1,
#  u'800702419990675456': 1,
#  u'800357306089279488': 1,
#  u'800656665746046976': 1,
#  'electroningplc': 1,
#  'aleixandre_a': 1,
#  'Almudenamarea': 3,
#  u'800735384007155712': 1,
#  u'800439736577982464': 1,
#  'vickyriver72': 1,
#  u'800675910890360832': 1,
#  u'800671752074526720': 1,
#  'AzoteCasta': 2,
#  u'800720536166924288': 1,
#  u'800702362633568256': 1,
#  'LuengoJose': 1,
#  u'800641562308988928': 1,
#  'aneshali': 1,
#  u'800731369794048000': 1,
#  'MaiteTorres9': 1,
#  'mpmoragon': 1,
#  u'800656053927079936': 1,
#  'fxchae': 1,
#  'ManoliPirula': 1,
#  'Chaykgs': 1,
#  'j02uanca': 4,
#  'cavernamediatic': 1,
#  u'800694862123331584': 1,
#  'marquesdeneguri': 1,
#  'titirimundy': 1,
#  'WMBUSTOS': 1,
#  u'800708331882954753': 1,
#  'palcorubia': 1,
#  u'800731527046922240': 1,
#  u'800702845007732737': 1,
#  u'800682795731484672': 1,
#  'antoniotrevin': 1,
#  'heccrc': 1,
#  'Chocolate_Ok_': 1,
#  u'800741717922021377': 1,
#  u'800678477208829957': 1,
#  'vmcorzo': 1,
#  'Sergipi': 1,
#  '6cleo': 1,
#  u'800698425662640128': 1,
#  'SergiGP': 1,
#  u'800702977929572352': 1,
#  u'800629713194586112': 1,
#  u'800722751887654912': 1,
#  u'800634993089384448': 1,
#  u'800696395883638784': 1,
#  u'800675850408652800': 1,
#  u'800632087711780864': 1,
#  u'800660695444430849': 1,
#  'HeledeLeon': 1,
#  'MontarazTrancos': 3,
#  'josefrannarciso': 1,
#  u'800712534697226242': 1,
#  'gisb_sus': 1,
#  'asturianodepro': 1,
#  u'800632084649902080': 1,
#  u'800697813776613376': 1,
#  u'800647399626547200': 1,
#  'JveMonty': 1,
#  'Agus_Crzz_Lula': 1,
#  'nomadayo': 1,
#  'sarahYK8': 2,
#  u'800688101676957696': 1,
#  'Silviazarafolas': 1,
#  u'800725126585192448': 1,
#  u'800448202541563904': 1,
#  'DailyMurAlhmdmu': 1,
#  u'800693605887262720': 1,
#  'PatFBermejo': 1,
#  u'800435613879201792': 1,
#  u'800692996203249664': 1,
#  'kanuti1977': 1,
#  'juanjofdezl': 1,
#  'helenchi55': 1,
#  'Mins1965': 1,
#  u'800436271592116224': 1,
#  'nachazo': 1,
#  '_LaMamma_': 1,
#  'lozomarti': 1,
#  'todoslosblock': 2,
#  'reyesmariaglez': 1,
#  u'800678000035594244': 1,
#  u'800444556684693505': 1,
#  'viajesbosforo': 1,
#  u'800734946038022145': 1,
#  'l_alonso': 2,
#  u'800706775381110785': 1,
#  'angelotobg': 1,
#  u'800697923097022465': 1,
#  u'800723577922125824': 1,
#  u'800731067716161536': 1,
#  'javierbcn333': 1,
#  u'800689365827522562': 1,
#  u'800676764838166528': 1,
#  u'800365768185679872': 1,
#  u'800710904602132481': 1,
#  u'800711850593841152': 1,
#  u'800458082472120320': 1,
#  u'800739825783599105': 1,
#  u'800685497983107072': 1,
#  'luciaferradas': 1,
#  u'800719419609649153': 1,
#  'RRIHUETE': 1,
#  u'800669662652534785': 1,
#  u'800717835718643714': 1,
#  'Cs_Libres': 1,
#  u'800674793204973568': 1,
#  u'800697840179748864': 1,
#  'ribeiroanamaria': 1,
#  'onubachat': 1,
#  'elazotedel': 1,
#  'tusanunciosmex': 1,
#  u'800728629399420928': 1,
#  u'800633335307452416': 1,
#  u'800691788889681920': 1,
#  u'800710584370987009': 1,
#  u'800662931839062016': 1,
#  u'800442850416660480': 1,
#  'korzklap': 1,
#  'pratseva': 2,
#  'proecuador_mad': 1,
#  u'800661274606665729': 1,
#  'Andreavpf82': 1,
#  'Carles_Vidal': 1,
#  u'800692671693979649': 1,
#  'PALPHI': 1,
#  'VampireIsKawaii': 1,
#  u'800457862732480517': 1,
#  u'800704603318812672': 1,
#  u'800714040251154432': 1,
#  'fredy_rosillo': 1,
#  u'800442096977121284': 1,
#  u'800649838790578177': 1,
#  u'800450838602846208': 1,
#  'Dariiely_': 19,
#  u'800726210808578048': 1,
#  'HotmaChino': 1,
#  'yizo7': 1,
#  u'800719705619185664': 1,
#  u'800735615482404864': 1,
#  'XavierCapdevil2': 1,
#  'sthrytayes': 1,
#  'makynavajeando': 1,
#  'Rosario78924761': 2,
#  u'800719276088889344': 1,
#  u'800676422964678656': 1,
#  u'800720209246113792': 1,
#  'Podemos2015': 1,
#  u'800679393853116416': 1,
#  u'800661079735042048': 1,
#  'Tonicanto1': 1,
#  'bluecatgossip': 1,
#  u'800684822503026689': 1,
#  u'800364138522234881': 1,
#  'GamergyES': 1,
#  'AlbertoNaval1': 1,
#  'maytegonca': 3,
#  'maalmela': 1,
#  'Rubenak': 2,
#  'curefans': 1,
#  u'800706800970563584': 1,
#  u'800730220512866308': 1,
#  u'800685063813918721': 1,
#  u'800735280969945088': 1,
#  'FLeorion': 1,
#  'cmiremalazne': 2,
#  'ReinoMadridista': 1,
#  u'800718660319019008': 1,
#  u'800705231029841921': 1,
#  'MartaPastor': 2,
#  'angsimpa': 3,
#  u'800735239148605440': 1,
#  u'800668058411012096': 1,
#  'chrisjs12': 1,
#  u'800670839855337472': 1,
#  u'800681851706810369': 1,
#  u'800687097334087681': 1,
#  u'800728556351406080': 1,
#  'AnikinGil': 1,
#  u'800634557397684224': 1,
#  'diosflorentino': 1,
#  'RizzoBlackStar': 1,
#  u'800723581504225280': 1,
#  u'800716121242374145': 1,
#  'chakie51': 6,
#  u'800435970466164736': 1,
#  u'800717288961937408': 1,
#  u'800722397108248577': 1,
#  u'800732932486889472': 1,
#  u'800688160980111362': 1,
#  u'800736877745676289': 1,
#  u'800437807130910721': 1,
#  u'800712573788258304': 1,
#  'laure_santana': 1,
#  u'800740124992671748': 1,
#  'josepalmalozano': 1,
#  u'800717581401235456': 1,
#  u'800729608840679425': 1,
#  u'800728318618337280': 1,
#  u'800649119639498752': 1,
#  'JazzeLeon': 1,
#  u'800367228445069312': 1,
#  u'800700618092343300': 1,
#  'AmericaAPrimera': 1,
#  'Libra_Rojo': 1,
#  u'800648323216605184': 1,
#  'MiloImpera': 1,
#  'EsPosiciones': 1,
#  u'800699964833861632': 1,
#  u'800680817492197376': 1,
#  'Martu_kita': 2,
#  u'800722603384049664': 1,
#  'VikNavorski': 1,
#  u'800719263539433473': 1,
#  'Fino_Felino': 1,
#  '_OscarBenitez_': 1,
#  u'800708586267668480': 1,
#  u'800633462336212993': 1,
#  u'800680130045739010': 1,
#  u'800726435186884608': 1,
#  u'800659365283975169': 1,
#  u'800679604063080448': 1,
#  'dirobotello': 1,
#  u'800676140436377601': 1,
#  u'800704700286926848': 1,
#  'Yersinia1982': 1,
#  'Rothb4rd': 1,
#  u'800359696905289728': 1,
#  u'800721509178339329': 1,
#  'pabolo_w': 1,
#  'Juanijito11': 1,
#  u'800429414488113152': 1,
#  u'800715579619418116': 1,
#  'SlyLR': 3,
#  u'800633625360400384': 1,
#  u'800726820169588736': 1,
#  u'800692628685815808': 1,
#  'JuntosporGuanta': 1,
#  'dbargel': 2,
#  u'800733843133120512': 1,
#  'OlivaRuarte': 1,
#  'lolylamejor2002': 1,
#  'Bolsarota': 1,
#  'pazgabela': 1,
#  u'800704602660306944': 1,
#  u'800706926623518720': 1,
#  u'800734212877905921': 1,
#  'RaulAlcaldeS': 4,
#  u'800458464900382721': 1,
#  u'800453331168673792': 1,
#  'FIRETBF': 1,
#  u'800687072243695616': 1,
#  'HermannLacHey': 1,
#  u'800687369749938176': 1,
#  'IzaroOtxoa1': 1,
#  u'800713077473865728': 1,
#  'Faricarol': 1,
#  'rbt1975': 1,
#  u'800741867629539329': 1,
#  'OWLand1': 1,
#  u'800707629408550912': 1,
#  u'800461097316872194': 1,
#  'moranjesus89': 1,
#  'cullerot_g': 1,
#  u'800709638555508736': 1,
#  'SunriseAtTheSky': 1,
#  u'800739046410489856': 1,
#  'PALOMACORRALRIV': 1,
#  u'800739001183465472': 1,
#  'AhoraChamartin': 1,
#  'onethatsavesme': 1,
#  u'800676515172093952': 1,
#  u'800444099186655232': 1,
#  u'800734600419016704': 1,
#  'lezmanu': 1,
#  u'800462698563694592': 1,
#  'Marjamardo': 1,
#  u'800682805927608320': 1,
#  'Juan_Gascon': 1,
#  'Miguel_Moto': 1,
#  'Mario_Rua': 1,
#  'aesthanbin': 2,
#  u'800434586526191616': 1,
#  'nachoeusebio': 1,
#  'abdelafu': 2,
#  'VIAJESNEREMAR': 1,
#  'ripalo1957': 1,
#  u'800711279421878272': 1,
#  'Conchimatusalem': 1,
#  u'800698680340779008': 1,
#  u'800638677915500544': 1,
#  u'800738124976492544': 1,
#  u'800721746194272256': 1,
#  'JcnMely': 1,
#  'Mari_ano_Rajiao': 1,
#  'amurga1': 2,
#  u'800712279272685569': 1,
#  'Olivia59608218': 1,
#  'DesdeRamon': 1,
#  'jmaurab': 1,
#  u'800691474425872384': 1,
#  'MjgpAzucena': 1,
#  u'800713704819953665': 1,
#  u'800685684335984640': 1,
#  u'800440765235105792': 1,
#  u'800361337616535552': 1,
#  u'800724476216406016': 1,
#  'kirytekantaba': 1,
#  'ieseccnn': 1,
#  u'800717062897287168': 1,
#  'JOSLUISHERNANDO': 1,
#  u'800459882826764290': 1,
#  'jadelgadolopez': 1,
#  u'800708751179190276': 1,
#  'JoseLuIllun': 2,
#  u'800691916824313856': 1,
#  u'800449642643210242': 1,
#  'kimerius': 1,
#  u'800717286088708096': 1,
#  'fer_pu86': 1,
#  'LaQueen919': 1,
#  'dariogalc': 1,
#  u'800690503398240256': 1,
#  'miotroyomismo': 2,
#  u'800731150343962624': 1,
#  u'800741340594180096': 1,
#  u'800675156830146560': 1,
#  u'800721871440347136': 1,
#  'Fans_Mimositas': 8,
#  u'800679319689248768': 1,
#  'JosMdelaRiva': 2,
#  u'800647310669529089': 1,
#  u'800721292353826817': 1,
#  u'800692404386791426': 1,
#  'Groonando': 1,
#  u'800643865350901760': 1,
#  'nlarauzo': 1,
#  'montesinosrosa2': 2,
#  u'800672943734980609': 1,
#  u'800676154365669376': 1,
#  u'800692630610968576': 1,
#  u'800438311512842240': 1,
#  'CMarinMoon': 1,
#  u'800356033025687552': 1,
#  'IsabelTorneroR': 1,
#  'instituto_dm': 1,
#  u'800358029816397824': 1,
#  'Misespain666': 1,
#  'AkilinoL': 2,
#  'Alpha3thegull': 1,
#  'antonio_hung': 1,
#  'GC_Esperanza': 1,
#  'EternoRmcf7': 1,
#  'JonaPalacios83': 1,
#  u'800449519846649857': 1,
#  'DavidJotxi': 1,
#  u'800670377164832768': 1,
#  u'800633507626229760': 1,
#  '98snerea': 1,
#  'alfonsoaltr': 1,
#  'matjortino': 1,
#  u'800740366198640640': 1,
#  'ondacero': 1,
#  u'800736244221276165': 1,
#  'Tijsx': 1,
#  u'800736499381792768': 1,
#  u'800690791081512960': 1,
#  u'800696505984307201': 1,
#  u'800674896460345344': 1,
#  'paloma_p_p': 1,
#  u'800680664987119616': 1,
#  u'800692968634073088': 1,
#  'mariaabadmullor': 1,
#  u'800648787647729664': 1,
#  u'800673623354773504': 1,
#  'Jota_POV': 1,
#  'Carlosindreams': 1,
#  u'800684148172136448': 1,
#  u'800743566444285952': 1,
#  u'800464680791601152': 1,
#  u'800719529324281856': 1,
#  u'800705464702902272': 1,
#  'Dama_Cristal': 1,
#  u'800637300900171776': 1,
#  'JaviGCarballal': 1,
#  u'800686367378407428': 1,
#  'ariztegui': 1,
#  u'800716972812013569': 1,
#  'SLQuintales': 1,
#  u'800710531636219905': 1,
#  'pprivasvaciamad': 1,
#  'mxritvri': 1,
#  u'800717242807754752': 1,
#  u'800648906627485696': 1,
#  'lalidre4m': 1,
#  'amc2412': 4,
#  u'800743221236269056': 1,
#  'carballo_glez': 1,
#  'zulia1972': 1,
#  u'800673503439687680': 1,
#  'MaribelMtnez': 1,
#  u'800721626211852288': 1,
#  'jacusna': 2,
#  u'800718757182238720': 1,
#  'AnnaMCris': 1,
#  'lxxxcia': 1,
#  'damita2808': 2,
#  u'800701029041979392': 1,
#  u'800734920234541056': 1,
#  u'800656461999140864': 1,
#  u'800731072983990272': 1,
#  u'800723581613133824': 1,
#  'FERGOMTW': 1,
#  'MEspinosa_': 1,
#  u'800459357477552128': 1,
#  'PARTISANPL': 1,
#  u'800689824818724864': 1,
#  'irisnual': 1,
#  'Mostandiella': 1,
#  u'800712702842798080': 1,
#  u'800735714904309768': 1,
#  u'800737613976129539': 1,
#  u'800459670867558400': 1,
#  u'800726985005625344': 1,
#  u'800701280788369408': 1,
#  'mts41600': 1,
#  u'800677251352297472': 1,
#  u'800718595932045312': 1,
#  'Minu211221': 1,
#  'alexisOrtegaM': 1,
#  'ex_men_in_black': 1,
#  'MacarenaOrozco': 1,
#  'Nigridal': 1,
#  u'800703089862905857': 1,
#  'FZkandoussi': 1,
#  u'800713974945816576': 1,
#  'Salpanama': 1,
#  'Roberto50991705': 1,
#  'rapeco51': 1,
#  u'800715787828887552': 1,
#  u'800707123214766080': 1,
#  u'800647928368939008': 1,
#  u'800460584777027584': 1,
#  u'800729766995206144': 1,
#  u'800730812043890689': 1,
#  u'800672558962135040': 1,
#  u'800442764550815744': 1,
#  'allokat': 1,
#  u'800429271776980992': 1,
#  u'800359625748905984': 1,
#  'joseriv13006184': 1,
#  u'800721892877271040': 1,
#  'Caposalva': 1,
#  u'800710768232497153': 1,
#  u'800432187749400576': 1,
#  u'800458127716077568': 1,
#  u'800709920287059968': 1,
#  u'800676697204989956': 1,
#  u'800688362768076800': 1,
#  u'800715320218517504': 1,
#  u'800743523234574337': 1,
#  'amart166': 1,
#  u'800705074351644672': 1,
#  'yuliatsuko': 3,
#  'Mixer4Life0': 1,
#  'eloymou': 1,
#  u'800457496771067904': 1,
#  ...}

# %%
# %matplotlib inline
nx.draw(g)
plt.show()

# %% [markdown]
# Grafo desarrollado en Neo4j

# %%
file = open('C:\\Users\\Alberto\\PycharmProjects\\twitterExtraction\\CarmenaTweets_Test.txt','r')
decoded = ''
counter = 0
graph  = Graph("http://localhost:7474/db/data/",user='neo4j',password='ingamc03')
for line in file: 
    try:
        decoded = json.loads(line)
    except Exception as e:
        print e,':',decoded['id'] 
        
    try:
        user = processUser(decoded, dfusers)
    except Exception as a:
        print a.args,':','error processing users'
        
    try:
        tw = processTweet(decoded,dftweets)
    except Exception as a:
        print a.args,':','error processing tweet'
        
    try:
        create_relationship(tw,graph)
    except Exception as a:
        print a.args,':','creating node and relationship'
# Out:
# NAME:SenioritoLuShin
# DESC:ateo. nihilista. republicano (no monarquico), un poco feminista
# FOLLOWERS:87
# FOLLOWING:None
# Procesaudo el publisher.....
# NAME:SenioritoLuShin
# DESC:ateo. nihilista. republicano (no monarquico), un poco feminista
# FOLLOWERS:87
# FOLLOWING:None
# Procesado....
# ("'unicode' object has no attribute 'name'",) : creating node and relationship
# NAME:biferato
# DESC:Podemos cambiar España, está en nuestras manos
# FOLLOWERS:71
# FOLLOWING:None
# Procesaudo el publisher.....
# NAME:biferato
# DESC:Podemos cambiar España, está en nuestras manos
# FOLLOWERS:71
# FOLLOWING:None
# Procesado....
# ("'unicode' object has no attribute 'name'",) : creating node and relationship
# NAME:patxi7045
# ("cannot concatenate 'str' and 'NoneType' objects",) : error processing User......
# ("local variable 'us' referenced before assignment",) : error processing users
# Procesaudo el publisher.....
# NAME:patxi7045
# ("cannot concatenate 'str' and 'NoneType' objects",) : error processing User......
# ("local variable 'us' referenced before assignment",) : error processing Tweet
# ("local variable 'tw' referenced before assignment",) : error processing tweet
# ("'unicode' object has no attribute 'name'",) : creating node and relationship
# NAME:susoglosada
# DESC:Nacido en Ferreira de Pantón (LuGO), liberal de centroderecha, muy español, muy madridista y orgulloso de militar en el PP, partido vertebrador de España
# FOLLOWERS:1008
# FOLLOWING:None
# Procesaudo el publisher.....
# NAME:susoglosada
# DESC:Nacido en Ferreira de Pantón (LuGO), liberal de centroderecha, muy español, muy madridista y orgulloso de militar en el PP, partido vertebrador de España
# FOLLOWERS:1008
# FOLLOWING:None
# Procesado....
# ("'unicode' object has no attribute 'name'",) : creating node and relationship
# Expecting , delimiter: line 1 column 2249 (char 2248) : 801190090080972800
# NAME:susoglosada
# DESC:Nacido en Ferreira de Pantón (LuGO), liberal de centroderecha, muy español, muy madridista y orgulloso de militar en el PP, partido vertebrador de España
# FOLLOWERS:1008
# FOLLOWING:None
# Procesaudo el publisher.....
# NAME:susoglosada
# DESC:Nacido en Ferreira de Pantón (LuGO), liberal de centroderecha, muy español, muy madridista y orgulloso de militar en el PP, partido vertebrador de España
# FOLLOWERS:1008
# FOLLOWING:None
# Procesado....
# ("'unicode' object has no attribute 'name'",) : creating node and relationship
# Unterminated string starting at: line 1 column 1666 (char 1665) : 801190090080972800
# NAME:susoglosada
# DESC:Nacido en Ferreira de Pantón (LuGO), liberal de centroderecha, muy español, muy madridista y orgulloso de militar en el PP, partido vertebrador de España
# FOLLOWERS:1008
# FOLLOWING:None
# Procesaudo el publisher.....
# NAME:susoglosada
# DESC:Nacido en Ferreira de Pantón (LuGO), liberal de centroderecha, muy español, muy madridista y orgulloso de militar en el PP, partido vertebrador de España
# FOLLOWERS:1008
# FOLLOWING:None
# Procesado....
# ("'unicode' object has no attribute 'name'",) : creating node and relationship

# %%
dfusers = pd.DataFrame(columns=['name','description','url','followers','lang','profile_image','following','followers'])
dftweets = pd.DataFrame(columns=['userId','geo','coordinates','timestamp','tweet','source','isretweeted','lang','lat','lon','polarity'])

# %%
dfusers.head(2)
# Out:
#            Unnamed: 0                 name            location  \
# 0  799032032017993733  GRUPO METRO MENDOZA  Mendoza, Argentina
# 1          2326149346           Pepe López                 NaN
#
#                             url  followers lang  \
# 0  http://www.grupometromza.com       24.0   es
# 1                           NaN      329.0   es
#
#                                        profile_image  following
# 0  http://pbs.twimg.com/profile_images/7990356908...        NaN
# 1  http://pbs.twimg.com/profile_images/4310926238...        NaN
